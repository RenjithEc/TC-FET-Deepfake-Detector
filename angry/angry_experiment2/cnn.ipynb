# %%
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, concatenate,GlobalAveragePooling2D,Multiply,
    Add)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay, recall_score, precision_score, precision_recall_curve, auc

import seaborn as sns
import os
import random
import csv
import cv2

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\G713QM-\AppData\Local\Temp\ipykernel_22804\1336445651.py:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
def collect_images_recursively(base_folder):
    """
    Recursively collect image paths from all subdirectories.
    """
    image_paths = []
    for root, _, files in os.walk(base_folder):
        for file in sorted(files):
            if file.endswith(('.png', '.jpg', '.jpeg')):  # Add more formats if needed
                image_paths.append(os.path.join(root, file))
    return image_paths

def prepare_dataset(real_faces_folder, real_flow_folder, fake_faces_folder, fake_flow_folder, output_csv):
    """
    Prepare a CSV dataset mapping spatial frames (cropped faces) and optical flow images with labels
    for real and fake data.
    """
    dataset = []

    def process_real_data(cropped_faces_folder, optical_flow_folder, label):
        """
        Process real data, filtering only subdirectories containing "uniform" and "camera_front".
        """
        print("[INFO] Processing real data...")
        for subdir_name in sorted(os.listdir(cropped_faces_folder)):
            # if "uniform" not in subdir_name or "camera_front" not in subdir_name:
            #     continue

            subdir_path = os.path.join(cropped_faces_folder, subdir_name)
            flow_path = os.path.join(optical_flow_folder, subdir_name)

            if not os.path.isdir(subdir_path) or not os.path.isdir(flow_path):
                continue

            spatial_frames = collect_images_recursively(subdir_path)
            optical_flows = collect_images_recursively(flow_path)

            for frame, flow in zip(spatial_frames, optical_flows):
                dataset.append([frame, flow, label])

    def process_fake_data(cropped_faces_folder, optical_flow_folder, label):
        """
        Process fake data, filtering only subdirectories where the first three characters
        of the name after "end_to_end" are numeric and less than 101.
        """
        print("[INFO] Processing fake data...")
        for root, dirs, files in os.walk(cropped_faces_folder):
            if "end_to_end" not in root:
                continue

            # Extract the part after "end_to_end"
            parts = root.split("end_to_end")[-1].strip(os.sep).split(os.sep)
            print(f"[DEBUG] Current root: {root}")
            print(f"[DEBUG] Parts after 'end_to_end': {parts}")
            
            # if len(parts) < 1:
            #     print("[DEBUG] Skipping: No valid parts after 'end_to_end'.")
            #     continue
            
            # Get the first subdirectory name and split to extract the numeric prefix
            # first_part = parts[0]
            # numeric_prefix = first_part.split("_")[0]
            
            # if not numeric_prefix.isdigit():
            #     print(f"[DEBUG] Skipping: Prefix '{numeric_prefix}' is not numeric.")
            #     continue
            
            # if int(numeric_prefix) >= 200:
            #     print(f"[DEBUG] Skipping: Prefix '{numeric_prefix}' >= 101.")
            #     continue

            # Construct the corresponding optical flow folder
            relative_path = os.path.relpath(root, cropped_faces_folder)
            flow_path = os.path.join(optical_flow_folder, relative_path)
            
            if not os.path.isdir(flow_path):
                print(f"[DEBUG] Skipping: Optical flow folder does not exist for {root}.")
                continue

            # Recursively collect images
            spatial_frames = collect_images_recursively(root)
            optical_flows = collect_images_recursively(flow_path)

            for frame, flow in zip(spatial_frames, optical_flows):
                dataset.append([frame, flow, label])

    # Process real data
    process_real_data(real_faces_folder, real_flow_folder, label=0)

    # Process fake data
    process_fake_data(fake_faces_folder, fake_flow_folder, label=1)

    # Shuffle and save to CSV
    print(f"[INFO] Total dataset size before shuffling: {len(dataset)}")
    random.shuffle(dataset)
    with open(output_csv, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["spatial_frame", "optical_flow", "label"])  # Header
        writer.writerows(dataset)
    print(f"[INFO] CSV saved to: {output_csv}")

# Define paths
real_faces = "E:/Research/real/Cropped_Faces"
real_flow = "E:/Research/real/Optical_Flow"
fake_faces = "E:/Research/fake/Cropped_Faces"
fake_flow = "E:/Research/fake/Optical_Flow"
output_csv = "angry_dataset_real_fake_filtered.csv"

# Prepare the dataset
prepare_dataset(real_faces, real_flow, fake_faces, fake_flow, output_csv)
print("[INFO] Dataset preparation complete.")
# Out:
# [INFO] Processing real data...
# [INFO] Processing fake data...
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end
# [DEBUG] Parts after 'end_to_end': ['']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\711_M007
# [DEBUG] Parts after 'end_to_end': ['711_M007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\023_M113
# [DEBUG] Parts after 'end_to_end': ['023_M113']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\759_W025
# [DEBUG] Parts after 'end_to_end': ['759_W025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\952_W101
# [DEBUG] Parts after 'end_to_end': ['952_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\351_M023
# [DEBUG] Parts after 'end_to_end': ['351_M023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\837_W037
# [DEBUG] Parts after 'end_to_end': ['837_W037']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\974_M038
# [DEBUG] Parts after 'end_to_end': ['974_M038']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\092_M120
# [DEBUG] Parts after 'end_to_end': ['092_M120']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\503_W134
# [DEBUG] Parts after 'end_to_end': ['503_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\436_W022
# [DEBUG] Parts after 'end_to_end': ['436_W022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\816_W135
# [DEBUG] Parts after 'end_to_end': ['816_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\591_M118
# [DEBUG] Parts after 'end_to_end': ['591_M118']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\967_W008
# [DEBUG] Parts after 'end_to_end': ['967_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\050_M115
# [DEBUG] Parts after 'end_to_end': ['050_M115']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\536_W037
# [DEBUG] Parts after 'end_to_end': ['536_W037']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\270_M015
# [DEBUG] Parts after 'end_to_end': ['270_M015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\059_M118
# [DEBUG] Parts after 'end_to_end': ['059_M118']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\451_M138
# [DEBUG] Parts after 'end_to_end': ['451_M138']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\467_W027
# [DEBUG] Parts after 'end_to_end': ['467_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\851_M022
# [DEBUG] Parts after 'end_to_end': ['851_M022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\543_M141
# [DEBUG] Parts after 'end_to_end': ['543_M141']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\814_W134
# [DEBUG] Parts after 'end_to_end': ['814_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\490_W032
# [DEBUG] Parts after 'end_to_end': ['490_W032']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\553_W040
# [DEBUG] Parts after 'end_to_end': ['553_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\705_M132
# [DEBUG] Parts after 'end_to_end': ['705_M132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\833_M019
# [DEBUG] Parts after 'end_to_end': ['833_M019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\419_M031
# [DEBUG] Parts after 'end_to_end': ['419_M031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\315_W006
# [DEBUG] Parts after 'end_to_end': ['315_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\005_W101
# [DEBUG] Parts after 'end_to_end': ['005_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\360_W012
# [DEBUG] Parts after 'end_to_end': ['360_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\544_W039
# [DEBUG] Parts after 'end_to_end': ['544_W039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\702_M132
# [DEBUG] Parts after 'end_to_end': ['702_M132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\007_W101
# [DEBUG] Parts after 'end_to_end': ['007_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\318_W006
# [DEBUG] Parts after 'end_to_end': ['318_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\972_W009
# [DEBUG] Parts after 'end_to_end': ['972_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\101_W018
# [DEBUG] Parts after 'end_to_end': ['101_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\771_W027
# [DEBUG] Parts after 'end_to_end': ['771_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\129_M124
# [DEBUG] Parts after 'end_to_end': ['129_M124']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\132_W023
# [DEBUG] Parts after 'end_to_end': ['132_W023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\223_W037
# [DEBUG] Parts after 'end_to_end': ['223_W037']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\075_W014
# [DEBUG] Parts after 'end_to_end': ['075_W014']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\723_W132
# [DEBUG] Parts after 'end_to_end': ['723_W132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\428_W022
# [DEBUG] Parts after 'end_to_end': ['428_W022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\247_W040
# [DEBUG] Parts after 'end_to_end': ['247_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\191_W032
# [DEBUG] Parts after 'end_to_end': ['191_W032']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\179_M007
# [DEBUG] Parts after 'end_to_end': ['179_M007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\244_W040
# [DEBUG] Parts after 'end_to_end': ['244_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\901_M029
# [DEBUG] Parts after 'end_to_end': ['901_M029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\003_M101
# [DEBUG] Parts after 'end_to_end': ['003_M101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\185_M008
# [DEBUG] Parts after 'end_to_end': ['185_M008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\789_W133
# [DEBUG] Parts after 'end_to_end': ['789_W133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\183_M007
# [DEBUG] Parts after 'end_to_end': ['183_M007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\654_W131
# [DEBUG] Parts after 'end_to_end': ['654_W131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\739_W022
# [DEBUG] Parts after 'end_to_end': ['739_W022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\215_W036
# [DEBUG] Parts after 'end_to_end': ['215_W036']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\513_M104
# [DEBUG] Parts after 'end_to_end': ['513_M104']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\555_W040
# [DEBUG] Parts after 'end_to_end': ['555_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\257_W042
# [DEBUG] Parts after 'end_to_end': ['257_W042']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\168_W029
# [DEBUG] Parts after 'end_to_end': ['168_W029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\010_W006
# [DEBUG] Parts after 'end_to_end': ['010_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\571_M115
# [DEBUG] Parts after 'end_to_end': ['571_M115']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\507_W134
# [DEBUG] Parts after 'end_to_end': ['507_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\802_W031
# [DEBUG] Parts after 'end_to_end': ['802_W031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\834_M019
# [DEBUG] Parts after 'end_to_end': ['834_M019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\540_W136
# [DEBUG] Parts after 'end_to_end': ['540_W136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\889_W042
# [DEBUG] Parts after 'end_to_end': ['889_W042']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\052_W012
# [DEBUG] Parts after 'end_to_end': ['052_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\140_M132
# [DEBUG] Parts after 'end_to_end': ['140_M132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\950_M105
# [DEBUG] Parts after 'end_to_end': ['950_M105']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\595_W116
# [DEBUG] Parts after 'end_to_end': ['595_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\234_M012
# [DEBUG] Parts after 'end_to_end': ['234_M012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\193_W032
# [DEBUG] Parts after 'end_to_end': ['193_W032']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\768_M012
# [DEBUG] Parts after 'end_to_end': ['768_M012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\953_M137
# [DEBUG] Parts after 'end_to_end': ['953_M137']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\231_W136
# [DEBUG] Parts after 'end_to_end': ['231_W136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\038_W009
# [DEBUG] Parts after 'end_to_end': ['038_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\904_W111
# [DEBUG] Parts after 'end_to_end': ['904_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\326_M021
# [DEBUG] Parts after 'end_to_end': ['326_M021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\161_W027
# [DEBUG] Parts after 'end_to_end': ['161_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\377_M026
# [DEBUG] Parts after 'end_to_end': ['377_M026']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\955_M138
# [DEBUG] Parts after 'end_to_end': ['955_M138']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\758_W025
# [DEBUG] Parts after 'end_to_end': ['758_W025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\673_W013
# [DEBUG] Parts after 'end_to_end': ['673_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\667_W005
# [DEBUG] Parts after 'end_to_end': ['667_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\357_M024
# [DEBUG] Parts after 'end_to_end': ['357_M024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\205_W135
# [DEBUG] Parts after 'end_to_end': ['205_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\912_M031
# [DEBUG] Parts after 'end_to_end': ['912_M031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\111_M123
# [DEBUG] Parts after 'end_to_end': ['111_M123']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\304_M019
# [DEBUG] Parts after 'end_to_end': ['304_M019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\317_W006
# [DEBUG] Parts after 'end_to_end': ['317_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\350_W131
# [DEBUG] Parts after 'end_to_end': ['350_W131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\567_W042
# [DEBUG] Parts after 'end_to_end': ['567_W042']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\013_W006
# [DEBUG] Parts after 'end_to_end': ['013_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\022_M109
# [DEBUG] Parts after 'end_to_end': ['022_M109']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\393_M028
# [DEBUG] Parts after 'end_to_end': ['393_M028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\764_W026
# [DEBUG] Parts after 'end_to_end': ['764_W026']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\882_W041
# [DEBUG] Parts after 'end_to_end': ['882_W041']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\437_W023
# [DEBUG] Parts after 'end_to_end': ['437_W023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\712_W018
# [DEBUG] Parts after 'end_to_end': ['712_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\279_M134
# [DEBUG] Parts after 'end_to_end': ['279_M134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\210_M010
# [DEBUG] Parts after 'end_to_end': ['210_M010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\195_M008
# [DEBUG] Parts after 'end_to_end': ['195_M008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\769_W027
# [DEBUG] Parts after 'end_to_end': ['769_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\640_M122
# [DEBUG] Parts after 'end_to_end': ['640_M122']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\184_W031
# [DEBUG] Parts after 'end_to_end': ['184_W031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\671_W005
# [DEBUG] Parts after 'end_to_end': ['671_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\001_W101
# [DEBUG] Parts after 'end_to_end': ['001_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\799_W031
# [DEBUG] Parts after 'end_to_end': ['799_W031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\683_W014
# [DEBUG] Parts after 'end_to_end': ['683_W014']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\025_W007
# [DEBUG] Parts after 'end_to_end': ['025_W007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\330_W008
# [DEBUG] Parts after 'end_to_end': ['330_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\979_M038
# [DEBUG] Parts after 'end_to_end': ['979_M038']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\844_M134
# [DEBUG] Parts after 'end_to_end': ['844_M134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\259_M014
# [DEBUG] Parts after 'end_to_end': ['259_M014']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\854_M022
# [DEBUG] Parts after 'end_to_end': ['854_M022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\568_M114
# [DEBUG] Parts after 'end_to_end': ['568_M114']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\470_M139
# [DEBUG] Parts after 'end_to_end': ['470_M139']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\356_M024
# [DEBUG] Parts after 'end_to_end': ['356_M024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\869_W040
# [DEBUG] Parts after 'end_to_end': ['869_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\648_W009
# [DEBUG] Parts after 'end_to_end': ['648_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\448_M034
# [DEBUG] Parts after 'end_to_end': ['448_M034']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\122_W021
# [DEBUG] Parts after 'end_to_end': ['122_W021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\453_W024
# [DEBUG] Parts after 'end_to_end': ['453_W024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\992_W012
# [DEBUG] Parts after 'end_to_end': ['992_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\116_W132
# [DEBUG] Parts after 'end_to_end': ['116_W132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\630_W006
# [DEBUG] Parts after 'end_to_end': ['630_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\634_W007
# [DEBUG] Parts after 'end_to_end': ['634_W007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\625_W006
# [DEBUG] Parts after 'end_to_end': ['625_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\294_W100
# [DEBUG] Parts after 'end_to_end': ['294_W100']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\214_W035
# [DEBUG] Parts after 'end_to_end': ['214_W035']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\586_W111
# [DEBUG] Parts after 'end_to_end': ['586_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\942_M137
# [DEBUG] Parts after 'end_to_end': ['942_M137']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\368_W005
# [DEBUG] Parts after 'end_to_end': ['368_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\781_W029
# [DEBUG] Parts after 'end_to_end': ['781_W029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\310_M019
# [DEBUG] Parts after 'end_to_end': ['310_M019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\892_W110
# [DEBUG] Parts after 'end_to_end': ['892_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\088_W016
# [DEBUG] Parts after 'end_to_end': ['088_W016']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\145_W025
# [DEBUG] Parts after 'end_to_end': ['145_W025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\288_W125
# [DEBUG] Parts after 'end_to_end': ['288_W125']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\888_M027
# [DEBUG] Parts after 'end_to_end': ['888_M027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\406_W018
# [DEBUG] Parts after 'end_to_end': ['406_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\831_W036
# [DEBUG] Parts after 'end_to_end': ['831_W036']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\725_W021
# [DEBUG] Parts after 'end_to_end': ['725_W021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\983_W131
# [DEBUG] Parts after 'end_to_end': ['983_W131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\784_W029
# [DEBUG] Parts after 'end_to_end': ['784_W029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\114_M123
# [DEBUG] Parts after 'end_to_end': ['114_M123']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\996_M039
# [DEBUG] Parts after 'end_to_end': ['996_M039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\099_W018
# [DEBUG] Parts after 'end_to_end': ['099_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\371_W013
# [DEBUG] Parts after 'end_to_end': ['371_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\674_M131
# [DEBUG] Parts after 'end_to_end': ['674_M131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\766_W027
# [DEBUG] Parts after 'end_to_end': ['766_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\848_M021
# [DEBUG] Parts after 'end_to_end': ['848_M021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\281_W116
# [DEBUG] Parts after 'end_to_end': ['281_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\424_M031
# [DEBUG] Parts after 'end_to_end': ['424_M031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\128_M124
# [DEBUG] Parts after 'end_to_end': ['128_M124']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\971_M138
# [DEBUG] Parts after 'end_to_end': ['971_M138']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\954_W101
# [DEBUG] Parts after 'end_to_end': ['954_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\508_W135
# [DEBUG] Parts after 'end_to_end': ['508_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\206_W135
# [DEBUG] Parts after 'end_to_end': ['206_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\613_M120
# [DEBUG] Parts after 'end_to_end': ['613_M120']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\104_W018
# [DEBUG] Parts after 'end_to_end': ['104_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\986_W131
# [DEBUG] Parts after 'end_to_end': ['986_W131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\218_M011
# [DEBUG] Parts after 'end_to_end': ['218_M011']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\668_W005
# [DEBUG] Parts after 'end_to_end': ['668_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\929_W116
# [DEBUG] Parts after 'end_to_end': ['929_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\629_W006
# [DEBUG] Parts after 'end_to_end': ['629_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\578_W110
# [DEBUG] Parts after 'end_to_end': ['578_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\143_M132
# [DEBUG] Parts after 'end_to_end': ['143_M132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\836_W037
# [DEBUG] Parts after 'end_to_end': ['836_W037']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\637_W008
# [DEBUG] Parts after 'end_to_end': ['637_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\658_M124
# [DEBUG] Parts after 'end_to_end': ['658_M124']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\209_M010
# [DEBUG] Parts after 'end_to_end': ['209_M010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\847_M021
# [DEBUG] Parts after 'end_to_end': ['847_M021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\645_W009
# [DEBUG] Parts after 'end_to_end': ['645_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\477_W029
# [DEBUG] Parts after 'end_to_end': ['477_W029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\181_M007
# [DEBUG] Parts after 'end_to_end': ['181_M007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\677_W013
# [DEBUG] Parts after 'end_to_end': ['677_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\600_M118
# [DEBUG] Parts after 'end_to_end': ['600_M118']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\021_W007
# [DEBUG] Parts after 'end_to_end': ['021_W007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\201_W134
# [DEBUG] Parts after 'end_to_end': ['201_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\669_M124
# [DEBUG] Parts after 'end_to_end': ['669_M124']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\631_M121
# [DEBUG] Parts after 'end_to_end': ['631_M121']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\443_M137
# [DEBUG] Parts after 'end_to_end': ['443_M137']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\086_W016
# [DEBUG] Parts after 'end_to_end': ['086_W016']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\686_W015
# [DEBUG] Parts after 'end_to_end': ['686_W015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\922_M135
# [DEBUG] Parts after 'end_to_end': ['922_M135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\774_M013
# [DEBUG] Parts after 'end_to_end': ['774_M013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\510_M104
# [DEBUG] Parts after 'end_to_end': ['510_M104']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\134_W023
# [DEBUG] Parts after 'end_to_end': ['134_W023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\715_M007
# [DEBUG] Parts after 'end_to_end': ['715_M007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\352_M024
# [DEBUG] Parts after 'end_to_end': ['352_M024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\426_W021
# [DEBUG] Parts after 'end_to_end': ['426_W021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\978_W010
# [DEBUG] Parts after 'end_to_end': ['978_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\627_M121
# [DEBUG] Parts after 'end_to_end': ['627_M121']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\282_W116
# [DEBUG] Parts after 'end_to_end': ['282_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\765_W027
# [DEBUG] Parts after 'end_to_end': ['765_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\057_W012
# [DEBUG] Parts after 'end_to_end': ['057_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\793_M015
# [DEBUG] Parts after 'end_to_end': ['793_M015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\254_W042
# [DEBUG] Parts after 'end_to_end': ['254_W042']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\020_M109
# [DEBUG] Parts after 'end_to_end': ['020_M109']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\333_M021
# [DEBUG] Parts after 'end_to_end': ['333_M021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\935_W125
# [DEBUG] Parts after 'end_to_end': ['935_W125']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\085_W015
# [DEBUG] Parts after 'end_to_end': ['085_W015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\560_M114
# [DEBUG] Parts after 'end_to_end': ['560_M114']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\925_M136
# [DEBUG] Parts after 'end_to_end': ['925_M136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\036_M114
# [DEBUG] Parts after 'end_to_end': ['036_M114']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\303_M105
# [DEBUG] Parts after 'end_to_end': ['303_M105']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\601_M119
# [DEBUG] Parts after 'end_to_end': ['601_M119']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\840_M134
# [DEBUG] Parts after 'end_to_end': ['840_M134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\908_M030
# [DEBUG] Parts after 'end_to_end': ['908_M030']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\312_W101
# [DEBUG] Parts after 'end_to_end': ['312_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\709_W018
# [DEBUG] Parts after 'end_to_end': ['709_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\170_W029
# [DEBUG] Parts after 'end_to_end': ['170_W029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\400_W018
# [DEBUG] Parts after 'end_to_end': ['400_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\913_W112
# [DEBUG] Parts after 'end_to_end': ['913_W112']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\253_M014
# [DEBUG] Parts after 'end_to_end': ['253_M014']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\746_M011
# [DEBUG] Parts after 'end_to_end': ['746_M011']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\341_W010
# [DEBUG] Parts after 'end_to_end': ['341_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\589_W112
# [DEBUG] Parts after 'end_to_end': ['589_W112']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\810_W134
# [DEBUG] Parts after 'end_to_end': ['810_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\946_W100
# [DEBUG] Parts after 'end_to_end': ['946_W100']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\585_W111
# [DEBUG] Parts after 'end_to_end': ['585_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\853_W136
# [DEBUG] Parts after 'end_to_end': ['853_W136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\649_W010
# [DEBUG] Parts after 'end_to_end': ['649_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\069_W013
# [DEBUG] Parts after 'end_to_end': ['069_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\995_M039
# [DEBUG] Parts after 'end_to_end': ['995_M039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\147_M132
# [DEBUG] Parts after 'end_to_end': ['147_M132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\412_W019
# [DEBUG] Parts after 'end_to_end': ['412_W019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\203_W134
# [DEBUG] Parts after 'end_to_end': ['203_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\171_M133
# [DEBUG] Parts after 'end_to_end': ['171_M133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\387_M028
# [DEBUG] Parts after 'end_to_end': ['387_M028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\574_M117
# [DEBUG] Parts after 'end_to_end': ['574_M117']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\124_W022
# [DEBUG] Parts after 'end_to_end': ['124_W022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\909_M030
# [DEBUG] Parts after 'end_to_end': ['909_M030']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\058_M117
# [DEBUG] Parts after 'end_to_end': ['058_M117']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\394_M028
# [DEBUG] Parts after 'end_to_end': ['394_M028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\653_M123
# [DEBUG] Parts after 'end_to_end': ['653_M123']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\856_M023
# [DEBUG] Parts after 'end_to_end': ['856_M023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\335_M022
# [DEBUG] Parts after 'end_to_end': ['335_M022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\039_M114
# [DEBUG] Parts after 'end_to_end': ['039_M114']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\423_W021
# [DEBUG] Parts after 'end_to_end': ['423_W021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\926_W116
# [DEBUG] Parts after 'end_to_end': ['926_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\876_M025
# [DEBUG] Parts after 'end_to_end': ['876_M025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\803_W032
# [DEBUG] Parts after 'end_to_end': ['803_W032']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\914_M031
# [DEBUG] Parts after 'end_to_end': ['914_M031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\813_W134
# [DEBUG] Parts after 'end_to_end': ['813_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\040_W010
# [DEBUG] Parts after 'end_to_end': ['040_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\852_M022
# [DEBUG] Parts after 'end_to_end': ['852_M022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\225_W037
# [DEBUG] Parts after 'end_to_end': ['225_W037']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\263_W111
# [DEBUG] Parts after 'end_to_end': ['263_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\165_W028
# [DEBUG] Parts after 'end_to_end': ['165_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\729_M008
# [DEBUG] Parts after 'end_to_end': ['729_M008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\777_M013
# [DEBUG] Parts after 'end_to_end': ['777_M013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\414_W132
# [DEBUG] Parts after 'end_to_end': ['414_W132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\932_M136
# [DEBUG] Parts after 'end_to_end': ['932_M136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\607_W100
# [DEBUG] Parts after 'end_to_end': ['607_W100']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\097_M121
# [DEBUG] Parts after 'end_to_end': ['097_M121']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\949_M105
# [DEBUG] Parts after 'end_to_end': ['949_M105']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\504_M140
# [DEBUG] Parts after 'end_to_end': ['504_M140']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\628_M121
# [DEBUG] Parts after 'end_to_end': ['628_M121']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\251_W041
# [DEBUG] Parts after 'end_to_end': ['251_W041']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\082_W015
# [DEBUG] Parts after 'end_to_end': ['082_W015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\563_W041
# [DEBUG] Parts after 'end_to_end': ['563_W041']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\232_W039
# [DEBUG] Parts after 'end_to_end': ['232_W039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\242_W040
# [DEBUG] Parts after 'end_to_end': ['242_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\891_M027
# [DEBUG] Parts after 'end_to_end': ['891_M027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\432_M136
# [DEBUG] Parts after 'end_to_end': ['432_M136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\064_M118
# [DEBUG] Parts after 'end_to_end': ['064_M118']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\202_W134
# [DEBUG] Parts after 'end_to_end': ['202_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\060_W012
# [DEBUG] Parts after 'end_to_end': ['060_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\144_W025
# [DEBUG] Parts after 'end_to_end': ['144_W025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\775_M013
# [DEBUG] Parts after 'end_to_end': ['775_M013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\473_W028
# [DEBUG] Parts after 'end_to_end': ['473_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\646_W009
# [DEBUG] Parts after 'end_to_end': ['646_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\261_W110
# [DEBUG] Parts after 'end_to_end': ['261_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\325_M021
# [DEBUG] Parts after 'end_to_end': ['325_M021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\102_M122
# [DEBUG] Parts after 'end_to_end': ['102_M122']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\164_M005
# [DEBUG] Parts after 'end_to_end': ['164_M005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\121_W021
# [DEBUG] Parts after 'end_to_end': ['121_W021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\825_W035
# [DEBUG] Parts after 'end_to_end': ['825_W035']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\032_W009
# [DEBUG] Parts after 'end_to_end': ['032_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\479_W029
# [DEBUG] Parts after 'end_to_end': ['479_W029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\037_W009
# [DEBUG] Parts after 'end_to_end': ['037_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\068_W013
# [DEBUG] Parts after 'end_to_end': ['068_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\415_M030
# [DEBUG] Parts after 'end_to_end': ['415_M030']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\208_W035
# [DEBUG] Parts after 'end_to_end': ['208_W035']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\883_W041
# [DEBUG] Parts after 'end_to_end': ['883_W041']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\706_W017
# [DEBUG] Parts after 'end_to_end': ['706_W017']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\821_M018
# [DEBUG] Parts after 'end_to_end': ['821_M018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\562_M114
# [DEBUG] Parts after 'end_to_end': ['562_M114']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\829_W035
# [DEBUG] Parts after 'end_to_end': ['829_W035']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\956_W101
# [DEBUG] Parts after 'end_to_end': ['956_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\795_W133
# [DEBUG] Parts after 'end_to_end': ['795_W133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\920_M135
# [DEBUG] Parts after 'end_to_end': ['920_M135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\596_W116
# [DEBUG] Parts after 'end_to_end': ['596_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\142_W025
# [DEBUG] Parts after 'end_to_end': ['142_W025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\071_M119
# [DEBUG] Parts after 'end_to_end': ['071_M119']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\583_W110
# [DEBUG] Parts after 'end_to_end': ['583_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\506_W134
# [DEBUG] Parts after 'end_to_end': ['506_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\576_W042
# [DEBUG] Parts after 'end_to_end': ['576_W042']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\269_M015
# [DEBUG] Parts after 'end_to_end': ['269_M015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\874_M025
# [DEBUG] Parts after 'end_to_end': ['874_M025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\718_W019
# [DEBUG] Parts after 'end_to_end': ['718_W019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\642_W008
# [DEBUG] Parts after 'end_to_end': ['642_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\501_M140
# [DEBUG] Parts after 'end_to_end': ['501_M140']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\561_W041
# [DEBUG] Parts after 'end_to_end': ['561_W041']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\109_M122
# [DEBUG] Parts after 'end_to_end': ['109_M122']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\663_W012
# [DEBUG] Parts after 'end_to_end': ['663_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\687_W015
# [DEBUG] Parts after 'end_to_end': ['687_W015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\547_M109
# [DEBUG] Parts after 'end_to_end': ['547_M109']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\028_W008
# [DEBUG] Parts after 'end_to_end': ['028_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\664_W012
# [DEBUG] Parts after 'end_to_end': ['664_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\529_W036
# [DEBUG] Parts after 'end_to_end': ['529_W036']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\458_W025
# [DEBUG] Parts after 'end_to_end': ['458_W025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\238_W039
# [DEBUG] Parts after 'end_to_end': ['238_W039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\533_W037
# [DEBUG] Parts after 'end_to_end': ['533_W037']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\464_M139
# [DEBUG] Parts after 'end_to_end': ['464_M139']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\133_M132
# [DEBUG] Parts after 'end_to_end': ['133_M132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\977_W010
# [DEBUG] Parts after 'end_to_end': ['977_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\118_W132
# [DEBUG] Parts after 'end_to_end': ['118_W132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\871_W041
# [DEBUG] Parts after 'end_to_end': ['871_W041']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\773_W028
# [DEBUG] Parts after 'end_to_end': ['773_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\012_W006
# [DEBUG] Parts after 'end_to_end': ['012_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\471_W027
# [DEBUG] Parts after 'end_to_end': ['471_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\900_W111
# [DEBUG] Parts after 'end_to_end': ['900_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\794_M015
# [DEBUG] Parts after 'end_to_end': ['794_M015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\695_M005
# [DEBUG] Parts after 'end_to_end': ['695_M005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\029_W008
# [DEBUG] Parts after 'end_to_end': ['029_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\524_W035
# [DEBUG] Parts after 'end_to_end': ['524_W035']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\608_M119
# [DEBUG] Parts after 'end_to_end': ['608_M119']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\963_M138
# [DEBUG] Parts after 'end_to_end': ['963_M138']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\886_M027
# [DEBUG] Parts after 'end_to_end': ['886_M027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\159_M005
# [DEBUG] Parts after 'end_to_end': ['159_M005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\245_M013
# [DEBUG] Parts after 'end_to_end': ['245_M013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\260_W110
# [DEBUG] Parts after 'end_to_end': ['260_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\862_W039
# [DEBUG] Parts after 'end_to_end': ['862_W039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\894_M027
# [DEBUG] Parts after 'end_to_end': ['894_M027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\355_W012
# [DEBUG] Parts after 'end_to_end': ['355_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\778_W028
# [DEBUG] Parts after 'end_to_end': ['778_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\887_W042
# [DEBUG] Parts after 'end_to_end': ['887_W042']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\841_M134
# [DEBUG] Parts after 'end_to_end': ['841_M134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\843_M134
# [DEBUG] Parts after 'end_to_end': ['843_M134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\791_M015
# [DEBUG] Parts after 'end_to_end': ['791_M015']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\569_M115
# [DEBUG] Parts after 'end_to_end': ['569_M115']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\819_W135
# [DEBUG] Parts after 'end_to_end': ['819_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\959_W006
# [DEBUG] Parts after 'end_to_end': ['959_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\612_M119
# [DEBUG] Parts after 'end_to_end': ['612_M119']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\742_M010
# [DEBUG] Parts after 'end_to_end': ['742_M010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\347_M023
# [DEBUG] Parts after 'end_to_end': ['347_M023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\076_W014
# [DEBUG] Parts after 'end_to_end': ['076_W014']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\014_M131
# [DEBUG] Parts after 'end_to_end': ['014_M131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\527_W036
# [DEBUG] Parts after 'end_to_end': ['527_W036']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\740_W022
# [DEBUG] Parts after 'end_to_end': ['740_W022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\474_W028
# [DEBUG] Parts after 'end_to_end': ['474_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\295_W100
# [DEBUG] Parts after 'end_to_end': ['295_W100']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\364_M025
# [DEBUG] Parts after 'end_to_end': ['364_M025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\349_W131
# [DEBUG] Parts after 'end_to_end': ['349_W131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\921_M135
# [DEBUG] Parts after 'end_to_end': ['921_M135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\786_W133
# [DEBUG] Parts after 'end_to_end': ['786_W133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\480_W133
# [DEBUG] Parts after 'end_to_end': ['480_W133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\197_M009
# [DEBUG] Parts after 'end_to_end': ['197_M009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\958_W006
# [DEBUG] Parts after 'end_to_end': ['958_W006']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\884_W042
# [DEBUG] Parts after 'end_to_end': ['884_W042']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\592_W112
# [DEBUG] Parts after 'end_to_end': ['592_W112']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\108_W019
# [DEBUG] Parts after 'end_to_end': ['108_W019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\694_M005
# [DEBUG] Parts after 'end_to_end': ['694_M005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\008_W101
# [DEBUG] Parts after 'end_to_end': ['008_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\370_W013
# [DEBUG] Parts after 'end_to_end': ['370_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\981_W010
# [DEBUG] Parts after 'end_to_end': ['981_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\182_W133
# [DEBUG] Parts after 'end_to_end': ['182_W133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\763_W026
# [DEBUG] Parts after 'end_to_end': ['763_W026']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\587_W111
# [DEBUG] Parts after 'end_to_end': ['587_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\898_M028
# [DEBUG] Parts after 'end_to_end': ['898_M028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\964_W007
# [DEBUG] Parts after 'end_to_end': ['964_W007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\367_W005
# [DEBUG] Parts after 'end_to_end': ['367_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\290_W125
# [DEBUG] Parts after 'end_to_end': ['290_W125']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\523_M101
# [DEBUG] Parts after 'end_to_end': ['523_M101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\248_W041
# [DEBUG] Parts after 'end_to_end': ['248_W041']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\651_W010
# [DEBUG] Parts after 'end_to_end': ['651_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\661_W012
# [DEBUG] Parts after 'end_to_end': ['661_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\641_W008
# [DEBUG] Parts after 'end_to_end': ['641_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\930_W116
# [DEBUG] Parts after 'end_to_end': ['930_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\127_M124
# [DEBUG] Parts after 'end_to_end': ['127_M124']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\785_W133
# [DEBUG] Parts after 'end_to_end': ['785_W133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\923_M135
# [DEBUG] Parts after 'end_to_end': ['923_M135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\299_M105
# [DEBUG] Parts after 'end_to_end': ['299_M105']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\861_M024
# [DEBUG] Parts after 'end_to_end': ['861_M024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\842_W136
# [DEBUG] Parts after 'end_to_end': ['842_W136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\558_W040
# [DEBUG] Parts after 'end_to_end': ['558_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\556_W040
# [DEBUG] Parts after 'end_to_end': ['556_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\593_W112
# [DEBUG] Parts after 'end_to_end': ['593_W112']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\459_W025
# [DEBUG] Parts after 'end_to_end': ['459_W025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\707_M007
# [DEBUG] Parts after 'end_to_end': ['707_M007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\976_W009
# [DEBUG] Parts after 'end_to_end': ['976_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\670_W005
# [DEBUG] Parts after 'end_to_end': ['670_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\993_W012
# [DEBUG] Parts after 'end_to_end': ['993_W012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\783_W029
# [DEBUG] Parts after 'end_to_end': ['783_W029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\616_M105
# [DEBUG] Parts after 'end_to_end': ['616_M105']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\910_M030
# ...
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\186_W031
# [DEBUG] Parts after 'end_to_end': ['186_W031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\411_W019
# [DEBUG] Parts after 'end_to_end': ['411_W019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\919_M031
# [DEBUG] Parts after 'end_to_end': ['919_M031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\751_W024
# [DEBUG] Parts after 'end_to_end': ['751_W024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\045_W010
# [DEBUG] Parts after 'end_to_end': ['045_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\875_M025
# [DEBUG] Parts after 'end_to_end': ['875_M025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\306_M019
# [DEBUG] Parts after 'end_to_end': ['306_M019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\120_W021
# [DEBUG] Parts after 'end_to_end': ['120_W021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\577_W110
# [DEBUG] Parts after 'end_to_end': ['577_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\500_W134
# [DEBUG] Parts after 'end_to_end': ['500_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\865_W039
# [DEBUG] Parts after 'end_to_end': ['865_W039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\401_M029
# [DEBUG] Parts after 'end_to_end': ['401_M029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\070_W013
# [DEBUG] Parts after 'end_to_end': ['070_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\337_M022
# [DEBUG] Parts after 'end_to_end': ['337_M022']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\167_W028
# [DEBUG] Parts after 'end_to_end': ['167_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\597_W116
# [DEBUG] Parts after 'end_to_end': ['597_W116']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\450_W024
# [DEBUG] Parts after 'end_to_end': ['450_W024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\043_M115
# [DEBUG] Parts after 'end_to_end': ['043_M115']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\439_W023
# [DEBUG] Parts after 'end_to_end': ['439_W023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\177_W133
# [DEBUG] Parts after 'end_to_end': ['177_W133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\657_W131
# [DEBUG] Parts after 'end_to_end': ['657_W131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\302_M105
# [DEBUG] Parts after 'end_to_end': ['302_M105']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\808_W032
# [DEBUG] Parts after 'end_to_end': ['808_W032']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\948_M105
# [DEBUG] Parts after 'end_to_end': ['948_M105']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\198_M009
# [DEBUG] Parts after 'end_to_end': ['198_M009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\722_W132
# [DEBUG] Parts after 'end_to_end': ['722_W132']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\827_W035
# [DEBUG] Parts after 'end_to_end': ['827_W035']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\019_W007
# [DEBUG] Parts after 'end_to_end': ['019_W007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\797_M016
# [DEBUG] Parts after 'end_to_end': ['797_M016']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\160_M005
# [DEBUG] Parts after 'end_to_end': ['160_M005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\776_W028
# [DEBUG] Parts after 'end_to_end': ['776_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\346_M023
# [DEBUG] Parts after 'end_to_end': ['346_M023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\061_M118
# [DEBUG] Parts after 'end_to_end': ['061_M118']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\534_W037
# [DEBUG] Parts after 'end_to_end': ['534_W037']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\187_M008
# [DEBUG] Parts after 'end_to_end': ['187_M008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\324_M021
# [DEBUG] Parts after 'end_to_end': ['324_M021']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\362_W005
# [DEBUG] Parts after 'end_to_end': ['362_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\639_M122
# [DEBUG] Parts after 'end_to_end': ['639_M122']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\139_W024
# [DEBUG] Parts after 'end_to_end': ['139_W024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\237_M012
# [DEBUG] Parts after 'end_to_end': ['237_M012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\961_W007
# [DEBUG] Parts after 'end_to_end': ['961_W007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\519_M106
# [DEBUG] Parts after 'end_to_end': ['519_M106']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\446_W024
# [DEBUG] Parts after 'end_to_end': ['446_W024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\162_W028
# [DEBUG] Parts after 'end_to_end': ['162_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\402_W018
# [DEBUG] Parts after 'end_to_end': ['402_W018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\338_W010
# [DEBUG] Parts after 'end_to_end': ['338_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\016_M109
# [DEBUG] Parts after 'end_to_end': ['016_M109']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\719_M007
# [DEBUG] Parts after 'end_to_end': ['719_M007']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\207_W135
# [DEBUG] Parts after 'end_to_end': ['207_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\398_W017
# [DEBUG] Parts after 'end_to_end': ['398_W017']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\822_W135
# [DEBUG] Parts after 'end_to_end': ['822_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\156_W027
# [DEBUG] Parts after 'end_to_end': ['156_W027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\514_M106
# [DEBUG] Parts after 'end_to_end': ['514_M106']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\004_M101
# [DEBUG] Parts after 'end_to_end': ['004_M101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\604_W125
# [DEBUG] Parts after 'end_to_end': ['604_W125']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\067_W005
# [DEBUG] Parts after 'end_to_end': ['067_W005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\938_M034
# [DEBUG] Parts after 'end_to_end': ['938_M034']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\605_M119
# [DEBUG] Parts after 'end_to_end': ['605_M119']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\975_W009
# [DEBUG] Parts after 'end_to_end': ['975_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\091_W017
# [DEBUG] Parts after 'end_to_end': ['091_W017']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\200_W134
# [DEBUG] Parts after 'end_to_end': ['200_W134']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\717_W019
# [DEBUG] Parts after 'end_to_end': ['717_W019']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\787_M014
# [DEBUG] Parts after 'end_to_end': ['787_M014']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\035_M114
# [DEBUG] Parts after 'end_to_end': ['035_M114']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\730_M008
# [DEBUG] Parts after 'end_to_end': ['730_M008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\748_W023
# [DEBUG] Parts after 'end_to_end': ['748_W023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\258_W110
# [DEBUG] Parts after 'end_to_end': ['258_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\262_W110
# [DEBUG] Parts after 'end_to_end': ['262_W110']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\404_M029
# [DEBUG] Parts after 'end_to_end': ['404_M029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\737_M010
# [DEBUG] Parts after 'end_to_end': ['737_M010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\980_W010
# [DEBUG] Parts after 'end_to_end': ['980_W010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\264_W111
# [DEBUG] Parts after 'end_to_end': ['264_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\353_M024
# [DEBUG] Parts after 'end_to_end': ['353_M024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\319_M135
# [DEBUG] Parts after 'end_to_end': ['319_M135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\517_W135
# [DEBUG] Parts after 'end_to_end': ['517_W135']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\753_W024
# [DEBUG] Parts after 'end_to_end': ['753_W024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\163_M005
# [DEBUG] Parts after 'end_to_end': ['163_M005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\449_M138
# [DEBUG] Parts after 'end_to_end': ['449_M138']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\391_W016
# [DEBUG] Parts after 'end_to_end': ['391_W016']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\690_M004
# [DEBUG] Parts after 'end_to_end': ['690_M004']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\647_M123
# [DEBUG] Parts after 'end_to_end': ['647_M123']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\704_W017
# [DEBUG] Parts after 'end_to_end': ['704_W017']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\096_W017
# [DEBUG] Parts after 'end_to_end': ['096_W017']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\830_W036
# [DEBUG] Parts after 'end_to_end': ['830_W036']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\676_W013
# [DEBUG] Parts after 'end_to_end': ['676_W013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\389_W016
# [DEBUG] Parts after 'end_to_end': ['389_W016']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\236_M012
# [DEBUG] Parts after 'end_to_end': ['236_M012']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\485_W031
# [DEBUG] Parts after 'end_to_end': ['485_W031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\407_M029
# [DEBUG] Parts after 'end_to_end': ['407_M029']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\399_W017
# [DEBUG] Parts after 'end_to_end': ['399_W017']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\867_W040
# [DEBUG] Parts after 'end_to_end': ['867_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\422_M031
# [DEBUG] Parts after 'end_to_end': ['422_M031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\089_W016
# [DEBUG] Parts after 'end_to_end': ['089_W016']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\240_W039
# [DEBUG] Parts after 'end_to_end': ['240_W039']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\397_W017
# [DEBUG] Parts after 'end_to_end': ['397_W017']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\689_M004
# [DEBUG] Parts after 'end_to_end': ['689_M004']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\361_M025
# [DEBUG] Parts after 'end_to_end': ['361_M025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\772_W028
# [DEBUG] Parts after 'end_to_end': ['772_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\141_W024
# [DEBUG] Parts after 'end_to_end': ['141_W024']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\873_M025
# [DEBUG] Parts after 'end_to_end': ['873_M025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\811_M133
# [DEBUG] Parts after 'end_to_end': ['811_M133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\271_W111
# [DEBUG] Parts after 'end_to_end': ['271_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\944_W100
# [DEBUG] Parts after 'end_to_end': ['944_W100']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\870_W040
# [DEBUG] Parts after 'end_to_end': ['870_W040']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\034_W009
# [DEBUG] Parts after 'end_to_end': ['034_W009']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\877_M026
# [DEBUG] Parts after 'end_to_end': ['877_M026']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\491_M038
# [DEBUG] Parts after 'end_to_end': ['491_M038']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\812_M133
# [DEBUG] Parts after 'end_to_end': ['812_M133']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\697_M005
# [DEBUG] Parts after 'end_to_end': ['697_M005']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\087_M120
# [DEBUG] Parts after 'end_to_end': ['087_M120']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\618_W101
# [DEBUG] Parts after 'end_to_end': ['618_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\741_M010
# [DEBUG] Parts after 'end_to_end': ['741_M010']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\968_W008
# [DEBUG] Parts after 'end_to_end': ['968_W008']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\154_W026
# [DEBUG] Parts after 'end_to_end': ['154_W026']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\298_M018
# [DEBUG] Parts after 'end_to_end': ['298_M018']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\166_W028
# [DEBUG] Parts after 'end_to_end': ['166_W028']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\438_W023
# [DEBUG] Parts after 'end_to_end': ['438_W023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\857_M023
# [DEBUG] Parts after 'end_to_end': ['857_M023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\230_W136
# [DEBUG] Parts after 'end_to_end': ['230_W136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\855_M023
# [DEBUG] Parts after 'end_to_end': ['855_M023']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\431_M136
# [DEBUG] Parts after 'end_to_end': ['431_M136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\927_M136
# [DEBUG] Parts after 'end_to_end': ['927_M136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\588_W111
# [DEBUG] Parts after 'end_to_end': ['588_W111']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\125_W101
# [DEBUG] Parts after 'end_to_end': ['125_W101']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\380_M027
# [DEBUG] Parts after 'end_to_end': ['380_M027']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\189_W031
# [DEBUG] Parts after 'end_to_end': ['189_W031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\011_M131
# [DEBUG] Parts after 'end_to_end': ['011_M131']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\429_M136
# [DEBUG] Parts after 'end_to_end': ['429_M136']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\915_M031
# [DEBUG] Parts after 'end_to_end': ['915_M031']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\363_M025
# [DEBUG] Parts after 'end_to_end': ['363_M025']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\779_M013
# [DEBUG] Parts after 'end_to_end': ['779_M013']
# [DEBUG] Current root: E:/Research/fake/Cropped_Faces\end_to_end\603_W125
# [DEBUG] Parts after 'end_to_end': ['603_W125']
# [INFO] Total dataset size before shuffling: 1918729
# [INFO] CSV saved to: angry_dataset_real_fake_filtered.csv
# [INFO] Dataset preparation complete.

# %%
def create_cnn_with_attention(input_shape):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(0.001))(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.2)(x)  # Dropout added in convolutional layer
    
    x = Conv2D(64, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.2)(x)
    
    # Attention mechanism
    attention = GlobalAveragePooling2D()(x)
    attention = Dense(64, activation="relu", kernel_regularizer=l2(0.001))(attention)
    attention = Dense(64, activation="sigmoid", kernel_regularizer=l2(0.001))(attention)
    x = Multiply()([x, attention])  # Apply attention

    x = GlobalAveragePooling2D()(x)  # Replace Flatten with GAP
    return inputs, x

# Spatial feature extractor
spatial_input, spatial_features = create_cnn_with_attention((256, 256, 3))  # RGB input

# Temporal feature extractor
temporal_input, temporal_features = create_cnn_with_attention((256, 256, 3))  # Optical flow input

# Align spatial and temporal features
spatial_features = Dense(64, activation="relu", kernel_regularizer=l2(0.001))(spatial_features)
temporal_features = Dense(64, activation="relu", kernel_regularizer=l2(0.001))(temporal_features)

# Combine features
combined = concatenate([spatial_features, temporal_features])

# Fully connected layers with Dropout and regularization
x = Dense(64, activation="relu", kernel_regularizer=l2(0.001))(combined)
x = Dropout(0.5)(x)
x = Dense(32, activation="relu", kernel_regularizer=l2(0.001))(x)
x = Dropout(0.5)(x)
x = Dense(1, activation="sigmoid")(x)  # Binary classification output

# Model
model = Model(inputs=[spatial_input, temporal_input], outputs=x)

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss="binary_crossentropy",
    metrics=["accuracy"],
    run_eagerly=False
)

# Model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 32  896         ['input_3[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 32  896         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32  0          ['batch_normalization_4[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 32  0          ['batch_normalization_6[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 128, 128, 32  0           ['max_pooling2d_4[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 32  0           ['max_pooling2d_6[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 64  18496       ['dropout_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 64  18496       ['dropout_8[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['max_pooling2d_5[0][0]']
#
#  dropout_9 (Dropout)            (None, 64, 64, 64)   0           ['max_pooling2d_7[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 64)          0           ['dropout_7[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_6 (Gl  (None, 64)          0           ['dropout_9[0][0]']
#  obalAveragePooling2D)
#
#  dense_9 (Dense)                (None, 64)           4160        ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_11 (Dense)               (None, 64)           4160        ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 64)           4160        ['dense_9[0][0]']
#
#  dense_12 (Dense)               (None, 64)           4160        ['dense_11[0][0]']
#
#  multiply_2 (Multiply)          (None, 64, 64, 64)   0           ['dropout_7[0][0]',
#                                                                   'dense_10[0][0]']
#
#  multiply_3 (Multiply)          (None, 64, 64, 64)   0           ['dropout_9[0][0]',
#                                                                   'dense_12[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 64)          0           ['multiply_2[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_7 (Gl  (None, 64)          0           ['multiply_3[0][0]']
#  obalAveragePooling2D)
#
#  dense_13 (Dense)               (None, 64)           4160        ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_14 (Dense)               (None, 64)           4160        ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  concatenate_1 (Concatenate)    (None, 128)          0           ['dense_13[0][0]',
#                                                                   'dense_14[0][0]']
#
#  dense_15 (Dense)               (None, 64)           8256        ['concatenate_1[0][0]']
#
#  dropout_10 (Dropout)           (None, 64)           0           ['dense_15[0][0]']
#
#  dense_16 (Dense)               (None, 32)           2080        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 32)           0           ['dense_16[0][0]']
#
#  dense_17 (Dense)               (None, 1)            33          ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 74,881
# Trainable params: 74,497
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data, batch_size, shuffle=True, **kwargs):
        super().__init__(**kwargs)  # Ensure compatibility with Keras Sequence API
        self.data = data
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.data))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __len__(self):
        return len(self.data) // self.batch_size

    def __getitem__(self, idx):
        batch_indexes = self.indexes[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch = [self.data[i] for i in batch_indexes]
        
        spatial_frames = []
        optical_flows = []
        labels = []
        for row in batch:
            spatial_frame_path = row[0]
            optical_flow_path = row[1]
            label = row[2]
    
            spatial_frame = cv2.imread(spatial_frame_path)
            optical_flow = cv2.imread(optical_flow_path)
    
            if spatial_frame is None or optical_flow is None:
                print(f"[WARNING] Missing file(s): {spatial_frame_path} or {optical_flow_path}")
                continue
            
            spatial_frame = cv2.resize(spatial_frame, (256, 256))
            optical_flow = cv2.resize(optical_flow, (256, 256))
    
            spatial_frames.append(spatial_frame / 255.0)
            optical_flows.append(optical_flow / 255.0)
            labels.append(label)
    
        spatial_frames = np.array(spatial_frames, dtype="float32")
        optical_flows = np.array(optical_flows, dtype="float32")
        labels = np.array(labels, dtype="float32").reshape(-1, 1)
        
        spatial_frames = tf.convert_to_tensor(spatial_frames)
        optical_flows = tf.convert_to_tensor(optical_flows)
        labels = tf.convert_to_tensor(labels)
        
        return (spatial_frames, optical_flows), labels

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)
            
    def reset(self):
        """Reset the generator to start from the beginning."""
        self.indexes = np.arange(len(self.data))  # Reset indexes
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
# Load the dataset from CSV
dataset = pd.read_csv("angry_dataset_real_fake_filtered.csv").values

# Split into training and validation sets
train_data, val_data = train_test_split(dataset, test_size=0.2, random_state=42)

# %%
# Example batch test
train_gen = DataGenerator(train_data, batch_size=2)
# Example batch test
inputs, labels_batch = train_gen[0]
spatial_batch, temporal_batch = inputs

# Enforce correct label shape
labels_batch = labels_batch.numpy().reshape(-1, 1)  # Convert to NumPy and reshape
print(f"Spatial batch shape: {spatial_batch.shape}")
print(f"Temporal batch shape: {temporal_batch.shape}")
print(f"Labels batch shape: {labels_batch.shape}")
# Out:
# Spatial batch shape: (2, 256, 256, 3)
# Temporal batch shape: (2, 256, 256, 3)
# Labels batch shape: (2, 1)

# %%
# Load the dataset from the CSV file
dataset = pd.read_csv("angry_dataset_real_fake_filtered.csv").values

# Split into training and validation sets
train_data, val_data = train_test_split(dataset, test_size=0.2, random_state=42)

# Initialize data generators
train_gen = DataGenerator(train_data, batch_size=16)
val_gen = DataGenerator(val_data, batch_size=16)

# Early Stopping Callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",  # Monitor validation loss
    patience=3,          # Stop training after 3 epochs with no improvement
    restore_best_weights=True,  # Restore the best model weights
    verbose=1
)

# Learning Rate Scheduler Callback
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",  # Monitor validation loss
    factor=0.1,          # Reduce learning rate by a factor of 0.1
    patience=2,           # Wait 2 epochs before reducing the learning rate
    min_lr=1e-6, 
    verbose=1
)

# Model Checkpoint Callback to save the best model
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath="angry_expression_model_best.h5",  # Filepath to save the best model
    monitor="val_loss",  # Monitor validation loss
    save_best_only=True,  # Save only when the monitored metric improves
    save_weights_only=False,  # Save the full model
    mode="min",  # Minimize validation loss
    verbose=1  # Print log when saving
)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 32  896         ['input_3[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 32  896         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32  0          ['batch_normalization_4[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 32  0          ['batch_normalization_6[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 128, 128, 32  0           ['max_pooling2d_4[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 32  0           ['max_pooling2d_6[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 64  18496       ['dropout_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 64  18496       ['dropout_8[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['max_pooling2d_5[0][0]']
#
#  dropout_9 (Dropout)            (None, 64, 64, 64)   0           ['max_pooling2d_7[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 64)          0           ['dropout_7[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_6 (Gl  (None, 64)          0           ['dropout_9[0][0]']
#  obalAveragePooling2D)
#
#  dense_9 (Dense)                (None, 64)           4160        ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_11 (Dense)               (None, 64)           4160        ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 64)           4160        ['dense_9[0][0]']
#
#  dense_12 (Dense)               (None, 64)           4160        ['dense_11[0][0]']
#
#  multiply_2 (Multiply)          (None, 64, 64, 64)   0           ['dropout_7[0][0]',
#                                                                   'dense_10[0][0]']
#
#  multiply_3 (Multiply)          (None, 64, 64, 64)   0           ['dropout_9[0][0]',
#                                                                   'dense_12[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 64)          0           ['multiply_2[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_7 (Gl  (None, 64)          0           ['multiply_3[0][0]']
#  obalAveragePooling2D)
#
#  dense_13 (Dense)               (None, 64)           4160        ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_14 (Dense)               (None, 64)           4160        ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  concatenate_1 (Concatenate)    (None, 128)          0           ['dense_13[0][0]',
#                                                                   'dense_14[0][0]']
#
#  dense_15 (Dense)               (None, 64)           8256        ['concatenate_1[0][0]']
#
#  dropout_10 (Dropout)           (None, 64)           0           ['dense_15[0][0]']
#
#  dense_16 (Dense)               (None, 32)           2080        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 32)           0           ['dense_16[0][0]']
#
#  dense_17 (Dense)               (None, 1)            33          ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 74,881
# Trainable params: 74,497
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    verbose=1,  # Set to 1 for detailed logs
    callbacks=[early_stopping, lr_scheduler, model_checkpoint]  # Include callbacks
)

print("[INFO] Model training completed. Best model saved as 'angry_expression_model_best.h5'.")
# Out:
# Epoch 1/10
# 95936/95936 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9941
# Epoch 1: val_loss improved from inf to 0.02980, saving model to angry_expression_model_best.h5
# 95936/95936 [==============================] - 26017s 271ms/step - loss: 0.0759 - accuracy: 0.9941 - val_loss: 0.0298 - val_accuracy: 0.9977 - lr: 1.0000e-04
# Epoch 2/10
# 95936/95936 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9970
# Epoch 2: val_loss did not improve from 0.02980
# 95936/95936 [==============================] - 25786s 269ms/step - loss: 0.0283 - accuracy: 0.9970 - val_loss: 0.1174 - val_accuracy: 0.9644 - lr: 1.0000e-04
# Epoch 3/10
# 95936/95936 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9975
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 3: val_loss did not improve from 0.02980
# 95936/95936 [==============================] - 25856s 270ms/step - loss: 0.0230 - accuracy: 0.9975 - val_loss: 0.0718 - val_accuracy: 0.9810 - lr: 1.0000e-04
# Epoch 4/10
# 95936/95936 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9993Restoring model weights from the end of the best epoch: 1.
#
# Epoch 4: val_loss did not improve from 0.02980
# 95936/95936 [==============================] - 26046s 271ms/step - loss: 0.0155 - accuracy: 0.9993 - val_loss: 0.0500 - val_accuracy: 0.9899 - lr: 1.0000e-05
# Epoch 4: early stopping
# [INFO] Model training completed. Best model saved as 'angry_expression_model_best.h5'.

# %%
# Plot training and validation accuracy
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training vs. Validation Accuracy")
plt.show()

# Plot training and validation loss
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs. Validation Loss")
plt.show()

# %%
val_gen = DataGenerator(val_data, batch_size=64)

# Verify DataGenerator output
(spatial_frames, optical_flows), labels = val_gen[0]
print("Model input shape:", model.input_shape)
print("Spatial Frames Shape:", spatial_frames.shape)
print("Optical Flows Shape:", optical_flows.shape)
print("Labels Shape:", labels.shape)

# Step 3: Generate Predictions
val_predictions = model.predict(val_gen)
val_probabilities = val_predictions.flatten()  # Flatten probabilities to 1D array
val_predictions = (val_probabilities > 0.5).astype(int)  # Convert probabilities to binary predictions

# Step 4: Extract Ground Truth Labels
val_labels = []
# Out:
# Model input shape: [(None, 256, 256, 3), (None, 256, 256, 3)]
# Spatial Frames Shape: (64, 256, 256, 3)
# Optical Flows Shape: (64, 256, 256, 3)
# Labels Shape: (64, 1)
# 5996/5996 [==============================] - 4475s 746ms/step

# %%
val_gen.reset()  # Ensure correct sequence in generator
for _, batch_labels in val_gen:
    val_labels.extend(batch_labels.numpy().flatten())
    if len(val_labels) >= len(val_predictions):
        break
val_labels = np.array(val_labels[:len(val_predictions)])  # Match predictions length

# Step 5: Evaluate Metrics
accuracy = accuracy_score(val_labels, val_predictions)
roc_auc = roc_auc_score(val_labels, val_probabilities)
recall = recall_score(val_labels, val_predictions)
precision = precision_score(val_labels, val_predictions)
precision_vals, recall_vals, thresholds_pr = precision_recall_curve(val_labels, val_probabilities)
pr_auc = auc(recall_vals, precision_vals)

# Print Metrics
print(f"Accuracy Score: {accuracy:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
print(f"Recall Score: {recall:.4f}")
print(f"Precision Score: {precision:.4f}")
print(f"PR AUC Score: {pr_auc:.4f}")

# Step 6: Visualize Metrics
# ROC Curve
fpr, tpr, thresholds = roc_curve(val_labels, val_probabilities)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.grid()
plt.show()

# Precision-Recall Curve
plt.figure()
plt.plot(recall_vals, precision_vals, color='purple', lw=2, label=f"PR Curve (AUC = {pr_auc:.4f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend(loc="upper right")
plt.grid()
plt.show()

# Confusion Matrix
cm = confusion_matrix(val_labels, val_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Real", "Fake"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy Score: 0.5085
# ROC AUC Score: 0.5001
# Recall Score: 0.5659
# Precision Score: 0.5654
# PR AUC Score: 0.5658
