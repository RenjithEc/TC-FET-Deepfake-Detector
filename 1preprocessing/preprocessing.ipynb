# %%
import os
import cv2
import dlib
import numpy as np
import random

# %%
# Paths for input and output
real_videos_dir = "F:/dataset/DeeperForensics-1.0/source_videos"

output_real_faces = "E:/dataset_1/disgust/real"
output_optical_flow = "E:/dataset_1/disgust/optical_flow"
output_edges = "E:/dataset_1/disgust/edges"

# Create directories if not exist
for path in [output_real_faces, output_optical_flow, output_edges]:
    os.makedirs(path, exist_ok=True)

# Load face detector
detector = dlib.get_frontal_face_detector()
predictor_path = "D:/school/Research/TC-FET-Deepfake-Detector/preprocessing/shape_predictor_68_face_landmarks.dat"  
predictor = dlib.shape_predictor(predictor_path)

def compute_dense_optical_flow(prev_frame, next_frame):
    """Computes dense optical flow and converts it into an RGB representation."""
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)

    flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
    magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    
    hsv = np.zeros_like(prev_frame)
    hsv[..., 1] = 255
    hsv[..., 0] = angle * 180 / np.pi / 2
    hsv[..., 2] = cv2.normalize(magnitude, None, 0, 255, cv2.NORM_MINMAX)

    return cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

def extract_edges(frame):
    """Extracts edges from a frame using the Canny edge detection method."""
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)
    return cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

def process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir):
    """Extracts faces and ensures optical flow and edge maps match the face frames."""
    folder_name = os.path.basename(os.path.dirname(video_path))  # Get folder name for naming
    cap = cv2.VideoCapture(video_path)
    ret, prev_frame = cap.read()
    frame_count = 0

    # Counters for statistics
    face_count = 0
    flow_count = 0
    edge_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = detector(gray)

        if faces:  # Only process optical flow and edges if a face is found
            for i, face in enumerate(faces):
                landmarks = predictor(gray, face)
                interocular_distance = landmarks.part(42).x - landmarks.part(39).x

                x, y, w, h = face.left(), face.top(), face.width(), face.height()
                size = 5 * interocular_distance  # Increase bounding box size

                x1 = max(0, x - size)
                y1 = max(0, y - size)
                x2 = min(frame.shape[1], x + size)
                y2 = min(frame.shape[0], y + size)

                face_crop = frame[y1:y2, x1:x2]

                if face_crop.shape[0] > 0 and face_crop.shape[1] > 0:  # Ensure valid cropping
                    face_resized = cv2.resize(face_crop, (299, 299))

                    filename_base = f"{folder_name}_{os.path.basename(video_path)}_frame{frame_count}_face{i}"
                    filename_face = f"{filename_base}.jpg"
                    filename_flow = f"{filename_base}_flow.jpg"
                    filename_edges = f"{filename_base}_edges.jpg"

                    # Save face
                    cv2.imwrite(os.path.join(save_faces_dir, filename_face), face_resized)
                    face_count += 1

                    # Compute optical flow and crop to face region
                    if prev_frame is not None:
                        flow_map = compute_dense_optical_flow(prev_frame, frame)
                        flow_crop = flow_map[y1:y2, x1:x2]
                        if flow_crop.shape[0] > 0 and flow_crop.shape[1] > 0:
                            flow_resized = cv2.resize(flow_crop, (299, 299))
                            cv2.imwrite(os.path.join(save_flow_dir, filename_flow), flow_resized)
                            flow_count += 1

                    # Compute edges and crop to face region
                    edge_map = extract_edges(frame)
                    edge_crop = edge_map[y1:y2, x1:x2]
                    if edge_crop.shape[0] > 0 and edge_crop.shape[1] > 0:
                        edge_resized = cv2.resize(edge_crop, (299, 299))
                        cv2.imwrite(os.path.join(save_edges_dir, filename_edges), edge_resized)
                        edge_count += 1

        prev_frame = frame
        frame_count += 1

    cap.release()

    # Print statistics for this video
    print(f"\n Video Processed: {os.path.basename(video_path)}")
    print(f"    Faces Extracted: {face_count}")
    print(f"    Optical Flow Maps: {flow_count}")
    print(f"    Edge Maps: {edge_count}")
    print("=" * 50)

def traverse_and_process(root_dir, save_faces_dir, save_flow_dir, save_edges_dir, check_disgust=False):
    """
    Traverses folders recursively and collects all video paths.
    Then shuffles them to process in a random order, optionally filtering 
    based on 'disgust', and skips videos that are already processed.
    """
    # Collect all valid video paths
    video_paths = []
    for root, _, files in os.walk(root_dir):
        # Skip if we must only process 'disgust' folders and this folder isn't one
        if check_disgust and "disgust" not in root.lower():
            continue
        
        for file in files:
            if file.endswith(".mp4") or file.endswith(".avi"):
                full_path = os.path.join(root, file)
                video_paths.append(full_path)

    # Shuffle the list of video paths
    random.shuffle(video_paths)

    # Now iterate over videos in random order
    for video_path in video_paths:
        folder_name = os.path.basename(os.path.dirname(video_path))
        file_name = os.path.basename(video_path)

        # Generate expected output filenames
        base_filename = f"{folder_name}_{file_name}_frame"

        # Check if at least one output exists
        processed = any(
            filename.startswith(base_filename)
            for directory in [save_faces_dir, save_flow_dir, save_edges_dir]
            for filename in os.listdir(directory)
        )

        if processed:
            print(f"Skipping {video_path} (already processed)")
            continue

        print(f"Processing {video_path}...")
        process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir)


# Process real videos (source_videos) but only if 'disgust' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, check_disgust=True)

print("\nProcessing complete!")
# Out:
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_down\disgust\camera_rightfront\M123_light_down_disgust_camera_rightfront.mp4...
#
#  Video Processed: M123_light_down_disgust_camera_rightfront.mp4
#     Faces Extracted: 227
#     Optical Flow Maps: 227
#     Edge Maps: 227
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M016\light_left\disgust\camera_left\M016_light_left_disgust_camera_left.mp4...
#
#  Video Processed: M016_light_left_disgust_camera_left.mp4
#     Faces Extracted: 90
#     Optical Flow Maps: 90
#     Edge Maps: 90
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W042\light_left\disgust\camera_leftfront\W042_light_left_disgust_camera_leftfront.mp4...
#
#  Video Processed: W042_light_left_disgust_camera_leftfront.mp4
#     Faces Extracted: 211
#     Optical Flow Maps: 211
#     Edge Maps: 211
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W012\light_left\disgust\camera_up\W012_light_left_disgust_camera_up.mp4...
#
#  Video Processed: W012_light_left_disgust_camera_up.mp4
#     Faces Extracted: 29
#     Optical Flow Maps: 29
#     Edge Maps: 29
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W131\light_leftdown\disgust\camera_rightfront\W131_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W131_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 87
#     Optical Flow Maps: 87
#     Edge Maps: 87
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M137\light_leftdown\disgust\camera_leftfront\M137_light_leftdown_disgust_camera_leftfront.mp4...
#
#  Video Processed: M137_light_leftdown_disgust_camera_leftfront.mp4
#     Faces Extracted: 396
#     Optical Flow Maps: 396
#     Edge Maps: 396
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M018\light_down\disgust\camera_rightfront\M018_light_down_disgust_camera_rightfront.mp4...
#
#  Video Processed: M018_light_down_disgust_camera_rightfront.mp4
#     Faces Extracted: 120
#     Optical Flow Maps: 120
#     Edge Maps: 120
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W039\light_right\disgust\camera_left\W039_light_right_disgust_camera_left.mp4...
#
#  Video Processed: W039_light_right_disgust_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M018\light_leftup\disgust\camera_right\M018_light_leftup_disgust_camera_right.mp4...
#
#  Video Processed: M018_light_leftup_disgust_camera_right.mp4
#     Faces Extracted: 24
#     Optical Flow Maps: 24
#     Edge Maps: 24
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W017\light_right\disgust\camera_rightfront\W017_light_right_disgust_camera_rightfront.mp4...
#
#  Video Processed: W017_light_right_disgust_camera_rightfront.mp4
#     Faces Extracted: 137
#     Optical Flow Maps: 137
#     Edge Maps: 137
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M118\light_down\disgust\camera_leftfront\M118_light_down_disgust_camera_leftfront.mp4...
#
#  Video Processed: M118_light_down_disgust_camera_leftfront.mp4
#     Faces Extracted: 197
#     Optical Flow Maps: 197
#     Edge Maps: 197
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M141\light_leftdown\disgust\camera_front\M141_light_leftdown_disgust_camera_front.mp4...
#
#  Video Processed: M141_light_leftdown_disgust_camera_front.mp4
#     Faces Extracted: 254
#     Optical Flow Maps: 254
#     Edge Maps: 254
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M013\light_rightup\disgust\camera_front\M013_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: M013_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 130
#     Optical Flow Maps: 130
#     Edge Maps: 130
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_right\disgust\camera_down\W027_light_right_disgust_camera_down.mp4...
#
#  Video Processed: W027_light_right_disgust_camera_down.mp4
#     Faces Extracted: 76
#     Optical Flow Maps: 76
#     Edge Maps: 76
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M014\light_down\disgust\camera_right\M014_light_down_disgust_camera_right.mp4...
#
#  Video Processed: M014_light_down_disgust_camera_right.mp4
#     Faces Extracted: 126
#     Optical Flow Maps: 126
#     Edge Maps: 126
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M119\light_right\disgust\camera_leftfront\M119_light_right_disgust_camera_leftfront.mp4...
#
#  Video Processed: M119_light_right_disgust_camera_leftfront.mp4
#     Faces Extracted: 158
#     Optical Flow Maps: 158
#     Edge Maps: 158
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W019\light_down\disgust\camera_leftfront\W019_light_down_disgust_camera_leftfront.mp4...
#
#  Video Processed: W019_light_down_disgust_camera_leftfront.mp4
#     Faces Extracted: 253
#     Optical Flow Maps: 253
#     Edge Maps: 253
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M113\light_rightup\disgust\camera_up\M113_light_rightup_disgust_camera_up.mp4...
#
#  Video Processed: M113_light_rightup_disgust_camera_up.mp4
#     Faces Extracted: 203
#     Optical Flow Maps: 203
#     Edge Maps: 203
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M109\light_leftup\disgust\camera_left\M109_light_leftup_disgust_camera_left.mp4...
#
#  Video Processed: M109_light_leftup_disgust_camera_left.mp4
#     Faces Extracted: 216
#     Optical Flow Maps: 216
#     Edge Maps: 216
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M135\light_rightdown\disgust\camera_left\M135_light_rightdown_disgust_camera_left.mp4...
#
#  Video Processed: M135_light_rightdown_disgust_camera_left.mp4
#     Faces Extracted: 82
#     Optical Flow Maps: 82
#     Edge Maps: 82
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M016\light_leftdown\disgust\camera_right\M016_light_leftdown_disgust_camera_right.mp4...
#
#  Video Processed: M016_light_leftdown_disgust_camera_right.mp4
#     Faces Extracted: 51
#     Optical Flow Maps: 51
#     Edge Maps: 51
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W012\light_leftup\disgust\camera_left\W012_light_leftup_disgust_camera_left.mp4...
#
#  Video Processed: W012_light_leftup_disgust_camera_left.mp4
#     Faces Extracted: 224
#     Optical Flow Maps: 224
#     Edge Maps: 224
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M114\light_leftdown\disgust\camera_rightfront\M114_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: M114_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 314
#     Optical Flow Maps: 314
#     Edge Maps: 314
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_leftup\disgust\camera_rightfront\M021_light_leftup_disgust_camera_rightfront.mp4...
#
#  Video Processed: M021_light_leftup_disgust_camera_rightfront.mp4
#     Faces Extracted: 3
#     Optical Flow Maps: 3
#     Edge Maps: 3
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M034\light_rightup\disgust\camera_down\M034_light_rightup_disgust_camera_down.mp4...
#
#  Video Processed: M034_light_rightup_disgust_camera_down.mp4
#     Faces Extracted: 157
#     Optical Flow Maps: 157
#     Edge Maps: 157
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W024\light_uniform\disgust\camera_left\W024_light_uniform_disgust_camera_left.mp4...
#
#  Video Processed: W024_light_uniform_disgust_camera_left.mp4
#     Faces Extracted: 237
#     Optical Flow Maps: 237
#     Edge Maps: 237
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M135\light_rightup\disgust\camera_left\M135_light_rightup_disgust_camera_left.mp4...
#
#  Video Processed: M135_light_rightup_disgust_camera_left.mp4
#     Faces Extracted: 364
#     Optical Flow Maps: 364
#     Edge Maps: 364
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_up\disgust\camera_left\M120_light_up_disgust_camera_left.mp4...
#
#  Video Processed: M120_light_up_disgust_camera_left.mp4
#     Faces Extracted: 264
#     Optical Flow Maps: 264
#     Edge Maps: 264
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W134\light_down\disgust\camera_leftfront\W134_light_down_disgust_camera_leftfront.mp4...
#
#  Video Processed: W134_light_down_disgust_camera_leftfront.mp4
#     Faces Extracted: 418
#     Optical Flow Maps: 418
#     Edge Maps: 418
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_rightdown\disgust\camera_up\W015_light_rightdown_disgust_camera_up.mp4...
#
#  Video Processed: W015_light_rightdown_disgust_camera_up.mp4
#     Faces Extracted: 35
#     Optical Flow Maps: 35
#     Edge Maps: 35
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M014\light_right\disgust\camera_rightfront\M014_light_right_disgust_camera_rightfront.mp4...
#
#  Video Processed: M014_light_right_disgust_camera_rightfront.mp4
#     Faces Extracted: 144
#     Optical Flow Maps: 144
#     Edge Maps: 144
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M109\light_rightdown\disgust\camera_leftfront\M109_light_rightdown_disgust_camera_leftfront.mp4...
#
#  Video Processed: M109_light_rightdown_disgust_camera_leftfront.mp4
#     Faces Extracted: 221
#     Optical Flow Maps: 221
#     Edge Maps: 221
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_up\disgust\camera_down\M024_light_up_disgust_camera_down.mp4...
#
#  Video Processed: M024_light_up_disgust_camera_down.mp4
#     Faces Extracted: 266
#     Optical Flow Maps: 266
#     Edge Maps: 266
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W037\light_leftdown\disgust\camera_rightfront\W037_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W037_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 89
#     Optical Flow Maps: 89
#     Edge Maps: 89
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W136\light_rightup\disgust\camera_right\W136_light_rightup_disgust_camera_right.mp4...
#
#  Video Processed: W136_light_rightup_disgust_camera_right.mp4
#     Faces Extracted: 344
#     Optical Flow Maps: 344
#     Edge Maps: 344
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M132\light_leftdown\disgust\camera_down\M132_light_leftdown_disgust_camera_down.mp4...
#
#  Video Processed: M132_light_leftdown_disgust_camera_down.mp4
#     Faces Extracted: 68
#     Optical Flow Maps: 68
#     Edge Maps: 68
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_uniform\disgust\camera_left\M120_light_uniform_disgust_camera_left.mp4...
#
#  Video Processed: M120_light_uniform_disgust_camera_left.mp4
#     Faces Extracted: 191
#     Optical Flow Maps: 191
#     Edge Maps: 191
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M019\light_left\disgust\camera_up\M019_light_left_disgust_camera_up.mp4...
#
#  Video Processed: M019_light_left_disgust_camera_up.mp4
#     Faces Extracted: 135
#     Optical Flow Maps: 135
#     Edge Maps: 135
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M019\light_uniform\disgust\camera_down\M019_light_uniform_disgust_camera_down.mp4...
#
#  Video Processed: M019_light_uniform_disgust_camera_down.mp4
#     Faces Extracted: 120
#     Optical Flow Maps: 120
#     Edge Maps: 120
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M135\light_leftup\disgust\camera_front\M135_light_leftup_disgust_camera_front.mp4...
#
#  Video Processed: M135_light_leftup_disgust_camera_front.mp4
#     Faces Extracted: 399
#     Optical Flow Maps: 399
#     Edge Maps: 399
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_up\disgust\camera_leftfront\W023_light_up_disgust_camera_leftfront.mp4...
#
#  Video Processed: W023_light_up_disgust_camera_leftfront.mp4
#     Faces Extracted: 235
#     Optical Flow Maps: 235
#     Edge Maps: 235
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M011\light_rightup\disgust\camera_front\M011_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: M011_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 107
#     Optical Flow Maps: 107
#     Edge Maps: 107
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_rightup\disgust\camera_leftfront\W016_light_rightup_disgust_camera_leftfront.mp4...
#
#  Video Processed: W016_light_rightup_disgust_camera_leftfront.mp4
#     Faces Extracted: 42
#     Optical Flow Maps: 42
#     Edge Maps: 42
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_left\disgust\camera_right\W014_light_left_disgust_camera_right.mp4...
#
#  Video Processed: W014_light_left_disgust_camera_right.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M007\light_down\disgust\camera_up\M007_light_down_disgust_camera_up.mp4...
#
#  Video Processed: M007_light_down_disgust_camera_up.mp4
#     Faces Extracted: 170
#     Optical Flow Maps: 170
#     Edge Maps: 170
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M012\light_left\disgust\camera_front\M012_light_left_disgust_camera_front.mp4...
#
#  Video Processed: M012_light_left_disgust_camera_front.mp4
#     Faces Extracted: 99
#     Optical Flow Maps: 99
#     Edge Maps: 99
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W022\light_right\disgust\camera_rightfront\W022_light_right_disgust_camera_rightfront.mp4...
#
#  Video Processed: W022_light_right_disgust_camera_rightfront.mp4
#     Faces Extracted: 211
#     Optical Flow Maps: 211
#     Edge Maps: 211
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_up\disgust\camera_front\W015_light_up_disgust_camera_front.mp4...
#
#  Video Processed: W015_light_up_disgust_camera_front.mp4
#     Faces Extracted: 295
#     Optical Flow Maps: 295
#     Edge Maps: 295
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_up\disgust\camera_left\M021_light_up_disgust_camera_left.mp4...
#
#  Video Processed: M021_light_up_disgust_camera_left.mp4
#     Faces Extracted: 8
#     Optical Flow Maps: 8
#     Edge Maps: 8
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M034\light_up\disgust\camera_front\M034_light_up_disgust_camera_front.mp4...
#
#  Video Processed: M034_light_up_disgust_camera_front.mp4
#     Faces Extracted: 323
#     Optical Flow Maps: 323
#     Edge Maps: 323
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M109\light_right\disgust\camera_right\M109_light_right_disgust_camera_right.mp4...
#
#  Video Processed: M109_light_right_disgust_camera_right.mp4
#     Faces Extracted: 223
#     Optical Flow Maps: 223
#     Edge Maps: 223
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W008\light_right\disgust\camera_left\W008_light_right_disgust_camera_left.mp4...
#
#  Video Processed: W008_light_right_disgust_camera_left.mp4
#     Faces Extracted: 8
#     Optical Flow Maps: 8
#     Edge Maps: 8
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_left\disgust\camera_right\M024_light_left_disgust_camera_right.mp4...
#
#  Video Processed: M024_light_left_disgust_camera_right.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M119\light_leftdown\disgust\camera_left\M119_light_leftdown_disgust_camera_left.mp4...
#
#  Video Processed: M119_light_leftdown_disgust_camera_left.mp4
#     Faces Extracted: 212
#     Optical Flow Maps: 212
#     Edge Maps: 212
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_right\disgust\camera_rightfront\W027_light_right_disgust_camera_rightfront.mp4...
#
#  Video Processed: W027_light_right_disgust_camera_rightfront.mp4
#     Faces Extracted: 215
#     Optical Flow Maps: 215
#     Edge Maps: 215
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W025\light_leftdown\disgust\camera_up\W025_light_leftdown_disgust_camera_up.mp4...
#
#  Video Processed: W025_light_leftdown_disgust_camera_up.mp4
#     Faces Extracted: 121
#     Optical Flow Maps: 121
#     Edge Maps: 121
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W017\light_down\disgust\camera_front\W017_light_down_disgust_camera_front.mp4...
#
#  Video Processed: W017_light_down_disgust_camera_front.mp4
#     Faces Extracted: 158
#     Optical Flow Maps: 158
#     Edge Maps: 158
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W019\light_up\disgust\camera_down\W019_light_up_disgust_camera_down.mp4...
#
#  Video Processed: W019_light_up_disgust_camera_down.mp4
#     Faces Extracted: 287
#     Optical Flow Maps: 287
#     Edge Maps: 287
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M141\light_uniform\disgust\camera_right\M141_light_uniform_disgust_camera_right.mp4...
#
#  Video Processed: M141_light_uniform_disgust_camera_right.mp4
#     Faces Extracted: 678
#     Optical Flow Maps: 678
#     Edge Maps: 678
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M132\light_up\disgust\camera_leftfront\M132_light_up_disgust_camera_leftfront.mp4...
#
#  Video Processed: M132_light_up_disgust_camera_leftfront.mp4
#     Faces Extracted: 374
#     Optical Flow Maps: 374
#     Edge Maps: 374
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M131\light_down\disgust\camera_right\M131_light_down_disgust_camera_right.mp4...
#
#  Video Processed: M131_light_down_disgust_camera_right.mp4
#     Faces Extracted: 381
#     Optical Flow Maps: 381
#     Edge Maps: 381
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M013\light_right\disgust\camera_leftfront\M013_light_right_disgust_camera_leftfront.mp4...
#
#  Video Processed: M013_light_right_disgust_camera_leftfront.mp4
#     Faces Extracted: 65
#     Optical Flow Maps: 65
#     Edge Maps: 65
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_down\disgust\camera_front\W111_light_down_disgust_camera_front.mp4...
#
#  Video Processed: W111_light_down_disgust_camera_front.mp4
#     Faces Extracted: 248
#     Optical Flow Maps: 248
#     Edge Maps: 248
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_leftdown\disgust\camera_rightfront\W005_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W005_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 206
#     Optical Flow Maps: 206
#     Edge Maps: 206
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M011\light_leftdown\disgust\camera_right\M011_light_leftdown_disgust_camera_right.mp4...
#
#  Video Processed: M011_light_leftdown_disgust_camera_right.mp4
#     Faces Extracted: 33
#     Optical Flow Maps: 33
#     Edge Maps: 33
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M124\light_leftdown\disgust\camera_up\M124_light_leftdown_disgust_camera_up.mp4...
#
#  Video Processed: M124_light_leftdown_disgust_camera_up.mp4
#     Faces Extracted: 79
#     Optical Flow Maps: 79
#     Edge Maps: 79
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_rightdown\disgust\camera_rightfront\W023_light_rightdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W023_light_rightdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 187
#     Optical Flow Maps: 187
#     Edge Maps: 187
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W017\light_uniform\disgust\camera_leftfront\W017_light_uniform_disgust_camera_leftfront.mp4...
#
#  Video Processed: W017_light_uniform_disgust_camera_leftfront.mp4
#     Faces Extracted: 168
#     Optical Flow Maps: 168
#     Edge Maps: 168
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_rightup\disgust\camera_up\M021_light_rightup_disgust_camera_up.mp4...
#
#  Video Processed: M021_light_rightup_disgust_camera_up.mp4
#     Faces Extracted: 151
#     Optical Flow Maps: 151
#     Edge Maps: 151
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M133\light_rightdown\disgust\camera_up\M133_light_rightdown_disgust_camera_up.mp4...
#
#  Video Processed: M133_light_rightdown_disgust_camera_up.mp4
#     Faces Extracted: 64
#     Optical Flow Maps: 64
#     Edge Maps: 64
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M011\light_right\disgust\camera_front\M011_light_right_disgust_camera_front.mp4...
#
#  Video Processed: M011_light_right_disgust_camera_front.mp4
#     Faces Extracted: 94
#     Optical Flow Maps: 94
#     Edge Maps: 94
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W035\light_leftup\disgust\camera_down\W035_light_leftup_disgust_camera_down.mp4...
#
#  Video Processed: W035_light_leftup_disgust_camera_down.mp4
#     Faces Extracted: 192
#     Optical Flow Maps: 192
#     Edge Maps: 192
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W018\light_leftup\disgust\camera_right\W018_light_leftup_disgust_camera_right.mp4...
#
#  Video Processed: W018_light_leftup_disgust_camera_right.mp4
#     Faces Extracted: 37
#     Optical Flow Maps: 37
#     Edge Maps: 37
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M117\light_leftdown\disgust\camera_left\M117_light_leftdown_disgust_camera_left.mp4...
#
#  Video Processed: M117_light_leftdown_disgust_camera_left.mp4
#     Faces Extracted: 270
#     Optical Flow Maps: 270
#     Edge Maps: 270
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M031\light_up\disgust\camera_right\M031_light_up_disgust_camera_right.mp4...
#
#  Video Processed: M031_light_up_disgust_camera_right.mp4
#     Faces Extracted: 281
#     Optical Flow Maps: 281
#     Edge Maps: 281
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W035\light_leftup\disgust\camera_front\W035_light_leftup_disgust_camera_front.mp4...
#
#  Video Processed: W035_light_leftup_disgust_camera_front.mp4
#     Faces Extracted: 210
#     Optical Flow Maps: 210
#     Edge Maps: 210
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W133\light_uniform\disgust\camera_down\W133_light_uniform_disgust_camera_down.mp4...
#
#  Video Processed: W133_light_uniform_disgust_camera_down.mp4
#     Faces Extracted: 392
#     Optical Flow Maps: 392
#     Edge Maps: 392
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M018\light_left\disgust\camera_down\M018_light_left_disgust_camera_down.mp4...
#
#  Video Processed: M018_light_left_disgust_camera_down.mp4
#     Faces Extracted: 136
#     Optical Flow Maps: 136
#     Edge Maps: 136
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W036\light_leftup\disgust\camera_left\W036_light_leftup_disgust_camera_left.mp4...
#
#  Video Processed: W036_light_leftup_disgust_camera_left.mp4
#     Faces Extracted: 191
#     Optical Flow Maps: 191
#     Edge Maps: 191
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_uniform\disgust\camera_rightfront\M120_light_uniform_disgust_camera_rightfront.mp4...
#
#  Video Processed: M120_light_uniform_disgust_camera_rightfront.mp4
#     Faces Extracted: 222
#     Optical Flow Maps: 222
#     Edge Maps: 222
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_up\disgust\camera_front\W027_light_up_disgust_camera_front.mp4...
#
#  Video Processed: W027_light_up_disgust_camera_front.mp4
#     Faces Extracted: 197
#     Optical Flow Maps: 197
#     Edge Maps: 197
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W133\light_uniform\disgust\camera_front\W133_light_uniform_disgust_camera_front.mp4...
#
#  Video Processed: W133_light_uniform_disgust_camera_front.mp4
#     Faces Extracted: 413
#     Optical Flow Maps: 413
#     Edge Maps: 413
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M019\light_leftup\disgust\camera_leftfront\M019_light_leftup_disgust_camera_leftfront.mp4...
#
#  Video Processed: M019_light_leftup_disgust_camera_leftfront.mp4
#     Faces Extracted: 163
#     Optical Flow Maps: 163
#     Edge Maps: 163
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M015\light_leftdown\disgust\camera_right\M015_light_leftdown_disgust_camera_right.mp4...
#
#  Video Processed: M015_light_leftdown_disgust_camera_right.mp4
#     Faces Extracted: 135
#     Optical Flow Maps: 135
#     Edge Maps: 135
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W042\light_leftdown\disgust\camera_rightfront\W042_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W042_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 205
#     Optical Flow Maps: 205
#     Edge Maps: 205
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_rightdown\disgust\camera_down\M136_light_rightdown_disgust_camera_down.mp4...
#
#  Video Processed: M136_light_rightdown_disgust_camera_down.mp4
#     Faces Extracted: 145
#     Optical Flow Maps: 145
#     Edge Maps: 145
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_left\disgust\camera_up\W015_light_left_disgust_camera_up.mp4...
#
#  Video Processed: W015_light_left_disgust_camera_up.mp4
#     Faces Extracted: 4
#     Optical Flow Maps: 4
#     Edge Maps: 4
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M026\light_uniform\disgust\camera_left\M026_light_uniform_disgust_camera_left.mp4...
#
#  Video Processed: M026_light_uniform_disgust_camera_left.mp4
#     Faces Extracted: 152
#     Optical Flow Maps: 152
#     Edge Maps: 152
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_rightdown\disgust\camera_right\M120_light_rightdown_disgust_camera_right.mp4...
#
#  Video Processed: M120_light_rightdown_disgust_camera_right.mp4
#     Faces Extracted: 116
#     Optical Flow Maps: 116
#     Edge Maps: 116
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W028\light_rightdown\disgust\camera_up\W028_light_rightdown_disgust_camera_up.mp4...
#
#  Video Processed: W028_light_rightdown_disgust_camera_up.mp4
#     Faces Extracted: 108
#     Optical Flow Maps: 108
#     Edge Maps: 108
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_left\disgust\camera_leftfront\M120_light_left_disgust_camera_leftfront.mp4...
#
#  Video Processed: M120_light_left_disgust_camera_leftfront.mp4
#     Faces Extracted: 211
#     Optical Flow Maps: 211
#     Edge Maps: 211
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W006\light_left\disgust\camera_up\W006_light_left_disgust_camera_up.mp4...
#
#  Video Processed: W006_light_left_disgust_camera_up.mp4
#     Faces Extracted: 221
#     Optical Flow Maps: 221
#     Edge Maps: 221
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W031\light_rightdown\disgust\camera_rightfront\W031_light_rightdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W031_light_rightdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 169
#     Optical Flow Maps: 169
#     Edge Maps: 169
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_uniform\disgust\camera_rightfront\M123_light_uniform_disgust_camera_rightfront.mp4...
#
#  Video Processed: M123_light_uniform_disgust_camera_rightfront.mp4
#     Faces Extracted: 284
#     Optical Flow Maps: 284
#     Edge Maps: 284
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M140\light_up\disgust\camera_down\M140_light_up_disgust_camera_down.mp4...
#
#  Video Processed: M140_light_up_disgust_camera_down.mp4
#     Faces Extracted: 397
#     Optical Flow Maps: 397
#     Edge Maps: 397
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W019\light_rightdown\disgust\camera_rightfront\W019_light_rightdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W019_light_rightdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 266
#     Optical Flow Maps: 266
#     Edge Maps: 266
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M121\light_right\disgust\camera_leftfront\M121_light_right_disgust_camera_leftfront.mp4...
#
#  Video Processed: M121_light_right_disgust_camera_leftfront.mp4
#     Faces Extracted: 4
#     Optical Flow Maps: 4
#     Edge Maps: 4
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_up\disgust\camera_front\W005_light_up_disgust_camera_front.mp4...
#
#  Video Processed: W005_light_up_disgust_camera_front.mp4
#     Faces Extracted: 160
#     Optical Flow Maps: 160
#     Edge Maps: 160
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M027\light_down\disgust\camera_right\M027_light_down_disgust_camera_right.mp4...
#
#  Video Processed: M027_light_down_disgust_camera_right.mp4
#     Faces Extracted: 133
#     Optical Flow Maps: 133
#     Edge Maps: 133
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_down\disgust\camera_rightfront\M030_light_down_disgust_camera_rightfront.mp4...
#
#  Video Processed: M030_light_down_disgust_camera_rightfront.mp4
#     Faces Extracted: 202
#     Optical Flow Maps: 202
#     Edge Maps: 202
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_left\disgust\camera_up\W111_light_left_disgust_camera_up.mp4...
#
#  Video Processed: W111_light_left_disgust_camera_up.mp4
#     Faces Extracted: 5
#     Optical Flow Maps: 5
#     Edge Maps: 5
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M115\light_rightup\disgust\camera_left\M115_light_rightup_disgust_camera_left.mp4...
#
#  Video Processed: M115_light_rightup_disgust_camera_left.mp4
#     Faces Extracted: 1
#     Optical Flow Maps: 1
#     Edge Maps: 1
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W116\light_left\disgust\camera_rightfront\W116_light_left_disgust_camera_rightfront.mp4...
#
#  Video Processed: W116_light_left_disgust_camera_rightfront.mp4
#     Faces Extracted: 195
#     Optical Flow Maps: 195
#     Edge Maps: 195
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_rightdown\disgust\camera_right\W014_light_rightdown_disgust_camera_right.mp4...
#
#  Video Processed: W014_light_rightdown_disgust_camera_right.mp4
#     Faces Extracted: 184
#     Optical Flow Maps: 184
#     Edge Maps: 184
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W101\light_leftdown\disgust\camera_right\W101_light_leftdown_disgust_camera_right.mp4...
#
#  Video Processed: W101_light_leftdown_disgust_camera_right.mp4
#     Faces Extracted: 138
#     Optical Flow Maps: 138
#     Edge Maps: 138
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M028\light_up\disgust\camera_up\M028_light_up_disgust_camera_up.mp4...
#
#  Video Processed: M028_light_up_disgust_camera_up.mp4
#     Faces Extracted: 215
#     Optical Flow Maps: 215
#     Edge Maps: 215
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W135\light_leftup\disgust\camera_down\W135_light_leftup_disgust_camera_down.mp4...
#
#  Video Processed: W135_light_leftup_disgust_camera_down.mp4
#     Faces Extracted: 4
#     Optical Flow Maps: 4
#     Edge Maps: 4
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M119\light_rightup\disgust\camera_rightfront\M119_light_rightup_disgust_camera_rightfront.mp4...
#
#  Video Processed: M119_light_rightup_disgust_camera_rightfront.mp4
#     Faces Extracted: 209
#     Optical Flow Maps: 209
#     Edge Maps: 209
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W135\light_leftdown\disgust\camera_rightfront\W135_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W135_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 235
#     Optical Flow Maps: 235
#     Edge Maps: 235
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M135\light_right\disgust\camera_front\M135_light_right_disgust_camera_front.mp4...
#
#  Video Processed: M135_light_right_disgust_camera_front.mp4
#     Faces Extracted: 410
#     Optical Flow Maps: 410
#     Edge Maps: 410
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W136\light_up\disgust\camera_left\W136_light_up_disgust_camera_left.mp4...
#
#  Video Processed: W136_light_up_disgust_camera_left.mp4
#     Faces Extracted: 380
#     Optical Flow Maps: 380
#     Edge Maps: 380
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W025\light_uniform\disgust\camera_leftfront\W025_light_uniform_disgust_camera_leftfront.mp4...
#
#  Video Processed: W025_light_uniform_disgust_camera_leftfront.mp4
#     Faces Extracted: 193
#     Optical Flow Maps: 193
#     Edge Maps: 193
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W032\light_uniform\disgust\camera_left\W032_light_uniform_disgust_camera_left.mp4...
#
#  Video Processed: W032_light_uniform_disgust_camera_left.mp4
#     Faces Extracted: 167
#     Optical Flow Maps: 167
#     Edge Maps: 167
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M039\light_rightup\disgust\camera_rightfront\M039_light_rightup_disgust_camera_rightfront.mp4...
#
#  Video Processed: M039_light_rightup_disgust_camera_rightfront.mp4
#     Faces Extracted: 183
#     Optical Flow Maps: 183
#     Edge Maps: 183
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W029\light_leftdown\disgust\camera_front\W029_light_leftdown_disgust_camera_front.mp4...
#
#  Video Processed: W029_light_leftdown_disgust_camera_front.mp4
#     Faces Extracted: 207
#     Optical Flow Maps: 207
#     Edge Maps: 207
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M122\light_leftdown\disgust\camera_rightfront\M122_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: M122_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 3
#     Optical Flow Maps: 3
#     Edge Maps: 3
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M141\light_down\disgust\camera_rightfront\M141_light_down_disgust_camera_rightfront.mp4...
#
#  Video Processed: M141_light_down_disgust_camera_rightfront.mp4
#     Faces Extracted: 442
#     Optical Flow Maps: 442
#     Edge Maps: 442
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W131\light_down\disgust\camera_leftfront\W131_light_down_disgust_camera_leftfront.mp4...
#
#  Video Processed: W131_light_down_disgust_camera_leftfront.mp4
#     Faces Extracted: 399
#     Optical Flow Maps: 399
#     Edge Maps: 399
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M005\light_left\disgust\camera_rightfront\M005_light_left_disgust_camera_rightfront.mp4...
#
#  Video Processed: M005_light_left_disgust_camera_rightfront.mp4
#     Faces Extracted: 174
#     Optical Flow Maps: 174
#     Edge Maps: 174
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W132\light_rightup\disgust\camera_up\W132_light_rightup_disgust_camera_up.mp4...
#
#  Video Processed: W132_light_rightup_disgust_camera_up.mp4
#     Faces Extracted: 469
#     Optical Flow Maps: 469
#     Edge Maps: 469
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_rightdown\disgust\camera_up\M024_light_rightdown_disgust_camera_up.mp4...
#
#  Video Processed: M024_light_rightdown_disgust_camera_up.mp4
#     Faces Extracted: 184
#     Optical Flow Maps: 184
#     Edge Maps: 184
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M019\light_up\disgust\camera_right\M019_light_up_disgust_camera_right.mp4...
#
#  Video Processed: M019_light_up_disgust_camera_right.mp4
#     Faces Extracted: 115
#     Optical Flow Maps: 115
#     Edge Maps: 115
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_leftup\disgust\camera_leftfront\W112_light_leftup_disgust_camera_leftfront.mp4...
#
#  Video Processed: W112_light_leftup_disgust_camera_leftfront.mp4
#     Faces Extracted: 181
#     Optical Flow Maps: 181
#     Edge Maps: 181
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W008\light_rightup\disgust\camera_front\W008_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: W008_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 137
#     Optical Flow Maps: 137
#     Edge Maps: 137
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W042\light_down\disgust\camera_rightfront\W042_light_down_disgust_camera_rightfront.mp4...
#
#  Video Processed: W042_light_down_disgust_camera_rightfront.mp4
#     Faces Extracted: 263
#     Optical Flow Maps: 263
#     Edge Maps: 263
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M031\light_rightdown\disgust\camera_leftfront\M031_light_rightdown_disgust_camera_leftfront.mp4...
#
#  Video Processed: M031_light_rightdown_disgust_camera_leftfront.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_up\disgust\camera_right\W009_light_up_disgust_camera_right.mp4...
#
#  Video Processed: W009_light_up_disgust_camera_right.mp4
#     Faces Extracted: 297
#     Optical Flow Maps: 297
#     Edge Maps: 297
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M025\light_down\disgust\camera_left\M025_light_down_disgust_camera_left.mp4...
#
#  Video Processed: M025_light_down_disgust_camera_left.mp4
#     Faces Extracted: 22
#     Optical Flow Maps: 22
#     Edge Maps: 22
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W132\light_uniform\disgust\camera_left\W132_light_uniform_disgust_camera_left.mp4...
#
#  Video Processed: W132_light_uniform_disgust_camera_left.mp4
#     Faces Extracted: 330
#     Optical Flow Maps: 330
#     Edge Maps: 330
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W041\light_leftup\disgust\camera_leftfront\W041_light_leftup_disgust_camera_leftfront.mp4...
#
#  Video Processed: W041_light_leftup_disgust_camera_leftfront.mp4
#     Faces Extracted: 172
#     Optical Flow Maps: 172
#     Edge Maps: 172
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W024\light_rightup\disgust\camera_up\W024_light_rightup_disgust_camera_up.mp4...
#
#  Video Processed: W024_light_rightup_disgust_camera_up.mp4
#     Faces Extracted: 198
#     Optical Flow Maps: 198
#     Edge Maps: 198
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_leftup\disgust\camera_front\W015_light_leftup_disgust_camera_front.mp4...
#
#  Video Processed: W015_light_leftup_disgust_camera_front.mp4
#     Faces Extracted: 310
#     Optical Flow Maps: 310
#     Edge Maps: 310
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_uniform\disgust\camera_up\M004_light_uniform_disgust_camera_up.mp4...
#
#  Video Processed: M004_light_uniform_disgust_camera_up.mp4
#     Faces Extracted: 143
#     Optical Flow Maps: 143
#     Edge Maps: 143
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_leftup\disgust\camera_left\M004_light_leftup_disgust_camera_left.mp4...
#
#  Video Processed: M004_light_leftup_disgust_camera_left.mp4
#     Faces Extracted: 143
#     Optical Flow Maps: 143
#     Edge Maps: 143
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M015\light_rightup\disgust\camera_front\M015_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: M015_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 211
#     Optical Flow Maps: 211
#     Edge Maps: 211
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M134\light_rightup\disgust\camera_left\M134_light_rightup_disgust_camera_left.mp4...
#
#  Video Processed: M134_light_rightup_disgust_camera_left.mp4
#     Faces Extracted: 41
#     Optical Flow Maps: 41
#     Edge Maps: 41
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M115\light_uniform\disgust\camera_left\M115_light_uniform_disgust_camera_left.mp4...
#
#  Video Processed: M115_light_uniform_disgust_camera_left.mp4
#     Faces Extracted: 352
#     Optical Flow Maps: 352
#     Edge Maps: 352
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_rightdown\disgust\camera_up\M120_light_rightdown_disgust_camera_up.mp4...
#
#  Video Processed: M120_light_rightdown_disgust_camera_up.mp4
#     Faces Extracted: 17
#     Optical Flow Maps: 17
#     Edge Maps: 17
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W008\light_leftup\disgust\camera_front\W008_light_leftup_disgust_camera_front.mp4...
#
#  Video Processed: W008_light_leftup_disgust_camera_front.mp4
#     Faces Extracted: 156
#     Optical Flow Maps: 156
#     Edge Maps: 156
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W134\light_leftup\disgust\camera_left\W134_light_leftup_disgust_camera_left.mp4...
#
#  Video Processed: W134_light_leftup_disgust_camera_left.mp4
#     Faces Extracted: 382
#     Optical Flow Maps: 382
#     Edge Maps: 382
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M132\light_right\disgust\camera_rightfront\M132_light_right_disgust_camera_rightfront.mp4...
#
#  Video Processed: M132_light_right_disgust_camera_rightfront.mp4
#     Faces Extracted: 409
#     Optical Flow Maps: 409
#     Edge Maps: 409
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_rightdown\disgust\camera_up\W023_light_rightdown_disgust_camera_up.mp4...
#
#  Video Processed: W023_light_rightdown_disgust_camera_up.mp4
#     Faces Extracted: 187
#     Optical Flow Maps: 187
#     Edge Maps: 187
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W132\light_uniform\disgust\camera_rightfront\W132_light_uniform_disgust_camera_rightfront.mp4...
#
#  Video Processed: W132_light_uniform_disgust_camera_rightfront.mp4
#     Faces Extracted: 394
#     Optical Flow Maps: 394
#     Edge Maps: 394
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M009\light_right\disgust\camera_left\M009_light_right_disgust_camera_left.mp4...
#
#  Video Processed: M009_light_right_disgust_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_uniform\disgust\camera_up\W027_light_uniform_disgust_camera_up.mp4...
#
#  Video Processed: W027_light_uniform_disgust_camera_up.mp4
#     Faces Extracted: 123
#     Optical Flow Maps: 123
#     Edge Maps: 123
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M012\light_rightdown\disgust\camera_up\M012_light_rightdown_disgust_camera_up.mp4...
#
#  Video Processed: M012_light_rightdown_disgust_camera_up.mp4
#     Faces Extracted: 83
#     Optical Flow Maps: 83
#     Edge Maps: 83
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W012\light_leftup\disgust\camera_rightfront\W012_light_leftup_disgust_camera_rightfront.mp4...
#
#  Video Processed: W012_light_leftup_disgust_camera_rightfront.mp4
#     Faces Extracted: 224
#     Optical Flow Maps: 224
#     Edge Maps: 224
# ==================================================
# ...
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_uniform\disgust\camera_right\M030_light_uniform_disgust_camera_right.mp4...
#
#  Video Processed: M030_light_uniform_disgust_camera_right.mp4
#     Faces Extracted: 137
#     Optical Flow Maps: 137
#     Edge Maps: 137
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_up\disgust\camera_left\W112_light_up_disgust_camera_left.mp4...
#
#  Video Processed: W112_light_up_disgust_camera_left.mp4
#     Faces Extracted: 186
#     Optical Flow Maps: 186
#     Edge Maps: 186
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M039\light_up\disgust\camera_left\M039_light_up_disgust_camera_left.mp4...
#
#  Video Processed: M039_light_up_disgust_camera_left.mp4
#     Faces Extracted: 176
#     Optical Flow Maps: 176
#     Edge Maps: 176
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W017\light_rightup\disgust\camera_front\W017_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: W017_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 158
#     Optical Flow Maps: 158
#     Edge Maps: 158
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W026\light_uniform\disgust\camera_left\W026_light_uniform_disgust_camera_left.mp4...
#
#  Video Processed: W026_light_uniform_disgust_camera_left.mp4
#     Faces Extracted: 139
#     Optical Flow Maps: 139
#     Edge Maps: 139
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W116\light_up\disgust\camera_rightfront\W116_light_up_disgust_camera_rightfront.mp4...
#
#  Video Processed: W116_light_up_disgust_camera_rightfront.mp4
#     Faces Extracted: 282
#     Optical Flow Maps: 282
#     Edge Maps: 282
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W040\light_left\disgust\camera_leftfront\W040_light_left_disgust_camera_leftfront.mp4...
#
#  Video Processed: W040_light_left_disgust_camera_leftfront.mp4
#     Faces Extracted: 215
#     Optical Flow Maps: 215
#     Edge Maps: 215
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M011\light_leftdown\disgust\camera_up\M011_light_leftdown_disgust_camera_up.mp4...
#
#  Video Processed: M011_light_leftdown_disgust_camera_up.mp4
#     Faces Extracted: 55
#     Optical Flow Maps: 55
#     Edge Maps: 55
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M010\light_down\disgust\camera_up\M010_light_down_disgust_camera_up.mp4...
#
#  Video Processed: M010_light_down_disgust_camera_up.mp4
#     Faces Extracted: 206
#     Optical Flow Maps: 206
#     Edge Maps: 206
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M012\light_up\disgust\camera_leftfront\M012_light_up_disgust_camera_leftfront.mp4...
#
#  Video Processed: M012_light_up_disgust_camera_leftfront.mp4
#     Faces Extracted: 116
#     Optical Flow Maps: 116
#     Edge Maps: 116
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W041\light_leftdown\disgust\camera_leftfront\W041_light_leftdown_disgust_camera_leftfront.mp4...
#
#  Video Processed: W041_light_leftdown_disgust_camera_leftfront.mp4
#     Faces Extracted: 183
#     Optical Flow Maps: 183
#     Edge Maps: 183
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W116\light_up\disgust\camera_up\W116_light_up_disgust_camera_up.mp4...
#
#  Video Processed: W116_light_up_disgust_camera_up.mp4
#     Faces Extracted: 282
#     Optical Flow Maps: 282
#     Edge Maps: 282
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_leftup\disgust\camera_up\W112_light_leftup_disgust_camera_up.mp4...
#
#  Video Processed: W112_light_leftup_disgust_camera_up.mp4
#     Faces Extracted: 181
#     Optical Flow Maps: 181
#     Edge Maps: 181
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M115\light_rightup\disgust\camera_right\M115_light_rightup_disgust_camera_right.mp4...
#
#  Video Processed: M115_light_rightup_disgust_camera_right.mp4
#     Faces Extracted: 207
#     Optical Flow Maps: 207
#     Edge Maps: 207
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M122\light_down\disgust\camera_down\M122_light_down_disgust_camera_down.mp4...
#
#  Video Processed: M122_light_down_disgust_camera_down.mp4
#     Faces Extracted: 229
#     Optical Flow Maps: 229
#     Edge Maps: 229
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M038\light_up\disgust\camera_front\M038_light_up_disgust_camera_front.mp4...
#
#  Video Processed: M038_light_up_disgust_camera_front.mp4
#     Faces Extracted: 210
#     Optical Flow Maps: 210
#     Edge Maps: 210
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M027\light_right\disgust\camera_left\M027_light_right_disgust_camera_left.mp4...
#
#  Video Processed: M027_light_right_disgust_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M141\light_leftdown\disgust\camera_down\M141_light_leftdown_disgust_camera_down.mp4...
#
#  Video Processed: M141_light_leftdown_disgust_camera_down.mp4
#     Faces Extracted: 293
#     Optical Flow Maps: 293
#     Edge Maps: 293
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_down\disgust\camera_leftfront\W014_light_down_disgust_camera_leftfront.mp4...
#
#  Video Processed: W014_light_down_disgust_camera_leftfront.mp4
#     Faces Extracted: 154
#     Optical Flow Maps: 154
#     Edge Maps: 154
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M121\light_leftup\disgust\camera_rightfront\M121_light_leftup_disgust_camera_rightfront.mp4...
#
#  Video Processed: M121_light_leftup_disgust_camera_rightfront.mp4
#     Faces Extracted: 217
#     Optical Flow Maps: 217
#     Edge Maps: 217
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_down\disgust\camera_front\W023_light_down_disgust_camera_front.mp4...
#
#  Video Processed: W023_light_down_disgust_camera_front.mp4
#     Faces Extracted: 150
#     Optical Flow Maps: 150
#     Edge Maps: 150
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M117\light_up\disgust\camera_up\M117_light_up_disgust_camera_up.mp4...
#
#  Video Processed: M117_light_up_disgust_camera_up.mp4
#     Faces Extracted: 246
#     Optical Flow Maps: 246
#     Edge Maps: 246
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M018\light_left\disgust\camera_rightfront\M018_light_left_disgust_camera_rightfront.mp4...
#
#  Video Processed: M018_light_left_disgust_camera_rightfront.mp4
#     Faces Extracted: 11
#     Optical Flow Maps: 11
#     Edge Maps: 11
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M109\light_down\disgust\camera_up\M109_light_down_disgust_camera_up.mp4...
#
#  Video Processed: M109_light_down_disgust_camera_up.mp4
#     Faces Extracted: 236
#     Optical Flow Maps: 236
#     Edge Maps: 236
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W132\light_up\disgust\camera_front\W132_light_up_disgust_camera_front.mp4...
#
#  Video Processed: W132_light_up_disgust_camera_front.mp4
#     Faces Extracted: 381
#     Optical Flow Maps: 381
#     Edge Maps: 381
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W040\light_down\disgust\camera_down\W040_light_down_disgust_camera_down.mp4...
#
#  Video Processed: W040_light_down_disgust_camera_down.mp4
#     Faces Extracted: 220
#     Optical Flow Maps: 220
#     Edge Maps: 220
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_up\disgust\camera_down\W016_light_up_disgust_camera_down.mp4...
#
#  Video Processed: W016_light_up_disgust_camera_down.mp4
#     Faces Extracted: 218
#     Optical Flow Maps: 218
#     Edge Maps: 218
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M015\light_rightdown\disgust\camera_left\M015_light_rightdown_disgust_camera_left.mp4...
#
#  Video Processed: M015_light_rightdown_disgust_camera_left.mp4
#     Faces Extracted: 26
#     Optical Flow Maps: 26
#     Edge Maps: 26
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M115\light_uniform\disgust\camera_rightfront\M115_light_uniform_disgust_camera_rightfront.mp4...
#
#  Video Processed: M115_light_uniform_disgust_camera_rightfront.mp4
#     Faces Extracted: 317
#     Optical Flow Maps: 317
#     Edge Maps: 317
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W134\light_down\disgust\camera_left\W134_light_down_disgust_camera_left.mp4...
#
#  Video Processed: W134_light_down_disgust_camera_left.mp4
#     Faces Extracted: 376
#     Optical Flow Maps: 376
#     Edge Maps: 376
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M109\light_rightup\disgust\camera_front\M109_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: M109_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 233
#     Optical Flow Maps: 233
#     Edge Maps: 233
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W031\light_rightup\disgust\camera_down\W031_light_rightup_disgust_camera_down.mp4...
#
#  Video Processed: W031_light_rightup_disgust_camera_down.mp4
#     Faces Extracted: 195
#     Optical Flow Maps: 195
#     Edge Maps: 195
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M008\light_uniform\disgust\camera_down\M008_light_uniform_disgust_camera_down.mp4...
#
#  Video Processed: M008_light_uniform_disgust_camera_down.mp4
#     Faces Extracted: 172
#     Optical Flow Maps: 172
#     Edge Maps: 172
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W040\light_right\disgust\camera_down\W040_light_right_disgust_camera_down.mp4...
#
#  Video Processed: W040_light_right_disgust_camera_down.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_rightdown\disgust\camera_down\W112_light_rightdown_disgust_camera_down.mp4...
#
#  Video Processed: W112_light_rightdown_disgust_camera_down.mp4
#     Faces Extracted: 220
#     Optical Flow Maps: 220
#     Edge Maps: 220
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M007\light_up\disgust\camera_leftfront\M007_light_up_disgust_camera_leftfront.mp4...
#
#  Video Processed: M007_light_up_disgust_camera_leftfront.mp4
#     Faces Extracted: 180
#     Optical Flow Maps: 180
#     Edge Maps: 180
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_up\disgust\camera_up\M004_light_up_disgust_camera_up.mp4...
#
#  Video Processed: M004_light_up_disgust_camera_up.mp4
#     Faces Extracted: 261
#     Optical Flow Maps: 261
#     Edge Maps: 261
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M005\light_leftup\disgust\camera_down\M005_light_leftup_disgust_camera_down.mp4...
#
#  Video Processed: M005_light_leftup_disgust_camera_down.mp4
#     Faces Extracted: 112
#     Optical Flow Maps: 112
#     Edge Maps: 112
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W021\light_leftup\disgust\camera_down\W021_light_leftup_disgust_camera_down.mp4...
#
#  Video Processed: W021_light_leftup_disgust_camera_down.mp4
#     Faces Extracted: 291
#     Optical Flow Maps: 291
#     Edge Maps: 291
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W133\light_leftdown\disgust\camera_rightfront\W133_light_leftdown_disgust_camera_rightfront.mp4...
#
#  Video Processed: W133_light_leftdown_disgust_camera_rightfront.mp4
#     Faces Extracted: 55
#     Optical Flow Maps: 55
#     Edge Maps: 55
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W013\light_uniform\disgust\camera_down\W013_light_uniform_disgust_camera_down.mp4...
#
#  Video Processed: W013_light_uniform_disgust_camera_down.mp4
#     Faces Extracted: 147
#     Optical Flow Maps: 147
#     Edge Maps: 147
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W025\light_down\disgust\camera_rightfront\W025_light_down_disgust_camera_rightfront.mp4...
#
#  Video Processed: W025_light_down_disgust_camera_rightfront.mp4
#     Faces Extracted: 155
#     Optical Flow Maps: 155
#     Edge Maps: 155
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M028\light_left\disgust\camera_rightfront\M028_light_left_disgust_camera_rightfront.mp4...
#
#  Video Processed: M028_light_left_disgust_camera_rightfront.mp4
#     Faces Extracted: 11
#     Optical Flow Maps: 11
#     Edge Maps: 11
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W025\light_leftup\disgust\camera_down\W025_light_leftup_disgust_camera_down.mp4...
#
#  Video Processed: W025_light_leftup_disgust_camera_down.mp4
#     Faces Extracted: 4
#     Optical Flow Maps: 4
#     Edge Maps: 4
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M009\light_rightup\disgust\camera_front\M009_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: M009_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 141
#     Optical Flow Maps: 141
#     Edge Maps: 141
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M118\light_down\disgust\camera_left\M118_light_down_disgust_camera_left.mp4...
#
#  Video Processed: M118_light_down_disgust_camera_left.mp4
#     Faces Extracted: 192
#     Optical Flow Maps: 192
#     Edge Maps: 192
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W042\light_leftup\disgust\camera_front\W042_light_leftup_disgust_camera_front.mp4...
#
#  Video Processed: W042_light_leftup_disgust_camera_front.mp4
#     Faces Extracted: 173
#     Optical Flow Maps: 173
#     Edge Maps: 173
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_left\disgust\camera_front\M024_light_left_disgust_camera_front.mp4...
#
#  Video Processed: M024_light_left_disgust_camera_front.mp4
#     Faces Extracted: 255
#     Optical Flow Maps: 255
#     Edge Maps: 255
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_uniform\disgust\camera_down\M004_light_uniform_disgust_camera_down.mp4...
#
#  Video Processed: M004_light_uniform_disgust_camera_down.mp4
#     Faces Extracted: 289
#     Optical Flow Maps: 289
#     Edge Maps: 289
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M133\light_right\disgust\camera_right\M133_light_right_disgust_camera_right.mp4...
