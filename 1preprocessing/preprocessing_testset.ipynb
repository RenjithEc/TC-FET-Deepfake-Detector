# %%
import os
import cv2
import dlib
import numpy as np
import random

# %%
# Paths for input and output
real_videos_dir = "F:/dataset/DeeperForensics-1.0/source_videos"
fake_videos_dir = "F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1"

# Define dataset paths for real emotions
check_real_faces_sad = "E:/dataset_1/sad/real"
check_optical_flow_sad = "E:/dataset_1/sad/optical_flow" 
check_edges_sad = "E:/dataset_1/sad/edges"

check_real_faces_angry = "E:/dataset_1/angry/real"
check_optical_flow_angry = "E:/dataset_1/angry/optical_flow" 
check_edges_angry = "E:/dataset_1/angry/edges"

check_real_faces_contempt = "E:/dataset_1/contempt/real"
check_optical_flow_contempt = "E:/dataset_1/contempt/optical_flow" 
check_edges_contempt = "E:/dataset_1/contempt/edges"

check_real_faces_disgust = "E:/dataset_1/disgust/real"
check_optical_flow_disgust = "E:/dataset_1/disgust/optical_flow" 
check_edges_disgust = "E:/dataset_1/disgust/edges"

check_real_faces_fear = "E:/dataset_1/fear/real"
check_optical_flow_fear = "E:/dataset_1/fear/optical_flow" 
check_edges_fear = "E:/dataset_1/fear/edges"

check_real_faces_happy = "E:/dataset_1/happy/real"
check_optical_flow_happy = "E:/dataset_1/happy/optical_flow" 
check_edges_happy = "E:/dataset_1/happy/edges"

check_real_faces_neutral = "E:/dataset_1/neutral/real"
check_optical_flow_neutral = "E:/dataset_1/neutral/optical_flow"
check_edges_neutral = "E:/dataset_1/neutral/edges"

check_real_faces_surprise = "E:/dataset_1/surprise/real"
check_optical_flow_surprise = "E:/dataset_1/surprise/optical_flow" 
check_edges_surprise = "E:/dataset_1/surprise/edges"

# Define dataset paths for fake images 
check_fake_faces = "E:/dataset_1/happy/fake"
check_fake_optical_flow = "E:/dataset_1/happy/optical_flow"
check_fake_edges = "E:/dataset_1/happy/edges"

#Save paths
output_real_faces = "E:/dataset_1/test_set/real"
output_fake_faces = "E:/dataset_1/test_set/fake"
output_optical_flow = "E:/dataset_1/test_set/optical_flow"
output_edges = "E:/dataset_1/test_set/edges"

# Create directories if not exist
for path in [output_real_faces, output_optical_flow, output_edges, output_fake_faces]:
    os.makedirs(path, exist_ok=True)

# Load face detector
detector = dlib.get_frontal_face_detector()
predictor_path = "D:/school/Research/TC-FET-Deepfake-Detector/1preprocessing/shape_predictor_68_face_landmarks.dat"  
predictor = dlib.shape_predictor(predictor_path)

def compute_dense_optical_flow(prev_frame, next_frame):
    """Computes dense optical flow and converts it into an RGB representation."""
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)

    flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
    magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    
    hsv = np.zeros_like(prev_frame)
    hsv[..., 1] = 255
    hsv[..., 0] = angle * 180 / np.pi / 2
    hsv[..., 2] = cv2.normalize(magnitude, None, 0, 255, cv2.NORM_MINMAX)

    return cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

def extract_edges(frame):
    """Extracts edges from a frame using the Canny edge detection method."""
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)
    return cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

def process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir):
    """Extracts faces and ensures optical flow and edge maps match the face frames."""
    folder_name = os.path.basename(os.path.dirname(video_path))  # Get folder name for naming
    cap = cv2.VideoCapture(video_path)
    ret, prev_frame = cap.read()
    frame_count = 0

    # Counters for statistics
    face_count = 0
    flow_count = 0
    edge_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = detector(gray)

        if faces:  # Only process optical flow and edges if a face is found
            for i, face in enumerate(faces):
                landmarks = predictor(gray, face)
                interocular_distance = landmarks.part(42).x - landmarks.part(39).x

                x, y, w, h = face.left(), face.top(), face.width(), face.height()
                size = 5 * interocular_distance  # Increase bounding box size

                x1 = max(0, x - size)
                y1 = max(0, y - size)
                x2 = min(frame.shape[1], x + size)
                y2 = min(frame.shape[0], y + size)

                face_crop = frame[y1:y2, x1:x2]

                if face_crop.shape[0] > 0 and face_crop.shape[1] > 0:  # Ensure valid cropping
                    face_resized = cv2.resize(face_crop, (299, 299))

                    filename_base = f"{folder_name}_{os.path.basename(video_path)}_frame{frame_count}_face{i}"
                    filename_face = f"{filename_base}.jpg"
                    filename_flow = f"{filename_base}_flow.jpg"
                    filename_edges = f"{filename_base}_edges.jpg"

                    # Save face
                    cv2.imwrite(os.path.join(save_faces_dir, filename_face), face_resized)
                    face_count += 1

                    # Compute optical flow and crop to face region
                    if prev_frame is not None:
                        flow_map = compute_dense_optical_flow(prev_frame, frame)
                        flow_crop = flow_map[y1:y2, x1:x2]
                        if flow_crop.shape[0] > 0 and flow_crop.shape[1] > 0:
                            flow_resized = cv2.resize(flow_crop, (299, 299))
                            cv2.imwrite(os.path.join(save_flow_dir, filename_flow), flow_resized)
                            flow_count += 1

                    # Compute edges and crop to face region
                    edge_map = extract_edges(frame)
                    edge_crop = edge_map[y1:y2, x1:x2]
                    if edge_crop.shape[0] > 0 and edge_crop.shape[1] > 0:
                        edge_resized = cv2.resize(edge_crop, (299, 299))
                        cv2.imwrite(os.path.join(save_edges_dir, filename_edges), edge_resized)
                        edge_count += 1

        prev_frame = frame
        frame_count += 1

    cap.release()

    # Print statistics for this video
    print(f"\n Video Processed: {os.path.basename(video_path)}")
    print(f"    Faces Extracted: {face_count}")
    print(f"    Optical Flow Maps: {flow_count}")
    print(f"    Edge Maps: {edge_count}")
    print("=" * 50)

def traverse_and_process(root_dir, save_faces_dir, save_flow_dir, save_edges_dir, filter, 
                         check_faces_dir, check_flow_dir, check_edges_dir, n, check=False):
    """
    Traverses folders recursively and collects all video paths.
    Then shuffles them to process in a random order, optionally filtering 
    based on 'disgust', and skips videos that are already processed.
    Processes up to n videos.
    """
    # Collect all valid video paths
    video_paths = []
    for root, _, files in os.walk(root_dir):
        # Skip if we must only process 'disgust' folders and this folder isn't one
        if check and filter not in root.lower():
            continue
        
        for file in files:
            if file.endswith(".mp4") or file.endswith(".avi"):
                full_path = os.path.join(root, file)
                video_paths.append(full_path)

    # Shuffle the list of video paths
    random.shuffle(video_paths)

    # Initialize counter for processed videos
    processed_count = 0

    # Now iterate over videos in random order
    for video_path in video_paths:
        # Break out of the loop if we've processed n videos
        if processed_count >= n:
            print(f"Processed {n} videos, stopping further processing.")
            break

        folder_name = os.path.basename(os.path.dirname(video_path))
        file_name = os.path.basename(video_path)

        # Generate expected output filenames
        base_filename = f"{folder_name}_{file_name}_frame"

        # Check if at least one output exists
        processed = any(
            filename.startswith(base_filename)
            for directory in [check_faces_dir, check_flow_dir, check_edges_dir]
            for filename in os.listdir(directory)
        )

        if processed:
            print(f"Skipping {video_path} (already processed)")
            continue

        print(f"Processing {video_path}...")
        process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir)
        processed_count += 1


# Process real videos (source_videos) but only if 'angry' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "angry", check_real_faces_angry, check_optical_flow_angry, check_edges_angry, 20, check=True)
# Process real videos (source_videos) but only if 'happy' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "happy", check_real_faces_happy, check_optical_flow_happy, check_edges_happy, 20, check=True)
# Process real videos (source_videos) but only if 'sad' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "sad", check_real_faces_sad, check_optical_flow_sad, check_edges_sad, 20, check=True)
# Process real videos (source_videos) but only if 'disgust' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "disgust", check_real_faces_disgust, check_optical_flow_disgust, check_edges_disgust, 20, check=True)
# Process real videos (source_videos) but only if 'neutral' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "neutral", check_real_faces_neutral, check_optical_flow_neutral, check_edges_neutral, 20, check=True)
# Process real videos (source_videos) but only if 'surprise' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "surprise", check_real_faces_surprise, check_optical_flow_surprise, check_edges_surprise, 20, check=True)
# Process real videos (source_videos) but only if 'contempt' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "contempt", check_real_faces_contempt, check_optical_flow_contempt, check_edges_contempt, 20, check=True)
# Process real videos (source_videos) but only if 'fear' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, "fear", check_real_faces_fear, check_optical_flow_fear, check_edges_fear, 20, check=True)
# Process fake videos (manipulated_videos) 
traverse_and_process(fake_videos_dir, output_fake_faces, output_optical_flow, output_edges, "", check_fake_faces, check_fake_optical_flow, check_fake_edges, 160, check=False)

print("\nProcessing complete!")
# Out:
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W135\light_down\angry\camera_leftfront\W135_light_down_angry_camera_leftfront.mp4...
#
#  Video Processed: W135_light_down_angry_camera_leftfront.mp4
#     Faces Extracted: 376
#     Optical Flow Maps: 376
#     Edge Maps: 376
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_left\angry\camera_leftfront\W015_light_left_angry_camera_leftfront.mp4...
#
#  Video Processed: W015_light_left_angry_camera_leftfront.mp4
#     Faces Extracted: 376
#     Optical Flow Maps: 376
#     Edge Maps: 376
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M133\light_leftdown\angry\camera_right\M133_light_leftdown_angry_camera_right.mp4...
#
#  Video Processed: M133_light_leftdown_angry_camera_right.mp4
#     Faces Extracted: 370
#     Optical Flow Maps: 370
#     Edge Maps: 370
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W018\light_down\angry\camera_front\W018_light_down_angry_camera_front.mp4...
#
#  Video Processed: W018_light_down_angry_camera_front.mp4
#     Faces Extracted: 204
#     Optical Flow Maps: 204
#     Edge Maps: 204
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_right\angry\camera_right\M021_light_right_angry_camera_right.mp4...
#
#  Video Processed: M021_light_right_angry_camera_right.mp4
#     Faces Extracted: 4
#     Optical Flow Maps: 4
#     Edge Maps: 4
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M138\light_leftdown\angry\camera_right\M138_light_leftdown_angry_camera_right.mp4...
#
#  Video Processed: M138_light_leftdown_angry_camera_right.mp4
#     Faces Extracted: 348
#     Optical Flow Maps: 348
#     Edge Maps: 348
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W008\light_right\angry\camera_left\W008_light_right_angry_camera_left.mp4...
#
#  Video Processed: W008_light_right_angry_camera_left.mp4
#     Faces Extracted: 1
#     Optical Flow Maps: 1
#     Edge Maps: 1
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M139\light_up\angry\camera_right\M139_light_up_angry_camera_right.mp4...
#
#  Video Processed: M139_light_up_angry_camera_right.mp4
#     Faces Extracted: 418
#     Optical Flow Maps: 418
#     Edge Maps: 418
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W022\light_rightdown\angry\camera_leftfront\W022_light_rightdown_angry_camera_leftfront.mp4...
#
#  Video Processed: W022_light_rightdown_angry_camera_leftfront.mp4
#     Faces Extracted: 193
#     Optical Flow Maps: 193
#     Edge Maps: 193
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M039\light_rightup\angry\camera_down\M039_light_rightup_angry_camera_down.mp4...
#
#  Video Processed: M039_light_rightup_angry_camera_down.mp4
#     Faces Extracted: 202
#     Optical Flow Maps: 202
#     Edge Maps: 202
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W021\light_rightup\angry\camera_right\W021_light_rightup_angry_camera_right.mp4...
#
#  Video Processed: W021_light_rightup_angry_camera_right.mp4
#     Faces Extracted: 226
#     Optical Flow Maps: 226
#     Edge Maps: 226
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M038\light_right\angry\camera_down\M038_light_right_angry_camera_down.mp4...
#
#  Video Processed: M038_light_right_angry_camera_down.mp4
#     Faces Extracted: 143
#     Optical Flow Maps: 143
#     Edge Maps: 143
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_up\angry\camera_up\M024_light_up_angry_camera_up.mp4...
#
#  Video Processed: M024_light_up_angry_camera_up.mp4
#     Faces Extracted: 191
#     Optical Flow Maps: 191
#     Edge Maps: 191
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M010\light_uniform\angry\camera_rightfront\M010_light_uniform_angry_camera_rightfront.mp4...
#
#  Video Processed: M010_light_uniform_angry_camera_rightfront.mp4
#     Faces Extracted: 175
#     Optical Flow Maps: 175
#     Edge Maps: 175
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M109\light_uniform\angry\camera_right\M109_light_uniform_angry_camera_right.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M137\light_left\angry\camera_rightfront\M137_light_left_angry_camera_rightfront.mp4...
#
#  Video Processed: M137_light_left_angry_camera_rightfront.mp4
#     Faces Extracted: 90
#     Optical Flow Maps: 90
#     Edge Maps: 90
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M031\light_uniform\angry\camera_left\M031_light_uniform_angry_camera_left.mp4...
#
#  Video Processed: M031_light_uniform_angry_camera_left.mp4
#     Faces Extracted: 198
#     Optical Flow Maps: 198
#     Edge Maps: 198
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_up\angry\camera_rightfront\M021_light_up_angry_camera_rightfront.mp4...
#
#  Video Processed: M021_light_up_angry_camera_rightfront.mp4
#     Faces Extracted: 136
#     Optical Flow Maps: 136
#     Edge Maps: 136
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M118\light_right\angry\camera_down\M118_light_right_angry_camera_down.mp4...
#
#  Video Processed: M118_light_right_angry_camera_down.mp4
#     Faces Extracted: 144
#     Optical Flow Maps: 144
#     Edge Maps: 144
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\W116\light_down\angry\camera_front\W116_light_down_angry_camera_front.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W031\light_rightdown\angry\camera_rightfront\W031_light_rightdown_angry_camera_rightfront.mp4...
#
#  Video Processed: W031_light_rightdown_angry_camera_rightfront.mp4
#     Faces Extracted: 199
#     Optical Flow Maps: 199
#     Edge Maps: 199
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M034\light_uniform\angry\camera_up\M034_light_uniform_angry_camera_up.mp4...
#
#  Video Processed: M034_light_uniform_angry_camera_up.mp4
#     Faces Extracted: 345
#     Optical Flow Maps: 345
#     Edge Maps: 345
# ==================================================
# Processed 20 videos, stopping further processing.
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_right\happy\camera_front\W014_light_right_happy_camera_front.mp4...
#
#  Video Processed: W014_light_right_happy_camera_front.mp4
#     Faces Extracted: 111
#     Optical Flow Maps: 111
#     Edge Maps: 111
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_rightdown\happy\camera_left\M021_light_rightdown_happy_camera_left.mp4...
#
#  Video Processed: M021_light_rightdown_happy_camera_left.mp4
#     Faces Extracted: 64
#     Optical Flow Maps: 64
#     Edge Maps: 64
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_up\happy\camera_front\W009_light_up_happy_camera_front.mp4...
#
#  Video Processed: W009_light_up_happy_camera_front.mp4
#     Faces Extracted: 147
#     Optical Flow Maps: 147
#     Edge Maps: 147
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M117\light_rightdown\happy\camera_left\M117_light_rightdown_happy_camera_left.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W029\light_up\happy\camera_rightfront\W029_light_up_happy_camera_rightfront.mp4...
#
#  Video Processed: W029_light_up_happy_camera_rightfront.mp4
#     Faces Extracted: 226
#     Optical Flow Maps: 226
#     Edge Maps: 226
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_right\happy\camera_up\W009_light_right_happy_camera_up.mp4...
#
#  Video Processed: W009_light_right_happy_camera_up.mp4
#     Faces Extracted: 40
#     Optical Flow Maps: 40
#     Edge Maps: 40
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_up\happy\camera_right\W111_light_up_happy_camera_right.mp4...
#
#  Video Processed: W111_light_up_happy_camera_right.mp4
#     Faces Extracted: 221
#     Optical Flow Maps: 221
#     Edge Maps: 221
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W026\light_down\happy\camera_up\W026_light_down_happy_camera_up.mp4...
#
#  Video Processed: W026_light_down_happy_camera_up.mp4
#     Faces Extracted: 181
#     Optical Flow Maps: 181
#     Edge Maps: 181
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W018\light_uniform\happy\camera_rightfront\W018_light_uniform_happy_camera_rightfront.mp4...
#
#  Video Processed: W018_light_uniform_happy_camera_rightfront.mp4
#     Faces Extracted: 161
#     Optical Flow Maps: 161
#     Edge Maps: 161
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_down\happy\camera_up\M030_light_down_happy_camera_up.mp4...
#
#  Video Processed: M030_light_down_happy_camera_up.mp4
#     Faces Extracted: 180
#     Optical Flow Maps: 180
#     Edge Maps: 180
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W136\light_right\happy\camera_left\W136_light_right_happy_camera_left.mp4...
#
#  Video Processed: W136_light_right_happy_camera_left.mp4
#     Faces Extracted: 62
#     Optical Flow Maps: 62
#     Edge Maps: 62
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W024\light_left\happy\camera_front\W024_light_left_happy_camera_front.mp4...
#
#  Video Processed: W024_light_left_happy_camera_front.mp4
#     Faces Extracted: 152
#     Optical Flow Maps: 152
#     Edge Maps: 152
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_down\happy\camera_up\W027_light_down_happy_camera_up.mp4...
#
#  Video Processed: W027_light_down_happy_camera_up.mp4
#     Faces Extracted: 124
#     Optical Flow Maps: 124
#     Edge Maps: 124
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M124\light_left\happy\camera_down\M124_light_left_happy_camera_down.mp4...
#
#  Video Processed: M124_light_left_happy_camera_down.mp4
#     Faces Extracted: 126
#     Optical Flow Maps: 126
#     Edge Maps: 126
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W026\light_rightup\happy\camera_leftfront\W026_light_rightup_happy_camera_leftfront.mp4...
#
#  Video Processed: W026_light_rightup_happy_camera_leftfront.mp4
#     Faces Extracted: 139
#     Optical Flow Maps: 139
#     Edge Maps: 139
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W135\light_leftup\happy\camera_down\W135_light_leftup_happy_camera_down.mp4...
#
#  Video Processed: W135_light_leftup_happy_camera_down.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M008\light_right\happy\camera_right\M008_light_right_happy_camera_right.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W037\light_rightup\happy\camera_down\W037_light_rightup_happy_camera_down.mp4...
#
#  Video Processed: W037_light_rightup_happy_camera_down.mp4
#     Faces Extracted: 151
#     Optical Flow Maps: 151
#     Edge Maps: 151
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W024\light_down\happy\camera_rightfront\W024_light_down_happy_camera_rightfront.mp4...
#
#  Video Processed: W024_light_down_happy_camera_rightfront.mp4
#     Faces Extracted: 144
#     Optical Flow Maps: 144
#     Edge Maps: 144
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_leftdown\happy\camera_up\M123_light_leftdown_happy_camera_up.mp4...
#
#  Video Processed: M123_light_leftdown_happy_camera_up.mp4
#     Faces Extracted: 27
#     Optical Flow Maps: 27
#     Edge Maps: 27
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M140\light_uniform\happy\camera_up\M140_light_uniform_happy_camera_up.mp4...
#
#  Video Processed: M140_light_uniform_happy_camera_up.mp4
#     Faces Extracted: 404
#     Optical Flow Maps: 404
#     Edge Maps: 404
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_rightdown\happy\camera_rightfront\W014_light_rightdown_happy_camera_rightfront.mp4...
#
#  Video Processed: W014_light_rightdown_happy_camera_rightfront.mp4
#     Faces Extracted: 160
#     Optical Flow Maps: 160
#     Edge Maps: 160
# ==================================================
# Processed 20 videos, stopping further processing.
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_leftup\sad\camera_up\W014_light_leftup_sad_camera_up.mp4...
#
#  Video Processed: W014_light_leftup_sad_camera_up.mp4
#     Faces Extracted: 83
#     Optical Flow Maps: 83
#     Edge Maps: 83
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W042\light_down\sad\camera_down\W042_light_down_sad_camera_down.mp4...
#
#  Video Processed: W042_light_down_sad_camera_down.mp4
#     Faces Extracted: 219
#     Optical Flow Maps: 219
#     Edge Maps: 219
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_rightup\sad\camera_left\W111_light_rightup_sad_camera_left.mp4...
#
#  Video Processed: W111_light_rightup_sad_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M026\light_up\sad\camera_right\M026_light_up_sad_camera_right.mp4...
#
#  Video Processed: M026_light_up_sad_camera_right.mp4
#     Faces Extracted: 174
#     Optical Flow Maps: 174
#     Edge Maps: 174
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\W016\light_rightdown\sad\camera_leftfront\W016_light_rightdown_sad_camera_leftfront.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M124\light_uniform\sad\camera_left\M124_light_uniform_sad_camera_left.mp4...
#
#  Video Processed: M124_light_uniform_sad_camera_left.mp4
#     Faces Extracted: 265
#     Optical Flow Maps: 265
#     Edge Maps: 265
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M012\light_down\sad\camera_left\M012_light_down_sad_camera_left.mp4...
#
#  Video Processed: M012_light_down_sad_camera_left.mp4
#     Faces Extracted: 104
#     Optical Flow Maps: 104
#     Edge Maps: 104
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W029\light_leftup\sad\camera_up\W029_light_leftup_sad_camera_up.mp4...
#
#  Video Processed: W029_light_leftup_sad_camera_up.mp4
#     Faces Extracted: 180
#     Optical Flow Maps: 180
#     Edge Maps: 180
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W134\light_down\sad\camera_leftfront\W134_light_down_sad_camera_leftfront.mp4...
#
#  Video Processed: W134_light_down_sad_camera_leftfront.mp4
#     Faces Extracted: 404
#     Optical Flow Maps: 404
#     Edge Maps: 404
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\W111\light_left\sad\camera_right\W111_light_left_sad_camera_right.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M109\light_down\sad\camera_front\M109_light_down_sad_camera_front.mp4...
#
#  Video Processed: M109_light_down_sad_camera_front.mp4
#     Faces Extracted: 213
#     Optical Flow Maps: 213
#     Edge Maps: 213
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M138\light_rightdown\sad\camera_leftfront\M138_light_rightdown_sad_camera_leftfront.mp4...
#
#  Video Processed: M138_light_rightdown_sad_camera_leftfront.mp4
#     Faces Extracted: 127
#     Optical Flow Maps: 127
#     Edge Maps: 127
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W008\light_leftup\sad\camera_down\W008_light_leftup_sad_camera_down.mp4...
#
#  Video Processed: W008_light_leftup_sad_camera_down.mp4
#     Faces Extracted: 190
#     Optical Flow Maps: 190
#     Edge Maps: 190
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_leftdown\sad\camera_right\W015_light_leftdown_sad_camera_right.mp4...
#
#  Video Processed: W015_light_leftdown_sad_camera_right.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\W101\light_rightup\sad\camera_rightfront\W101_light_rightup_sad_camera_rightfront.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_leftup\sad\camera_down\M120_light_leftup_sad_camera_down.mp4...
#
#  Video Processed: M120_light_leftup_sad_camera_down.mp4
#     Faces Extracted: 7
#     Optical Flow Maps: 7
#     Edge Maps: 7
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_uniform\sad\camera_down\W016_light_uniform_sad_camera_down.mp4...
#
#  Video Processed: W016_light_uniform_sad_camera_down.mp4
#     Faces Extracted: 150
#     Optical Flow Maps: 150
#     Edge Maps: 150
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_uniform\sad\camera_left\W016_light_uniform_sad_camera_left.mp4...
#
#  Video Processed: W016_light_uniform_sad_camera_left.mp4
#     Faces Extracted: 113
#     Optical Flow Maps: 113
#     Edge Maps: 113
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W019\light_rightdown\sad\camera_left\W019_light_rightdown_sad_camera_left.mp4...
#
#  Video Processed: W019_light_rightdown_sad_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_leftdown\sad\camera_rightfront\W009_light_leftdown_sad_camera_rightfront.mp4...
#
#  Video Processed: W009_light_leftdown_sad_camera_rightfront.mp4
#     Faces Extracted: 115
#     Optical Flow Maps: 115
#     Edge Maps: 115
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W031\light_rightup\sad\camera_down\W031_light_rightup_sad_camera_down.mp4...
#
#  Video Processed: W031_light_rightup_sad_camera_down.mp4
#     Faces Extracted: 149
#     Optical Flow Maps: 149
#     Edge Maps: 149
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W036\light_right\sad\camera_up\W036_light_right_sad_camera_up.mp4...
#
#  Video Processed: W036_light_right_sad_camera_up.mp4
#     Faces Extracted: 51
#     Optical Flow Maps: 51
#     Edge Maps: 51
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_rightup\sad\camera_right\M024_light_rightup_sad_camera_right.mp4...
#
#  Video Processed: M024_light_rightup_sad_camera_right.mp4
#     Faces Extracted: 111
#     Optical Flow Maps: 111
#     Edge Maps: 111
# ==================================================
# Processed 20 videos, stopping further processing.
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M011\light_down\disgust\camera_front\M011_light_down_disgust_camera_front.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M022\light_rightdown\disgust\camera_left\M022_light_rightdown_disgust_camera_left.mp4...
#
#  Video Processed: M022_light_rightdown_disgust_camera_left.mp4
#     Faces Extracted: 163
#     Optical Flow Maps: 163
#     Edge Maps: 163
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_leftup\disgust\camera_left\M136_light_leftup_disgust_camera_left.mp4...
#
#  Video Processed: M136_light_leftup_disgust_camera_left.mp4
#     Faces Extracted: 393
#     Optical Flow Maps: 393
#     Edge Maps: 393
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M122\light_left\disgust\camera_leftfront\M122_light_left_disgust_camera_leftfront.mp4...
#
#  Video Processed: M122_light_left_disgust_camera_leftfront.mp4
#     Faces Extracted: 202
#     Optical Flow Maps: 202
#     Edge Maps: 202
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W025\light_uniform\disgust\camera_up\W025_light_uniform_disgust_camera_up.mp4...
#
#  Video Processed: W025_light_uniform_disgust_camera_up.mp4
#     Faces Extracted: 211
#     Optical Flow Maps: 211
#     Edge Maps: 211
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M134\light_leftup\disgust\camera_up\M134_light_leftup_disgust_camera_up.mp4...
#
#  Video Processed: M134_light_leftup_disgust_camera_up.mp4
#     Faces Extracted: 21
#     Optical Flow Maps: 21
#     Edge Maps: 21
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W007\light_leftdown\disgust\camera_left\W007_light_leftdown_disgust_camera_left.mp4...
#
#  Video Processed: W007_light_leftdown_disgust_camera_left.mp4
#     Faces Extracted: 186
#     Optical Flow Maps: 186
#     Edge Maps: 186
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M026\light_leftdown\disgust\camera_down\M026_light_leftdown_disgust_camera_down.mp4...
#
#  Video Processed: M026_light_leftdown_disgust_camera_down.mp4
#     Faces Extracted: 106
#     Optical Flow Maps: 106
#     Edge Maps: 106
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M039\light_up\disgust\camera_up\M039_light_up_disgust_camera_up.mp4...
#
#  Video Processed: M039_light_up_disgust_camera_up.mp4
#     Faces Extracted: 176
#     Optical Flow Maps: 176
#     Edge Maps: 176
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W132\light_leftdown\disgust\camera_right\W132_light_leftdown_disgust_camera_right.mp4...
#
#  Video Processed: W132_light_leftdown_disgust_camera_right.mp4
#     Faces Extracted: 58
#     Optical Flow Maps: 58
#     Edge Maps: 58
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_down\disgust\camera_up\W023_light_down_disgust_camera_up.mp4...
#
#  Video Processed: W023_light_down_disgust_camera_up.mp4
#     Faces Extracted: 150
#     Optical Flow Maps: 150
#     Edge Maps: 150
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M140\light_up\disgust\camera_down\M140_light_up_disgust_camera_down.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W032\light_leftup\disgust\camera_left\W032_light_leftup_disgust_camera_left.mp4...
#
#  Video Processed: W032_light_leftup_disgust_camera_left.mp4
#     Faces Extracted: 204
#     Optical Flow Maps: 204
#     Edge Maps: 204
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M139\light_leftdown\disgust\camera_down\M139_light_leftdown_disgust_camera_down.mp4...
#
#  Video Processed: M139_light_leftdown_disgust_camera_down.mp4
#     Faces Extracted: 21
#     Optical Flow Maps: 21
#     Edge Maps: 21
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M011\light_right\disgust\camera_down\M011_light_right_disgust_camera_down.mp4...
#
#  Video Processed: M011_light_right_disgust_camera_down.mp4
#     Faces Extracted: 92
#     Optical Flow Maps: 92
#     Edge Maps: 92
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M026\light_uniform\disgust\camera_leftfront\M026_light_uniform_disgust_camera_leftfront.mp4...
#
#  Video Processed: M026_light_uniform_disgust_camera_leftfront.mp4
#     Faces Extracted: 152
#     Optical Flow Maps: 152
#     Edge Maps: 152
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M025\light_down\disgust\camera_right\M025_light_down_disgust_camera_right.mp4...
#
#  Video Processed: M025_light_down_disgust_camera_right.mp4
#     Faces Extracted: 11
#     Optical Flow Maps: 11
#     Edge Maps: 11
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W042\light_up\disgust\camera_rightfront\W042_light_up_disgust_camera_rightfront.mp4...
#
#  Video Processed: W042_light_up_disgust_camera_rightfront.mp4
#     Faces Extracted: 147
#     Optical Flow Maps: 147
#     Edge Maps: 147
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W134\light_right\disgust\camera_right\W134_light_right_disgust_camera_right.mp4...
#
#  Video Processed: W134_light_right_disgust_camera_right.mp4
#     Faces Extracted: 258
#     Optical Flow Maps: 258
#     Edge Maps: 258
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M134\light_down\disgust\camera_right\M134_light_down_disgust_camera_right.mp4...
#
#  Video Processed: M134_light_down_disgust_camera_right.mp4
#     Faces Extracted: 416
#     Optical Flow Maps: 416
#     Edge Maps: 416
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_rightup\disgust\camera_front\M136_light_rightup_disgust_camera_front.mp4...
#
#  Video Processed: M136_light_rightup_disgust_camera_front.mp4
#     Faces Extracted: 385
#     Optical Flow Maps: 385
#     Edge Maps: 385
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W029\light_up\disgust\camera_up\W029_light_up_disgust_camera_up.mp4...
#
#  Video Processed: W029_light_up_disgust_camera_up.mp4
#     Faces Extracted: 189
#     Optical Flow Maps: 189
#     Edge Maps: 189
# ==================================================
# Processed 20 videos, stopping further processing.
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M115\light_left\neutral\camera_up\M115_light_left_neutral_camera_up.mp4...
#
#  Video Processed: M115_light_left_neutral_camera_up.mp4
#     Faces Extracted: 253
#     Optical Flow Maps: 253
#     Edge Maps: 253
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W021\light_leftup\neutral\camera_right\W021_light_leftup_neutral_camera_right.mp4...
#
#  Video Processed: W021_light_leftup_neutral_camera_right.mp4
#     Faces Extracted: 323
#     Optical Flow Maps: 323
#     Edge Maps: 323
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M034\light_right\neutral\camera_down\M034_light_right_neutral_camera_down.mp4...
#
#  Video Processed: M034_light_right_neutral_camera_down.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W022\light_rightup\neutral\camera_up\W022_light_rightup_neutral_camera_up.mp4...
#
#  Video Processed: W022_light_rightup_neutral_camera_up.mp4
#     Faces Extracted: 168
#     Optical Flow Maps: 168
#     Edge Maps: 168
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M022\light_down\neutral\camera_rightfront\M022_light_down_neutral_camera_rightfront.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W013\light_leftdown\neutral\camera_up\W013_light_leftdown_neutral_camera_up.mp4...
#
#  Video Processed: W013_light_leftdown_neutral_camera_up.mp4
#     Faces Extracted: 56
#     Optical Flow Maps: 56
#     Edge Maps: 56
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W025\light_right\neutral\camera_front\W025_light_right_neutral_camera_front.mp4...
#
#  Video Processed: W025_light_right_neutral_camera_front.mp4
#     Faces Extracted: 194
#     Optical Flow Maps: 194
#     Edge Maps: 194
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_uniform\neutral\camera_left\W023_light_uniform_neutral_camera_left.mp4...
#
#  Video Processed: W023_light_uniform_neutral_camera_left.mp4
#     Faces Extracted: 271
#     Optical Flow Maps: 271
#     Edge Maps: 271
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_uniform\neutral\camera_leftfront\W016_light_uniform_neutral_camera_leftfront.mp4...
#
#  Video Processed: W016_light_uniform_neutral_camera_leftfront.mp4
#     Faces Extracted: 441
#     Optical Flow Maps: 441
#     Edge Maps: 441
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W132\light_up\neutral\camera_rightfront\W132_light_up_neutral_camera_rightfront.mp4...
#
#  Video Processed: W132_light_up_neutral_camera_rightfront.mp4
#     Faces Extracted: 381
#     Optical Flow Maps: 381
#     Edge Maps: 381
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_uniform\neutral\camera_down\M123_light_uniform_neutral_camera_down.mp4...
#
#  Video Processed: M123_light_uniform_neutral_camera_down.mp4
#     Faces Extracted: 254
#     Optical Flow Maps: 254
#     Edge Maps: 254
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_left\neutral\camera_front\W112_light_left_neutral_camera_front.mp4...
#
#  Video Processed: W112_light_left_neutral_camera_front.mp4
#     Faces Extracted: 224
#     Optical Flow Maps: 224
#     Edge Maps: 224
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M022\light_down\neutral\camera_front\M022_light_down_neutral_camera_front.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M119\light_leftup\neutral\camera_up\M119_light_leftup_neutral_camera_up.mp4...
#
#  Video Processed: M119_light_leftup_neutral_camera_up.mp4
#     Faces Extracted: 23
#     Optical Flow Maps: 23
#     Edge Maps: 23
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M015\light_left\neutral\camera_up\M015_light_left_neutral_camera_up.mp4...
#
#  Video Processed: M015_light_left_neutral_camera_up.mp4
#     Faces Extracted: 10
#     Optical Flow Maps: 10
#     Edge Maps: 10
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M137\light_left\neutral\camera_rightfront\M137_light_left_neutral_camera_rightfront.mp4...
#
#  Video Processed: M137_light_left_neutral_camera_rightfront.mp4
#     Faces Extracted: 315
#     Optical Flow Maps: 315
#     Edge Maps: 315
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_right\neutral\camera_up\M136_light_right_neutral_camera_up.mp4...
#
#  Video Processed: M136_light_right_neutral_camera_up.mp4
#     Faces Extracted: 41
#     Optical Flow Maps: 41
#     Edge Maps: 41
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W110\light_right\neutral\camera_front\W110_light_right_neutral_camera_front.mp4...
#
#  Video Processed: W110_light_right_neutral_camera_front.mp4
#     Faces Extracted: 39
#     Optical Flow Maps: 39
#     Edge Maps: 39
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W022\light_rightup\neutral\camera_leftfront\W022_light_rightup_neutral_camera_leftfront.mp4...
#
#  Video Processed: W022_light_rightup_neutral_camera_leftfront.mp4
#     Faces Extracted: 168
#     Optical Flow Maps: 168
#     Edge Maps: 168
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W040\light_uniform\neutral\camera_up\W040_light_uniform_neutral_camera_up.mp4...
#
#  Video Processed: W040_light_uniform_neutral_camera_up.mp4
#     Faces Extracted: 224
#     Optical Flow Maps: 224
#     Edge Maps: 224
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W032\light_right\neutral\camera_leftfront\W032_light_right_neutral_camera_leftfront.mp4...
#
#  Video Processed: W032_light_right_neutral_camera_leftfront.mp4
#     Faces Extracted: 17
#     Optical Flow Maps: 17
#     Edge Maps: 17
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_down\neutral\camera_rightfront\W015_light_down_neutral_camera_rightfront.mp4...
#
#  Video Processed: W015_light_down_neutral_camera_rightfront.mp4
#     Faces Extracted: 162
#     Optical Flow Maps: 162
#     Edge Maps: 162
# ==================================================
# Processed 20 videos, stopping further processing.
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M140\light_right\surprise\camera_right\M140_light_right_surprise_camera_right.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_up\surprise\camera_leftfront\W014_light_up_surprise_camera_leftfront.mp4...
#
#  Video Processed: W014_light_up_surprise_camera_leftfront.mp4
#     Faces Extracted: 153
#     Optical Flow Maps: 153
#     Edge Maps: 153
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_uniform\surprise\camera_leftfront\W014_light_uniform_surprise_camera_leftfront.mp4...
#
#  Video Processed: W014_light_uniform_surprise_camera_leftfront.mp4
#     Faces Extracted: 208
#     Optical Flow Maps: 208
#     Edge Maps: 208
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_uniform\surprise\camera_front\W009_light_uniform_surprise_camera_front.mp4...
#
#  Video Processed: W009_light_uniform_surprise_camera_front.mp4
#     Faces Extracted: 164
#     Optical Flow Maps: 164
#     Edge Maps: 164
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M118\light_right\surprise\camera_right\M118_light_right_surprise_camera_right.mp4...
#
#  Video Processed: M118_light_right_surprise_camera_right.mp4
#     Faces Extracted: 146
#     Optical Flow Maps: 146
#     Edge Maps: 146
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M119\light_up\surprise\camera_left\M119_light_up_surprise_camera_left.mp4...
#
#  Video Processed: M119_light_up_surprise_camera_left.mp4
#     Faces Extracted: 240
#     Optical Flow Maps: 240
#     Edge Maps: 240
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M012\light_uniform\surprise\camera_up\M012_light_uniform_surprise_camera_up.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M122\light_left\surprise\camera_down\M122_light_left_surprise_camera_down.mp4...
#
#  Video Processed: M122_light_left_surprise_camera_down.mp4
#     Faces Extracted: 172
#     Optical Flow Maps: 172
#     Edge Maps: 172
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W018\light_leftdown\surprise\camera_leftfront\W018_light_leftdown_surprise_camera_leftfront.mp4...
#
#  Video Processed: W018_light_leftdown_surprise_camera_leftfront.mp4
#     Faces Extracted: 160
#     Optical Flow Maps: 160
#     Edge Maps: 160
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_rightup\surprise\camera_right\M024_light_rightup_surprise_camera_right.mp4...
#
#  Video Processed: M024_light_rightup_surprise_camera_right.mp4
#     Faces Extracted: 118
#     Optical Flow Maps: 118
#     Edge Maps: 118
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_up\surprise\camera_leftfront\W111_light_up_surprise_camera_leftfront.mp4...
#
#  Video Processed: W111_light_up_surprise_camera_leftfront.mp4
#     Faces Extracted: 228
#     Optical Flow Maps: 228
#     Edge Maps: 228
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M137\light_rightdown\surprise\camera_front\M137_light_rightdown_surprise_camera_front.mp4...
#
#  Video Processed: M137_light_rightdown_surprise_camera_front.mp4
#     Faces Extracted: 333
#     Optical Flow Maps: 333
#     Edge Maps: 333
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\W026\light_uniform\surprise\camera_left\W026_light_uniform_surprise_camera_left.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W022\light_rightup\surprise\camera_down\W022_light_rightup_surprise_camera_down.mp4...
#
#  Video Processed: W022_light_rightup_surprise_camera_down.mp4
#     Faces Extracted: 196
#     Optical Flow Maps: 196
#     Edge Maps: 196
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M119\light_uniform\surprise\camera_up\M119_light_uniform_surprise_camera_up.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M023\light_leftdown\surprise\camera_rightfront\M023_light_leftdown_surprise_camera_rightfront.mp4...
#
#  Video Processed: M023_light_leftdown_surprise_camera_rightfront.mp4
#     Faces Extracted: 191
#     Optical Flow Maps: 191
#     Edge Maps: 191
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M025\light_down\surprise\camera_down\M025_light_down_surprise_camera_down.mp4...
#
#  Video Processed: M025_light_down_surprise_camera_down.mp4
#     Faces Extracted: 76
#     Optical Flow Maps: 76
#     Edge Maps: 76
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_rightdown\surprise\camera_up\W027_light_rightdown_surprise_camera_up.mp4...
#
#  Video Processed: W027_light_rightdown_surprise_camera_up.mp4
#     Faces Extracted: 182
#     Optical Flow Maps: 182
#     Edge Maps: 182
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W028\light_left\surprise\camera_front\W028_light_left_surprise_camera_front.mp4...
#
#  Video Processed: W028_light_left_surprise_camera_front.mp4
#     Faces Extracted: 6
#     Optical Flow Maps: 6
#     Edge Maps: 6
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_down\surprise\camera_down\W027_light_down_surprise_camera_down.mp4...
#
#  Video Processed: W027_light_down_surprise_camera_down.mp4
#     Faces Extracted: 85
#     Optical Flow Maps: 85
#     Edge Maps: 85
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W039\light_down\surprise\camera_down\W039_light_down_surprise_camera_down.mp4...
#
#  Video Processed: W039_light_down_surprise_camera_down.mp4
#     Faces Extracted: 187
#     Optical Flow Maps: 187
#     Edge Maps: 187
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M135\light_rightup\surprise\camera_front\M135_light_rightup_surprise_camera_front.mp4...
#
#  Video Processed: M135_light_rightup_surprise_camera_front.mp4
#     Faces Extracted: 392
#     Optical Flow Maps: 392
#     Edge Maps: 392
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M113\light_rightup\surprise\camera_front\M113_light_rightup_surprise_camera_front.mp4...
#
#  Video Processed: M113_light_rightup_surprise_camera_front.mp4
#     Faces Extracted: 80
#     Optical Flow Maps: 80
#     Edge Maps: 80
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W029\light_down\surprise\camera_left\W029_light_down_surprise_camera_left.mp4...
#
#  Video Processed: W029_light_down_surprise_camera_left.mp4
#     Faces Extracted: 180
#     Optical Flow Maps: 180
#     Edge Maps: 180
# ==================================================
# Processed 20 videos, stopping further processing.
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_down\contempt\camera_leftfront\W014_light_down_contempt_camera_leftfront.mp4...
#
#  Video Processed: W014_light_down_contempt_camera_leftfront.mp4
#     Faces Extracted: 161
#     Optical Flow Maps: 161
#     Edge Maps: 161
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M034\light_rightup\contempt\camera_leftfront\M034_light_rightup_contempt_camera_leftfront.mp4...
#
#  Video Processed: M034_light_rightup_contempt_camera_leftfront.mp4
#     Faces Extracted: 257
#     Optical Flow Maps: 257
#     Edge Maps: 257
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_uniform\contempt\camera_leftfront\W111_light_uniform_contempt_camera_leftfront.mp4...
#
#  Video Processed: W111_light_uniform_contempt_camera_leftfront.mp4
#     Faces Extracted: 325
#     Optical Flow Maps: 325
#     Edge Maps: 325
# ==================================================
# Skipping F:/dataset/DeeperForensics-1.0/source_videos\M009\light_left\contempt\camera_front\M009_light_left_contempt_camera_front.mp4 (already processed)
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_rightup\contempt\camera_left\M004_light_rightup_contempt_camera_left.mp4...
#
#  Video Processed: M004_light_rightup_contempt_camera_left.mp4
#     Faces Extracted: 22
#     Optical Flow Maps: 22
#     Edge Maps: 22
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M113\light_down\contempt\camera_down\M113_light_down_contempt_camera_down.mp4...
#
#  Video Processed: M113_light_down_contempt_camera_down.mp4
#     Faces Extracted: 151
#     Optical Flow Maps: 151
#     Edge Maps: 151
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_right\contempt\camera_front\M024_light_right_contempt_camera_front.mp4...
#
#  Video Processed: M024_light_right_contempt_camera_front.mp4
#     Faces Extracted: 152
#     Optical Flow Maps: 152
#     Edge Maps: 152
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M012\light_right\contempt\camera_front\M012_light_right_contempt_camera_front.mp4...
#
#  Video Processed: M012_light_right_contempt_camera_front.mp4
#     Faces Extracted: 85
#     Optical Flow Maps: 85
#     Edge Maps: 85
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W125\light_rightup\contempt\camera_down\W125_light_rightup_contempt_camera_down.mp4...
#
#  Video Processed: W125_light_rightup_contempt_camera_down.mp4
#     Faces Extracted: 205
#     Optical Flow Maps: 205
#     Edge Maps: 205
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M038\light_left\contempt\camera_down\M038_light_left_contempt_camera_down.mp4...
#
#  Video Processed: M038_light_left_contempt_camera_down.mp4
#     Faces Extracted: 137
#     Optical Flow Maps: 137
#     Edge Maps: 137
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_rightdown\contempt\camera_rightfront\W009_light_rightdown_contempt_camera_rightfront.mp4...
#
#  Video Processed: W009_light_rightdown_contempt_camera_rightfront.mp4
#     Faces Extracted: 153
#     Optical Flow Maps: 153
#     Edge Maps: 153
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W042\light_uniform\contempt\camera_leftfront\W042_light_uniform_contempt_camera_leftfront.mp4...
#
#  Video Processed: W042_light_uniform_contempt_camera_leftfront.mp4
#     Faces Extracted: 147
#     Optical Flow Maps: 147
#     Edge Maps: 147
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W133\light_left\contempt\camera_left\W133_light_left_contempt_camera_left.mp4...
#
#  Video Processed: W133_light_left_contempt_camera_left.mp4
#     Faces Extracted: 378
#     Optical Flow Maps: 378
#     Edge Maps: 378
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W116\light_left\contempt\camera_leftfront\W116_light_left_contempt_camera_leftfront.mp4...
#
#  Video Processed: W116_light_left_contempt_camera_leftfront.mp4
#     Faces Extracted: 216
#     Optical Flow Maps: 216
#     Edge Maps: 216
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M015\light_rightdown\contempt\camera_front\M015_light_rightdown_contempt_camera_front.mp4...
#
#  Video Processed: M015_light_rightdown_contempt_camera_front.mp4
#     Faces Extracted: 81
#     Optical Flow Maps: 81
#     Edge Maps: 81
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_leftdown\contempt\camera_right\M123_light_leftdown_contempt_camera_right.mp4...
#
#  Video Processed: M123_light_leftdown_contempt_camera_right.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M113\light_right\contempt\camera_up\M113_light_right_contempt_camera_up.mp4...
#
#  Video Processed: M113_light_right_contempt_camera_up.mp4
#     Faces Extracted: 19
#     Optical Flow Maps: 19
#     Edge Maps: 19
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W134\light_uniform\contempt\camera_right\W134_light_uniform_contempt_camera_right.mp4...
#
#  Video Processed: W134_light_uniform_contempt_camera_right.mp4
#     Faces Extracted: 422
#     Optical Flow Maps: 422
#     Edge Maps: 422
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W110\light_leftup\contempt\camera_right\W110_light_leftup_contempt_camera_right.mp4...
#
#  Video Processed: W110_light_leftup_contempt_camera_right.mp4
#     Faces Extracted: 201
#     Optical Flow Maps: 201
#     Edge Maps: 201
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_up\contempt\camera_down\M030_light_up_contempt_camera_down.mp4...
#
#  Video Processed: M030_light_up_contempt_camera_down.mp4
#     Faces Extracted: 181
#     Optical Flow Maps: 181
#     Edge Maps: 181
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M140\light_uniform\contempt\camera_left\M140_light_uniform_contempt_camera_left.mp4...
#
#  Video Processed: M140_light_uniform_contempt_camera_left.mp4
#     Faces Extracted: 352
#     Optical Flow Maps: 352
#     Edge Maps: 352
# ==================================================
# Processed 20 videos, stopping further processing.
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_uniform\fear\camera_front\M136_light_uniform_fear_camera_front.mp4...
#
#  Video Processed: M136_light_uniform_fear_camera_front.mp4
#     Faces Extracted: 386
# ...
#
#  Video Processed: 495_M039.mp4
#     Faces Extracted: 572
#     Optical Flow Maps: 572
#     Edge Maps: 572
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\833_M019.mp4...
#
#  Video Processed: 833_M019.mp4
#     Faces Extracted: 599
#     Optical Flow Maps: 599
#     Edge Maps: 599
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\709_W018.mp4...
#
#  Video Processed: 709_W018.mp4
#     Faces Extracted: 305
#     Optical Flow Maps: 305
#     Edge Maps: 305
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\310_M019.mp4...
#
#  Video Processed: 310_M019.mp4
#     Faces Extracted: 374
#     Optical Flow Maps: 374
#     Edge Maps: 374
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\763_W026.mp4...
#
#  Video Processed: 763_W026.mp4
#     Faces Extracted: 813
#     Optical Flow Maps: 813
#     Edge Maps: 813
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\600_M118.mp4...
#
#  Video Processed: 600_M118.mp4
#     Faces Extracted: 387
#     Optical Flow Maps: 387
#     Edge Maps: 387
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\317_W006.mp4...
#
#  Video Processed: 317_W006.mp4
#     Faces Extracted: 681
#     Optical Flow Maps: 681
#     Edge Maps: 681
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\381_W015.mp4...
#
#  Video Processed: 381_W015.mp4
#     Faces Extracted: 577
#     Optical Flow Maps: 577
#     Edge Maps: 577
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\768_M012.mp4...
#
#  Video Processed: 768_M012.mp4
#     Faces Extracted: 329
#     Optical Flow Maps: 329
#     Edge Maps: 329
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\393_M028.mp4...
#
#  Video Processed: 393_M028.mp4
#     Faces Extracted: 578
#     Optical Flow Maps: 578
#     Edge Maps: 578
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\120_W021.mp4...
#
#  Video Processed: 120_W021.mp4
#     Faces Extracted: 404
#     Optical Flow Maps: 404
#     Edge Maps: 404
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\946_W100.mp4...
#
#  Video Processed: 946_W100.mp4
#     Faces Extracted: 461
#     Optical Flow Maps: 461
#     Edge Maps: 461
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\029_W008.mp4...
#
#  Video Processed: 029_W008.mp4
#     Faces Extracted: 415
#     Optical Flow Maps: 415
#     Edge Maps: 415
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\100_M121.mp4...
#
#  Video Processed: 100_M121.mp4
#     Faces Extracted: 422
#     Optical Flow Maps: 422
#     Edge Maps: 422
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\668_W005.mp4...
#
#  Video Processed: 668_W005.mp4
#     Faces Extracted: 397
#     Optical Flow Maps: 397
#     Edge Maps: 397
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\808_W032.mp4...
#
#  Video Processed: 808_W032.mp4
#     Faces Extracted: 636
#     Optical Flow Maps: 636
#     Edge Maps: 636
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\666_M124.mp4...
#
#  Video Processed: 666_M124.mp4
#     Faces Extracted: 382
#     Optical Flow Maps: 382
#     Edge Maps: 382
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\127_M124.mp4...
#
#  Video Processed: 127_M124.mp4
#     Faces Extracted: 863
#     Optical Flow Maps: 863
#     Edge Maps: 863
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\755_M011.mp4...
#
#  Video Processed: 755_M011.mp4
#     Faces Extracted: 335
#     Optical Flow Maps: 335
#     Edge Maps: 335
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\739_W022.mp4...
#
#  Video Processed: 739_W022.mp4
#     Faces Extracted: 303
#     Optical Flow Maps: 303
#     Edge Maps: 303
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\194_M008.mp4...
#
#  Video Processed: 194_M008.mp4
#     Faces Extracted: 566
#     Optical Flow Maps: 566
#     Edge Maps: 566
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\443_M137.mp4...
#
#  Video Processed: 443_M137.mp4
#     Faces Extracted: 1145
#     Optical Flow Maps: 1145
#     Edge Maps: 1145
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\715_M007.mp4...
#
#  Video Processed: 715_M007.mp4
#     Faces Extracted: 855
#     Optical Flow Maps: 855
#     Edge Maps: 855
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\093_W017.mp4...
#
#  Video Processed: 093_W017.mp4
#     Faces Extracted: 307
#     Optical Flow Maps: 307
#     Edge Maps: 307
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\951_W101.mp4...
#
#  Video Processed: 951_W101.mp4
#     Faces Extracted: 1178
#     Optical Flow Maps: 1178
#     Edge Maps: 1178
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\528_M101.mp4...
#
#  Video Processed: 528_M101.mp4
#     Faces Extracted: 376
#     Optical Flow Maps: 376
#     Edge Maps: 376
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\675_M131.mp4...
#
#  Video Processed: 675_M131.mp4
#     Faces Extracted: 420
#     Optical Flow Maps: 420
#     Edge Maps: 420
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\753_W024.mp4...
#
#  Video Processed: 753_W024.mp4
#     Faces Extracted: 685
#     Optical Flow Maps: 685
#     Edge Maps: 685
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\672_W013.mp4...
#
#  Video Processed: 672_W013.mp4
#     Faces Extracted: 540
#     Optical Flow Maps: 540
#     Edge Maps: 540
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\578_W110.mp4...
#
#  Video Processed: 578_W110.mp4
#     Faces Extracted: 563
#     Optical Flow Maps: 563
#     Edge Maps: 563
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\235_M012.mp4...
#
#  Video Processed: 235_M012.mp4
#     Faces Extracted: 311
#     Optical Flow Maps: 311
#     Edge Maps: 311
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\244_W040.mp4...
#
#  Video Processed: 244_W040.mp4
#     Faces Extracted: 556
#     Optical Flow Maps: 556
#     Edge Maps: 556
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\233_W039.mp4...
#
#  Video Processed: 233_W039.mp4
#     Faces Extracted: 1359
#     Optical Flow Maps: 1359
#     Edge Maps: 1359
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\213_W035.mp4...
#
#  Video Processed: 213_W035.mp4
#     Faces Extracted: 377
#     Optical Flow Maps: 377
#     Edge Maps: 377
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\566_W041.mp4...
#
#  Video Processed: 566_W041.mp4
#     Faces Extracted: 856
#     Optical Flow Maps: 856
#     Edge Maps: 856
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\885_W042.mp4...
#
#  Video Processed: 885_W042.mp4
#     Faces Extracted: 328
#     Optical Flow Maps: 328
#     Edge Maps: 328
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\017_W006.mp4...
#
#  Video Processed: 017_W006.mp4
#     Faces Extracted: 397
#     Optical Flow Maps: 397
#     Edge Maps: 397
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\492_M038.mp4...
#
#  Video Processed: 492_M038.mp4
#     Faces Extracted: 642
#     Optical Flow Maps: 642
#     Edge Maps: 642
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\370_W013.mp4...
#
#  Video Processed: 370_W013.mp4
#     Faces Extracted: 375
#     Optical Flow Maps: 375
#     Edge Maps: 375
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\686_W015.mp4...
#
#  Video Processed: 686_W015.mp4
#     Faces Extracted: 341
#     Optical Flow Maps: 341
#     Edge Maps: 341
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\154_W026.mp4...
#
#  Video Processed: 154_W026.mp4
#     Faces Extracted: 593
#     Optical Flow Maps: 593
#     Edge Maps: 593
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\676_W013.mp4...
#
#  Video Processed: 676_W013.mp4
#     Faces Extracted: 514
#     Optical Flow Maps: 514
#     Edge Maps: 514
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\202_W134.mp4...
#
#  Video Processed: 202_W134.mp4
#     Faces Extracted: 322
#     Optical Flow Maps: 322
#     Edge Maps: 322
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\143_M132.mp4...
#
#  Video Processed: 143_M132.mp4
#     Faces Extracted: 413
#     Optical Flow Maps: 413
#     Edge Maps: 413
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\141_W024.mp4...
#
#  Video Processed: 141_W024.mp4
#     Faces Extracted: 508
#     Optical Flow Maps: 508
#     Edge Maps: 508
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\822_W135.mp4...
#
#  Video Processed: 822_W135.mp4
#     Faces Extracted: 296
#     Optical Flow Maps: 296
#     Edge Maps: 296
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\378_W014.mp4...
#
#  Video Processed: 378_W014.mp4
#     Faces Extracted: 760
#     Optical Flow Maps: 760
#     Edge Maps: 760
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\063_M118.mp4...
#
#  Video Processed: 063_M118.mp4
#     Faces Extracted: 929
#     Optical Flow Maps: 929
#     Edge Maps: 929
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\303_M105.mp4...
#
#  Video Processed: 303_M105.mp4
#     Faces Extracted: 567
#     Optical Flow Maps: 567
#     Edge Maps: 567
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\724_W132.mp4...
#
#  Video Processed: 724_W132.mp4
#     Faces Extracted: 599
#     Optical Flow Maps: 599
#     Edge Maps: 599
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\408_M030.mp4...
#
#  Video Processed: 408_M030.mp4
#     Faces Extracted: 305
#     Optical Flow Maps: 305
#     Edge Maps: 305
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\319_M135.mp4...
#
#  Video Processed: 319_M135.mp4
#     Faces Extracted: 716
#     Optical Flow Maps: 716
#     Edge Maps: 716
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\960_W006.mp4...
#
#  Video Processed: 960_W006.mp4
#     Faces Extracted: 344
#     Optical Flow Maps: 344
#     Edge Maps: 344
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\806_W032.mp4...
#
#  Video Processed: 806_W032.mp4
#     Faces Extracted: 300
#     Optical Flow Maps: 300
#     Edge Maps: 300
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\660_W131.mp4...
#
#  Video Processed: 660_W131.mp4
#     Faces Extracted: 340
#     Optical Flow Maps: 340
#     Edge Maps: 340
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\723_W132.mp4...
#
#  Video Processed: 723_W132.mp4
#     Faces Extracted: 729
#     Optical Flow Maps: 729
#     Edge Maps: 729
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\105_W019.mp4...
#
#  Video Processed: 105_W019.mp4
#     Faces Extracted: 299
#     Optical Flow Maps: 299
#     Edge Maps: 299
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\816_W135.mp4...
#
#  Video Processed: 816_W135.mp4
#     Faces Extracted: 410
#     Optical Flow Maps: 410
#     Edge Maps: 410
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\682_M004.mp4...
#
#  Video Processed: 682_M004.mp4
#     Faces Extracted: 964
#     Optical Flow Maps: 964
#     Edge Maps: 964
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\322_W007.mp4...
#
#  Video Processed: 322_W007.mp4
#     Faces Extracted: 312
#     Optical Flow Maps: 312
#     Edge Maps: 312
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\218_M011.mp4...
#
#  Video Processed: 218_M011.mp4
#     Faces Extracted: 352
#     Optical Flow Maps: 352
#     Edge Maps: 352
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\085_W015.mp4...
#
#  Video Processed: 085_W015.mp4
#     Faces Extracted: 328
#     Optical Flow Maps: 328
#     Edge Maps: 328
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\613_M120.mp4...
#
#  Video Processed: 613_M120.mp4
#     Faces Extracted: 414
#     Optical Flow Maps: 414
#     Edge Maps: 414
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end_level_1\646_W009.mp4...
#
#  Video Processed: 646_W009.mp4
#     Faces Extracted: 439
#     Optical Flow Maps: 439
#     Edge Maps: 439
# ==================================================
# Processed 160 videos, stopping further processing.
#
# Processing complete!
