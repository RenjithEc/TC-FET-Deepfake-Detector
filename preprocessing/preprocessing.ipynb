# %%
import os
import cv2
import dlib
import numpy as np
import random

# %%
# Paths for input and output
real_videos_dir = "F:/dataset/DeeperForensics-1.0/source_videos"

output_real_faces = "E:/dataset_1/neutral/real"
output_optical_flow = "E:/dataset_1/neutral/optical_flow"
output_edges = "E:/dataset_1/neutral/edges"

# Create directories if not exist
for path in [output_real_faces, output_optical_flow, output_edges]:
    os.makedirs(path, exist_ok=True)

# Load face detector
detector = dlib.get_frontal_face_detector()
predictor_path = "D:/school/Research/TC-FET-Deepfake-Detector/preprocessing/shape_predictor_68_face_landmarks.dat"  
predictor = dlib.shape_predictor(predictor_path)

def compute_dense_optical_flow(prev_frame, next_frame):
    """Computes dense optical flow and converts it into an RGB representation."""
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)

    flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
    magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    
    hsv = np.zeros_like(prev_frame)
    hsv[..., 1] = 255
    hsv[..., 0] = angle * 180 / np.pi / 2
    hsv[..., 2] = cv2.normalize(magnitude, None, 0, 255, cv2.NORM_MINMAX)

    return cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

def extract_edges(frame):
    """Extracts edges from a frame using the Canny edge detection method."""
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)
    return cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

def process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir):
    """Extracts faces and ensures optical flow and edge maps match the face frames."""
    folder_name = os.path.basename(os.path.dirname(video_path))  # Get folder name for naming
    cap = cv2.VideoCapture(video_path)
    ret, prev_frame = cap.read()
    frame_count = 0

    # Counters for statistics
    face_count = 0
    flow_count = 0
    edge_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = detector(gray)

        if faces:  # Only process optical flow and edges if a face is found
            for i, face in enumerate(faces):
                landmarks = predictor(gray, face)
                interocular_distance = landmarks.part(42).x - landmarks.part(39).x

                x, y, w, h = face.left(), face.top(), face.width(), face.height()
                size = 5 * interocular_distance  # Increase bounding box size

                x1 = max(0, x - size)
                y1 = max(0, y - size)
                x2 = min(frame.shape[1], x + size)
                y2 = min(frame.shape[0], y + size)

                face_crop = frame[y1:y2, x1:x2]

                if face_crop.shape[0] > 0 and face_crop.shape[1] > 0:  # Ensure valid cropping
                    face_resized = cv2.resize(face_crop, (299, 299))

                    filename_base = f"{folder_name}_{os.path.basename(video_path)}_frame{frame_count}_face{i}"
                    filename_face = f"{filename_base}.jpg"
                    filename_flow = f"{filename_base}_flow.jpg"
                    filename_edges = f"{filename_base}_edges.jpg"

                    # Save face
                    cv2.imwrite(os.path.join(save_faces_dir, filename_face), face_resized)
                    face_count += 1

                    # Compute optical flow and crop to face region
                    if prev_frame is not None:
                        flow_map = compute_dense_optical_flow(prev_frame, frame)
                        flow_crop = flow_map[y1:y2, x1:x2]
                        if flow_crop.shape[0] > 0 and flow_crop.shape[1] > 0:
                            flow_resized = cv2.resize(flow_crop, (299, 299))
                            cv2.imwrite(os.path.join(save_flow_dir, filename_flow), flow_resized)
                            flow_count += 1

                    # Compute edges and crop to face region
                    edge_map = extract_edges(frame)
                    edge_crop = edge_map[y1:y2, x1:x2]
                    if edge_crop.shape[0] > 0 and edge_crop.shape[1] > 0:
                        edge_resized = cv2.resize(edge_crop, (299, 299))
                        cv2.imwrite(os.path.join(save_edges_dir, filename_edges), edge_resized)
                        edge_count += 1

        prev_frame = frame
        frame_count += 1

    cap.release()

    # Print statistics for this video
    print(f"\n Video Processed: {os.path.basename(video_path)}")
    print(f"    Faces Extracted: {face_count}")
    print(f"    Optical Flow Maps: {flow_count}")
    print(f"    Edge Maps: {edge_count}")
    print("=" * 50)

def traverse_and_process(root_dir, save_faces_dir, save_flow_dir, save_edges_dir, check_neutral=False):
    """
    Traverses folders recursively and collects all video paths.
    Then shuffles them to process in a random order, optionally filtering 
    based on 'neutral', and skips videos that are already processed.
    """
    # Collect all valid video paths
    video_paths = []
    for root, _, files in os.walk(root_dir):
        # Skip if we must only process 'neutral' folders and this folder isn't one
        if check_neutral and "neutral" not in root.lower():
            continue
        
        for file in files:
            if file.endswith(".mp4") or file.endswith(".avi"):
                full_path = os.path.join(root, file)
                video_paths.append(full_path)

    # Shuffle the list of video paths
    random.shuffle(video_paths)

    # Now iterate over videos in random order
    for video_path in video_paths:
        folder_name = os.path.basename(os.path.dirname(video_path))
        file_name = os.path.basename(video_path)

        # Generate expected output filenames
        base_filename = f"{folder_name}_{file_name}_frame"

        # Check if at least one output exists
        processed = any(
            filename.startswith(base_filename)
            for directory in [save_faces_dir, save_flow_dir, save_edges_dir]
            for filename in os.listdir(directory)
        )

        if processed:
            print(f"Skipping {video_path} (already processed)")
            continue

        print(f"Processing {video_path}...")
        process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir)


# Process real videos (source_videos) but only if 'neutral' is in the path
traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, check_neutral=True)

print("\nProcessing complete!")
# Out:
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W028\light_down\neutral\camera_down\W028_light_down_neutral_camera_down.mp4...
#
#  Video Processed: W028_light_down_neutral_camera_down.mp4
#     Faces Extracted: 217
#     Optical Flow Maps: 217
#     Edge Maps: 217
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_leftdown\neutral\camera_front\W027_light_leftdown_neutral_camera_front.mp4...
#
#  Video Processed: W027_light_leftdown_neutral_camera_front.mp4
#     Faces Extracted: 117
#     Optical Flow Maps: 117
#     Edge Maps: 117
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W021\light_left\neutral\camera_rightfront\W021_light_left_neutral_camera_rightfront.mp4...
#
#  Video Processed: W021_light_left_neutral_camera_rightfront.mp4
#     Faces Extracted: 373
#     Optical Flow Maps: 373
#     Edge Maps: 373
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_leftup\neutral\camera_right\M030_light_leftup_neutral_camera_right.mp4...
#
#  Video Processed: M030_light_leftup_neutral_camera_right.mp4
#     Faces Extracted: 87
#     Optical Flow Maps: 87
#     Edge Maps: 87
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W017\light_rightdown\neutral\camera_right\W017_light_rightdown_neutral_camera_right.mp4...
#
#  Video Processed: W017_light_rightdown_neutral_camera_right.mp4
#     Faces Extracted: 119
#     Optical Flow Maps: 119
#     Edge Maps: 119
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M122\light_rightdown\neutral\camera_down\M122_light_rightdown_neutral_camera_down.mp4...
#
#  Video Processed: M122_light_rightdown_neutral_camera_down.mp4
#     Faces Extracted: 41
#     Optical Flow Maps: 41
#     Edge Maps: 41
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M022\light_right\neutral\camera_front\M022_light_right_neutral_camera_front.mp4...
#
#  Video Processed: M022_light_right_neutral_camera_front.mp4
#     Faces Extracted: 149
#     Optical Flow Maps: 149
#     Edge Maps: 149
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_left\neutral\camera_right\W005_light_left_neutral_camera_right.mp4...
#
#  Video Processed: W005_light_left_neutral_camera_right.mp4
#     Faces Extracted: 148
#     Optical Flow Maps: 148
#     Edge Maps: 148
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_left\neutral\camera_rightfront\W111_light_left_neutral_camera_rightfront.mp4...
#
#  Video Processed: W111_light_left_neutral_camera_rightfront.mp4
#     Faces Extracted: 182
#     Optical Flow Maps: 182
#     Edge Maps: 182
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W131\light_uniform\neutral\camera_right\W131_light_uniform_neutral_camera_right.mp4...
#
#  Video Processed: W131_light_uniform_neutral_camera_right.mp4
#     Faces Extracted: 265
#     Optical Flow Maps: 265
#     Edge Maps: 265
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M109\light_right\neutral\camera_leftfront\M109_light_right_neutral_camera_leftfront.mp4...
#
#  Video Processed: M109_light_right_neutral_camera_leftfront.mp4
#     Faces Extracted: 221
#     Optical Flow Maps: 221
#     Edge Maps: 221
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_up\neutral\camera_up\W112_light_up_neutral_camera_up.mp4...
#
#  Video Processed: W112_light_up_neutral_camera_up.mp4
#     Faces Extracted: 221
#     Optical Flow Maps: 221
#     Edge Maps: 221
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W131\light_leftup\neutral\camera_up\W131_light_leftup_neutral_camera_up.mp4...
#
#  Video Processed: W131_light_leftup_neutral_camera_up.mp4
#     Faces Extracted: 294
#     Optical Flow Maps: 294
#     Edge Maps: 294
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_rightdown\neutral\camera_front\M030_light_rightdown_neutral_camera_front.mp4...
#
#  Video Processed: M030_light_rightdown_neutral_camera_front.mp4
#     Faces Extracted: 78
#     Optical Flow Maps: 78
#     Edge Maps: 78
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M119\light_leftdown\neutral\camera_up\M119_light_leftdown_neutral_camera_up.mp4...
#
#  Video Processed: M119_light_leftdown_neutral_camera_up.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M018\light_leftup\neutral\camera_left\M018_light_leftup_neutral_camera_left.mp4...
#
#  Video Processed: M018_light_leftup_neutral_camera_left.mp4
#     Faces Extracted: 133
#     Optical Flow Maps: 133
#     Edge Maps: 133
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_leftup\neutral\camera_left\W023_light_leftup_neutral_camera_left.mp4...
#
#  Video Processed: W023_light_leftup_neutral_camera_left.mp4
#     Faces Extracted: 236
#     Optical Flow Maps: 236
#     Edge Maps: 236
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W022\light_down\neutral\camera_front\W022_light_down_neutral_camera_front.mp4...
#
#  Video Processed: W022_light_down_neutral_camera_front.mp4
#     Faces Extracted: 319
#     Optical Flow Maps: 319
#     Edge Maps: 319
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_uniform\neutral\camera_leftfront\W005_light_uniform_neutral_camera_leftfront.mp4...
#
#  Video Processed: W005_light_uniform_neutral_camera_leftfront.mp4
#     Faces Extracted: 263
#     Optical Flow Maps: 263
#     Edge Maps: 263
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W035\light_leftup\neutral\camera_down\W035_light_leftup_neutral_camera_down.mp4...
#
#  Video Processed: W035_light_leftup_neutral_camera_down.mp4
#     Faces Extracted: 264
#     Optical Flow Maps: 264
#     Edge Maps: 264
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M101\light_down\neutral\camera_rightfront\M101_light_down_neutral_camera_rightfront.mp4...
#
#  Video Processed: M101_light_down_neutral_camera_rightfront.mp4
#     Faces Extracted: 334
#     Optical Flow Maps: 334
#     Edge Maps: 334
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_left\neutral\camera_left\M123_light_left_neutral_camera_left.mp4...
#
#  Video Processed: M123_light_left_neutral_camera_left.mp4
#     Faces Extracted: 88
#     Optical Flow Maps: 88
#     Edge Maps: 88
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M118\light_right\neutral\camera_left\M118_light_right_neutral_camera_left.mp4...
#
#  Video Processed: M118_light_right_neutral_camera_left.mp4
#     Faces Extracted: 7
#     Optical Flow Maps: 7
#     Edge Maps: 7
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_leftup\neutral\camera_leftfront\M021_light_leftup_neutral_camera_leftfront.mp4...
#
#  Video Processed: M021_light_leftup_neutral_camera_leftfront.mp4
#     Faces Extracted: 232
#     Optical Flow Maps: 232
#     Edge Maps: 232
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_left\neutral\camera_leftfront\W014_light_left_neutral_camera_leftfront.mp4...
#
#  Video Processed: W014_light_left_neutral_camera_leftfront.mp4
#     Faces Extracted: 150
#     Optical Flow Maps: 150
#     Edge Maps: 150
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_down\neutral\camera_rightfront\M004_light_down_neutral_camera_rightfront.mp4...
#
#  Video Processed: M004_light_down_neutral_camera_rightfront.mp4
#     Faces Extracted: 224
#     Optical Flow Maps: 224
#     Edge Maps: 224
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_up\neutral\camera_rightfront\M021_light_up_neutral_camera_rightfront.mp4...
#
#  Video Processed: M021_light_up_neutral_camera_rightfront.mp4
#     Faces Extracted: 266
#     Optical Flow Maps: 266
#     Edge Maps: 266
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M009\light_left\neutral\camera_leftfront\M009_light_left_neutral_camera_leftfront.mp4...
#
#  Video Processed: M009_light_left_neutral_camera_leftfront.mp4
#     Faces Extracted: 188
#     Optical Flow Maps: 188
#     Edge Maps: 188
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M029\light_leftdown\neutral\camera_left\M029_light_leftdown_neutral_camera_left.mp4...
#
#  Video Processed: M029_light_leftdown_neutral_camera_left.mp4
#     Faces Extracted: 45
#     Optical Flow Maps: 45
#     Edge Maps: 45
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M141\light_left\neutral\camera_front\M141_light_left_neutral_camera_front.mp4...
#
#  Video Processed: M141_light_left_neutral_camera_front.mp4
#     Faces Extracted: 284
#     Optical Flow Maps: 284
#     Edge Maps: 284
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_uniform\neutral\camera_up\W112_light_uniform_neutral_camera_up.mp4...
#
#  Video Processed: W112_light_uniform_neutral_camera_up.mp4
#     Faces Extracted: 223
#     Optical Flow Maps: 223
#     Edge Maps: 223
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W008\light_left\neutral\camera_left\W008_light_left_neutral_camera_left.mp4...
#
#  Video Processed: W008_light_left_neutral_camera_left.mp4
#     Faces Extracted: 51
#     Optical Flow Maps: 51
#     Edge Maps: 51
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M029\light_down\neutral\camera_up\M029_light_down_neutral_camera_up.mp4...
#
#  Video Processed: M029_light_down_neutral_camera_up.mp4
#     Faces Extracted: 313
#     Optical Flow Maps: 313
#     Edge Maps: 313
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W026\light_right\neutral\camera_right\W026_light_right_neutral_camera_right.mp4...
#
#  Video Processed: W026_light_right_neutral_camera_right.mp4
#     Faces Extracted: 9
#     Optical Flow Maps: 9
#     Edge Maps: 9
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W035\light_leftdown\neutral\camera_right\W035_light_leftdown_neutral_camera_right.mp4...
#
#  Video Processed: W035_light_leftdown_neutral_camera_right.mp4
#     Faces Extracted: 1
#     Optical Flow Maps: 1
#     Edge Maps: 1
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W037\light_leftdown\neutral\camera_left\W037_light_leftdown_neutral_camera_left.mp4...
#
#  Video Processed: W037_light_leftdown_neutral_camera_left.mp4
#     Faces Extracted: 2
#     Optical Flow Maps: 2
#     Edge Maps: 2
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W031\light_uniform\neutral\camera_rightfront\W031_light_uniform_neutral_camera_rightfront.mp4...
#
#  Video Processed: W031_light_uniform_neutral_camera_rightfront.mp4
#     Faces Extracted: 138
#     Optical Flow Maps: 138
#     Edge Maps: 138
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W133\light_right\neutral\camera_down\W133_light_right_neutral_camera_down.mp4...
#
#  Video Processed: W133_light_right_neutral_camera_down.mp4
#     Faces Extracted: 142
#     Optical Flow Maps: 142
#     Edge Maps: 142
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_down\neutral\camera_leftfront\W015_light_down_neutral_camera_leftfront.mp4...
#
#  Video Processed: W015_light_down_neutral_camera_leftfront.mp4
#     Faces Extracted: 162
#     Optical Flow Maps: 162
#     Edge Maps: 162
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_leftdown\neutral\camera_leftfront\W023_light_leftdown_neutral_camera_leftfront.mp4...
#
#  Video Processed: W023_light_leftdown_neutral_camera_leftfront.mp4
#     Faces Extracted: 221
#     Optical Flow Maps: 221
#     Edge Maps: 221
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M121\light_right\neutral\camera_leftfront\M121_light_right_neutral_camera_leftfront.mp4...
#
#  Video Processed: M121_light_right_neutral_camera_leftfront.mp4
#     Faces Extracted: 132
#     Optical Flow Maps: 132
#     Edge Maps: 132
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M133\light_down\neutral\camera_rightfront\M133_light_down_neutral_camera_rightfront.mp4...
#
#  Video Processed: M133_light_down_neutral_camera_rightfront.mp4
#     Faces Extracted: 379
#     Optical Flow Maps: 379
#     Edge Maps: 379
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W135\light_left\neutral\camera_leftfront\W135_light_left_neutral_camera_leftfront.mp4...
#
#  Video Processed: W135_light_left_neutral_camera_leftfront.mp4
#     Faces Extracted: 365
#     Optical Flow Maps: 365
#     Edge Maps: 365
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W019\light_leftup\neutral\camera_left\W019_light_leftup_neutral_camera_left.mp4...
#
#  Video Processed: W019_light_leftup_neutral_camera_left.mp4
#     Faces Extracted: 164
#     Optical Flow Maps: 164
#     Edge Maps: 164
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W021\light_leftdown\neutral\camera_front\W021_light_leftdown_neutral_camera_front.mp4...
#
#  Video Processed: W021_light_leftdown_neutral_camera_front.mp4
#     Faces Extracted: 351
#     Optical Flow Maps: 351
#     Edge Maps: 351
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_up\neutral\camera_leftfront\M123_light_up_neutral_camera_leftfront.mp4...
#
#  Video Processed: M123_light_up_neutral_camera_leftfront.mp4
#     Faces Extracted: 262
#     Optical Flow Maps: 262
#     Edge Maps: 262
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M008\light_leftup\neutral\camera_down\M008_light_leftup_neutral_camera_down.mp4...
#
#  Video Processed: M008_light_leftup_neutral_camera_down.mp4
#     Faces Extracted: 228
#     Optical Flow Maps: 228
#     Edge Maps: 228
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M137\light_leftdown\neutral\camera_rightfront\M137_light_leftdown_neutral_camera_rightfront.mp4...
#
#  Video Processed: M137_light_leftdown_neutral_camera_rightfront.mp4
#     Faces Extracted: 143
#     Optical Flow Maps: 143
#     Edge Maps: 143
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_leftup\neutral\camera_down\W016_light_leftup_neutral_camera_down.mp4...
#
#  Video Processed: W016_light_leftup_neutral_camera_down.mp4
#     Faces Extracted: 169
#     Optical Flow Maps: 169
#     Edge Maps: 169
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W027\light_down\neutral\camera_left\W027_light_down_neutral_camera_left.mp4...
#
#  Video Processed: W027_light_down_neutral_camera_left.mp4
#     Faces Extracted: 269
#     Optical Flow Maps: 269
#     Edge Maps: 269
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W031\light_leftdown\neutral\camera_leftfront\W031_light_leftdown_neutral_camera_leftfront.mp4...
#
#  Video Processed: W031_light_leftdown_neutral_camera_leftfront.mp4
#     Faces Extracted: 167
#     Optical Flow Maps: 167
#     Edge Maps: 167
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M121\light_leftup\neutral\camera_right\M121_light_leftup_neutral_camera_right.mp4...
#
#  Video Processed: M121_light_leftup_neutral_camera_right.mp4
#     Faces Extracted: 180
#     Optical Flow Maps: 180
#     Edge Maps: 180
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_left\neutral\camera_right\M120_light_left_neutral_camera_right.mp4...
#
#  Video Processed: M120_light_left_neutral_camera_right.mp4
#     Faces Extracted: 89
#     Optical Flow Maps: 89
#     Edge Maps: 89
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_left\neutral\camera_left\W005_light_left_neutral_camera_left.mp4...
#
#  Video Processed: W005_light_left_neutral_camera_left.mp4
#     Faces Extracted: 220
#     Optical Flow Maps: 220
#     Edge Maps: 220
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M031\light_leftdown\neutral\camera_left\M031_light_leftdown_neutral_camera_left.mp4...
#
#  Video Processed: M031_light_leftdown_neutral_camera_left.mp4
#     Faces Extracted: 40
#     Optical Flow Maps: 40
#     Edge Maps: 40
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M117\light_up\neutral\camera_rightfront\M117_light_up_neutral_camera_rightfront.mp4...
#
#  Video Processed: M117_light_up_neutral_camera_rightfront.mp4
#     Faces Extracted: 302
#     Optical Flow Maps: 302
#     Edge Maps: 302
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_rightup\neutral\camera_leftfront\M024_light_rightup_neutral_camera_leftfront.mp4...
#
#  Video Processed: M024_light_rightup_neutral_camera_leftfront.mp4
#     Faces Extracted: 4
#     Optical Flow Maps: 4
#     Edge Maps: 4
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_up\neutral\camera_rightfront\W016_light_up_neutral_camera_rightfront.mp4...
#
#  Video Processed: W016_light_up_neutral_camera_rightfront.mp4
#     Faces Extracted: 164
#     Optical Flow Maps: 164
#     Edge Maps: 164
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M014\light_leftup\neutral\camera_left\M014_light_leftup_neutral_camera_left.mp4...
#
#  Video Processed: M014_light_leftup_neutral_camera_left.mp4
#     Faces Extracted: 150
#     Optical Flow Maps: 150
#     Edge Maps: 150
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W029\light_right\neutral\camera_front\W029_light_right_neutral_camera_front.mp4...
#
#  Video Processed: W029_light_right_neutral_camera_front.mp4
#     Faces Extracted: 201
#     Optical Flow Maps: 201
#     Edge Maps: 201
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_rightup\neutral\camera_left\W111_light_rightup_neutral_camera_left.mp4...
#
#  Video Processed: W111_light_rightup_neutral_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_leftdown\neutral\camera_down\W005_light_leftdown_neutral_camera_down.mp4...
#
#  Video Processed: W005_light_leftdown_neutral_camera_down.mp4
#     Faces Extracted: 234
#     Optical Flow Maps: 234
#     Edge Maps: 234
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W024\light_right\neutral\camera_front\W024_light_right_neutral_camera_front.mp4...
#
#  Video Processed: W024_light_right_neutral_camera_front.mp4
#     Faces Extracted: 173
#     Optical Flow Maps: 173
#     Edge Maps: 173
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W036\light_leftup\neutral\camera_down\W036_light_leftup_neutral_camera_down.mp4...
#
#  Video Processed: W036_light_leftup_neutral_camera_down.mp4
#     Faces Extracted: 145
#     Optical Flow Maps: 145
#     Edge Maps: 145
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M122\light_uniform\neutral\camera_down\M122_light_uniform_neutral_camera_down.mp4...
#
#  Video Processed: M122_light_uniform_neutral_camera_down.mp4
#     Faces Extracted: 239
#     Optical Flow Maps: 239
#     Edge Maps: 239
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M115\light_left\neutral\camera_right\M115_light_left_neutral_camera_right.mp4...
#
#  Video Processed: M115_light_left_neutral_camera_right.mp4
#     Faces Extracted: 178
#     Optical Flow Maps: 178
#     Edge Maps: 178
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M008\light_uniform\neutral\camera_right\M008_light_uniform_neutral_camera_right.mp4...
#
#  Video Processed: M008_light_uniform_neutral_camera_right.mp4
#     Faces Extracted: 212
#     Optical Flow Maps: 212
#     Edge Maps: 212
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W039\light_right\neutral\camera_leftfront\W039_light_right_neutral_camera_leftfront.mp4...
#
#  Video Processed: W039_light_right_neutral_camera_leftfront.mp4
#     Faces Extracted: 2
#     Optical Flow Maps: 2
#     Edge Maps: 2
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_leftdown\neutral\camera_rightfront\M120_light_leftdown_neutral_camera_rightfront.mp4...
#
#  Video Processed: M120_light_leftdown_neutral_camera_rightfront.mp4
#     Faces Extracted: 108
#     Optical Flow Maps: 108
#     Edge Maps: 108
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W039\light_leftdown\neutral\camera_up\W039_light_leftdown_neutral_camera_up.mp4...
#
#  Video Processed: W039_light_leftdown_neutral_camera_up.mp4
#     Faces Extracted: 76
#     Optical Flow Maps: 76
#     Edge Maps: 76
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W131\light_rightdown\neutral\camera_leftfront\W131_light_rightdown_neutral_camera_leftfront.mp4...
#
#  Video Processed: W131_light_rightdown_neutral_camera_leftfront.mp4
#     Faces Extracted: 230
#     Optical Flow Maps: 230
#     Edge Maps: 230
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W029\light_rightdown\neutral\camera_right\W029_light_rightdown_neutral_camera_right.mp4...
#
#  Video Processed: W029_light_rightdown_neutral_camera_right.mp4
#     Faces Extracted: 253
#     Optical Flow Maps: 253
#     Edge Maps: 253
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M131\light_rightdown\neutral\camera_left\M131_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: M131_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 2
#     Optical Flow Maps: 2
#     Edge Maps: 2
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W116\light_rightdown\neutral\camera_leftfront\W116_light_rightdown_neutral_camera_leftfront.mp4...
#
#  Video Processed: W116_light_rightdown_neutral_camera_leftfront.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M117\light_leftup\neutral\camera_front\M117_light_leftup_neutral_camera_front.mp4...
#
#  Video Processed: M117_light_leftup_neutral_camera_front.mp4
#     Faces Extracted: 196
#     Optical Flow Maps: 196
#     Edge Maps: 196
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W028\light_rightdown\neutral\camera_front\W028_light_rightdown_neutral_camera_front.mp4...
#
#  Video Processed: W028_light_rightdown_neutral_camera_front.mp4
#     Faces Extracted: 140
#     Optical Flow Maps: 140
#     Edge Maps: 140
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_leftup\neutral\camera_leftfront\W009_light_leftup_neutral_camera_leftfront.mp4...
#
#  Video Processed: W009_light_leftup_neutral_camera_leftfront.mp4
#     Faces Extracted: 226
#     Optical Flow Maps: 226
#     Edge Maps: 226
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_rightdown\neutral\camera_right\M030_light_rightdown_neutral_camera_right.mp4...
#
#  Video Processed: M030_light_rightdown_neutral_camera_right.mp4
#     Faces Extracted: 140
#     Optical Flow Maps: 140
#     Edge Maps: 140
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M023\light_rightup\neutral\camera_down\M023_light_rightup_neutral_camera_down.mp4...
#
#  Video Processed: M023_light_rightup_neutral_camera_down.mp4
#     Faces Extracted: 287
#     Optical Flow Maps: 287
#     Edge Maps: 287
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W136\light_down\neutral\camera_rightfront\W136_light_down_neutral_camera_rightfront.mp4...
#
#  Video Processed: W136_light_down_neutral_camera_rightfront.mp4
#     Faces Extracted: 400
#     Optical Flow Maps: 400
#     Edge Maps: 400
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M034\light_left\neutral\camera_left\M034_light_left_neutral_camera_left.mp4...
#
#  Video Processed: M034_light_left_neutral_camera_left.mp4
#     Faces Extracted: 3
#     Optical Flow Maps: 3
#     Edge Maps: 3
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_uniform\neutral\camera_rightfront\W009_light_uniform_neutral_camera_rightfront.mp4...
#
#  Video Processed: W009_light_uniform_neutral_camera_rightfront.mp4
#     Faces Extracted: 354
#     Optical Flow Maps: 354
#     Edge Maps: 354
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M024\light_right\neutral\camera_rightfront\M024_light_right_neutral_camera_rightfront.mp4...
#
#  Video Processed: M024_light_right_neutral_camera_rightfront.mp4
#     Faces Extracted: 249
#     Optical Flow Maps: 249
#     Edge Maps: 249
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W101\light_uniform\neutral\camera_front\W101_light_uniform_neutral_camera_front.mp4...
#
#  Video Processed: W101_light_uniform_neutral_camera_front.mp4
#     Faces Extracted: 87
#     Optical Flow Maps: 87
#     Edge Maps: 87
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W135\light_right\neutral\camera_rightfront\W135_light_right_neutral_camera_rightfront.mp4...
#
#  Video Processed: W135_light_right_neutral_camera_rightfront.mp4
#     Faces Extracted: 332
#     Optical Flow Maps: 332
#     Edge Maps: 332
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W018\light_up\neutral\camera_rightfront\W018_light_up_neutral_camera_rightfront.mp4...
#
#  Video Processed: W018_light_up_neutral_camera_rightfront.mp4
#     Faces Extracted: 123
#     Optical Flow Maps: 123
#     Edge Maps: 123
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W018\light_leftdown\neutral\camera_up\W018_light_leftdown_neutral_camera_up.mp4...
#
#  Video Processed: W018_light_leftdown_neutral_camera_up.mp4
#     Faces Extracted: 64
#     Optical Flow Maps: 64
#     Edge Maps: 64
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_leftdown\neutral\camera_front\W112_light_leftdown_neutral_camera_front.mp4...
#
#  Video Processed: W112_light_leftdown_neutral_camera_front.mp4
#     Faces Extracted: 262
#     Optical Flow Maps: 262
#     Edge Maps: 262
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M131\light_rightup\neutral\camera_up\M131_light_rightup_neutral_camera_up.mp4...
#
#  Video Processed: M131_light_rightup_neutral_camera_up.mp4
#     Faces Extracted: 390
#     Optical Flow Maps: 390
#     Edge Maps: 390
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W112\light_leftdown\neutral\camera_right\W112_light_leftdown_neutral_camera_right.mp4...
#
#  Video Processed: W112_light_leftdown_neutral_camera_right.mp4
#     Faces Extracted: 261
#     Optical Flow Maps: 261
#     Edge Maps: 261
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M124\light_rightdown\neutral\camera_up\M124_light_rightdown_neutral_camera_up.mp4...
#
#  Video Processed: M124_light_rightdown_neutral_camera_up.mp4
#     Faces Extracted: 10
#     Optical Flow Maps: 10
#     Edge Maps: 10
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M009\light_rightup\neutral\camera_front\M009_light_rightup_neutral_camera_front.mp4...
#
#  Video Processed: M009_light_rightup_neutral_camera_front.mp4
#     Faces Extracted: 203
#     Optical Flow Maps: 203
#     Edge Maps: 203
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W041\light_leftup\neutral\camera_front\W041_light_leftup_neutral_camera_front.mp4...
#
#  Video Processed: W041_light_leftup_neutral_camera_front.mp4
#     Faces Extracted: 243
#     Optical Flow Maps: 243
#     Edge Maps: 243
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M028\light_leftup\neutral\camera_front\M028_light_leftup_neutral_camera_front.mp4...
#
#  Video Processed: M028_light_leftup_neutral_camera_front.mp4
#     Faces Extracted: 239
#     Optical Flow Maps: 239
#     Edge Maps: 239
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M022\light_leftup\neutral\camera_leftfront\M022_light_leftup_neutral_camera_leftfront.mp4...
#
#  Video Processed: M022_light_leftup_neutral_camera_leftfront.mp4
#     Faces Extracted: 178
#     Optical Flow Maps: 178
#     Edge Maps: 178
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M012\light_down\neutral\camera_right\M012_light_down_neutral_camera_right.mp4...
#
#  Video Processed: M012_light_down_neutral_camera_right.mp4
#     Faces Extracted: 212
#     Optical Flow Maps: 212
#     Edge Maps: 212
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M007\light_leftdown\neutral\camera_rightfront\M007_light_leftdown_neutral_camera_rightfront.mp4...
#
#  Video Processed: M007_light_leftdown_neutral_camera_rightfront.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_uniform\neutral\camera_up\W009_light_uniform_neutral_camera_up.mp4...
#
#  Video Processed: W009_light_uniform_neutral_camera_up.mp4
#     Faces Extracted: 359
#     Optical Flow Maps: 359
#     Edge Maps: 359
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M005\light_down\neutral\camera_left\M005_light_down_neutral_camera_left.mp4...
#
#  Video Processed: M005_light_down_neutral_camera_left.mp4
#     Faces Extracted: 196
#     Optical Flow Maps: 196
#     Edge Maps: 196
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M124\light_left\neutral\camera_rightfront\M124_light_left_neutral_camera_rightfront.mp4...
#
#  Video Processed: M124_light_left_neutral_camera_rightfront.mp4
#     Faces Extracted: 188
#     Optical Flow Maps: 188
#     Edge Maps: 188
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M132\light_rightup\neutral\camera_leftfront\M132_light_rightup_neutral_camera_leftfront.mp4...
#
#  Video Processed: M132_light_rightup_neutral_camera_leftfront.mp4
#     Faces Extracted: 107
#     Optical Flow Maps: 107
#     Edge Maps: 107
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M027\light_leftup\neutral\camera_left\M027_light_leftup_neutral_camera_left.mp4...
#
#  Video Processed: M027_light_leftup_neutral_camera_left.mp4
#     Faces Extracted: 59
#     Optical Flow Maps: 59
#     Edge Maps: 59
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W101\light_rightup\neutral\camera_down\W101_light_rightup_neutral_camera_down.mp4...
#
#  Video Processed: W101_light_rightup_neutral_camera_down.mp4
#     Faces Extracted: 148
#     Optical Flow Maps: 148
#     Edge Maps: 148
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M022\light_uniform\neutral\camera_left\M022_light_uniform_neutral_camera_left.mp4...
#
#  Video Processed: M022_light_uniform_neutral_camera_left.mp4
#     Faces Extracted: 304
#     Optical Flow Maps: 304
#     Edge Maps: 304
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W019\light_down\neutral\camera_left\W019_light_down_neutral_camera_left.mp4...
#
#  Video Processed: W019_light_down_neutral_camera_left.mp4
#     Faces Extracted: 117
#     Optical Flow Maps: 117
#     Edge Maps: 117
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_up\neutral\camera_front\W005_light_up_neutral_camera_front.mp4...
#
#  Video Processed: W005_light_up_neutral_camera_front.mp4
#     Faces Extracted: 210
#     Optical Flow Maps: 210
#     Edge Maps: 210
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W018\light_leftup\neutral\camera_left\W018_light_leftup_neutral_camera_left.mp4...
#
#  Video Processed: W018_light_leftup_neutral_camera_left.mp4
#     Faces Extracted: 146
#     Optical Flow Maps: 146
#     Edge Maps: 146
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W012\light_uniform\neutral\camera_rightfront\W012_light_uniform_neutral_camera_rightfront.mp4...
#
#  Video Processed: W012_light_uniform_neutral_camera_rightfront.mp4
#     Faces Extracted: 306
#     Optical Flow Maps: 306
#     Edge Maps: 306
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_left\neutral\camera_left\W014_light_left_neutral_camera_left.mp4...
#
#  Video Processed: W014_light_left_neutral_camera_left.mp4
#     Faces Extracted: 118
#     Optical Flow Maps: 118
#     Edge Maps: 118
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M023\light_leftdown\neutral\camera_rightfront\M023_light_leftdown_neutral_camera_rightfront.mp4...
#
#  Video Processed: M023_light_leftdown_neutral_camera_rightfront.mp4
#     Faces Extracted: 386
#     Optical Flow Maps: 386
#     Edge Maps: 386
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M013\light_uniform\neutral\camera_left\M013_light_uniform_neutral_camera_left.mp4...
#
#  Video Processed: M013_light_uniform_neutral_camera_left.mp4
#     Faces Extracted: 153
#     Optical Flow Maps: 153
#     Edge Maps: 153
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W014\light_left\neutral\camera_up\W014_light_left_neutral_camera_up.mp4...
#
#  Video Processed: W014_light_left_neutral_camera_up.mp4
#     Faces Extracted: 60
#     Optical Flow Maps: 60
#     Edge Maps: 60
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_leftup\neutral\camera_down\M136_light_leftup_neutral_camera_down.mp4...
#
#  Video Processed: M136_light_leftup_neutral_camera_down.mp4
#     Faces Extracted: 371
#     Optical Flow Maps: 371
#     Edge Maps: 371
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_uniform\neutral\camera_rightfront\W015_light_uniform_neutral_camera_rightfront.mp4...
#
#  Video Processed: W015_light_uniform_neutral_camera_rightfront.mp4
#     Faces Extracted: 209
#     Optical Flow Maps: 209
#     Edge Maps: 209
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M138\light_left\neutral\camera_rightfront\M138_light_left_neutral_camera_rightfront.mp4...
#
#  Video Processed: M138_light_left_neutral_camera_rightfront.mp4
#     Faces Extracted: 350
#     Optical Flow Maps: 350
#     Edge Maps: 350
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W036\light_rightdown\neutral\camera_left\W036_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: W036_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M123\light_left\neutral\camera_front\M123_light_left_neutral_camera_front.mp4...
#
#  Video Processed: M123_light_left_neutral_camera_front.mp4
#     Faces Extracted: 149
#     Optical Flow Maps: 149
#     Edge Maps: 149
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W041\light_uniform\neutral\camera_down\W041_light_uniform_neutral_camera_down.mp4...
#
#  Video Processed: W041_light_uniform_neutral_camera_down.mp4
#     Faces Extracted: 244
#     Optical Flow Maps: 244
#     Edge Maps: 244
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M039\light_uniform\neutral\camera_rightfront\M039_light_uniform_neutral_camera_rightfront.mp4...
#
#  Video Processed: M039_light_uniform_neutral_camera_rightfront.mp4
#     Faces Extracted: 216
#     Optical Flow Maps: 216
#     Edge Maps: 216
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M025\light_left\neutral\camera_leftfront\M025_light_left_neutral_camera_leftfront.mp4...
#
#  Video Processed: M025_light_left_neutral_camera_leftfront.mp4
#     Faces Extracted: 331
#     Optical Flow Maps: 331
#     Edge Maps: 331
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M039\light_up\neutral\camera_up\M039_light_up_neutral_camera_up.mp4...
#
#  Video Processed: M039_light_up_neutral_camera_up.mp4
#     Faces Extracted: 202
#     Optical Flow Maps: 202
#     Edge Maps: 202
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M119\light_leftup\neutral\camera_rightfront\M119_light_leftup_neutral_camera_rightfront.mp4...
#
#  Video Processed: M119_light_leftup_neutral_camera_rightfront.mp4
#     Faces Extracted: 60
#     Optical Flow Maps: 60
#     Edge Maps: 60
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_leftup\neutral\camera_right\W015_light_leftup_neutral_camera_right.mp4...
#
#  Video Processed: W015_light_leftup_neutral_camera_right.mp4
#     Faces Extracted: 32
#     Optical Flow Maps: 32
#     Edge Maps: 32
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W131\light_rightdown\neutral\camera_right\W131_light_rightdown_neutral_camera_right.mp4...
#
#  Video Processed: W131_light_rightdown_neutral_camera_right.mp4
#     Faces Extracted: 405
#     Optical Flow Maps: 405
#     Edge Maps: 405
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W005\light_up\neutral\camera_down\W005_light_up_neutral_camera_down.mp4...
#
#  Video Processed: W005_light_up_neutral_camera_down.mp4
#     Faces Extracted: 210
#     Optical Flow Maps: 210
#     Edge Maps: 210
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M018\light_up\neutral\camera_right\M018_light_up_neutral_camera_right.mp4...
#
#  Video Processed: M018_light_up_neutral_camera_right.mp4
#     Faces Extracted: 145
#     Optical Flow Maps: 145
#     Edge Maps: 145
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M124\light_up\neutral\camera_leftfront\M124_light_up_neutral_camera_leftfront.mp4...
#
#  Video Processed: M124_light_up_neutral_camera_leftfront.mp4
#     Faces Extracted: 245
#     Optical Flow Maps: 245
#     Edge Maps: 245
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M030\light_right\neutral\camera_up\M030_light_right_neutral_camera_up.mp4...
#
#  Video Processed: M030_light_right_neutral_camera_up.mp4
#     Faces Extracted: 20
#     Optical Flow Maps: 20
#     Edge Maps: 20
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W026\light_rightdown\neutral\camera_front\W026_light_rightdown_neutral_camera_front.mp4...
#
#  Video Processed: W026_light_rightdown_neutral_camera_front.mp4
#     Faces Extracted: 95
#     Optical Flow Maps: 95
#     Edge Maps: 95
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M016\light_leftup\neutral\camera_leftfront\M016_light_leftup_neutral_camera_leftfront.mp4...
#
#  Video Processed: M016_light_leftup_neutral_camera_leftfront.mp4
#     Faces Extracted: 122
#     Optical Flow Maps: 122
#     Edge Maps: 122
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_down\neutral\camera_front\M136_light_down_neutral_camera_front.mp4...
#
#  Video Processed: M136_light_down_neutral_camera_front.mp4
#     Faces Extracted: 412
#     Optical Flow Maps: 412
#     Edge Maps: 412
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M029\light_uniform\neutral\camera_up\M029_light_uniform_neutral_camera_up.mp4...
#
#  Video Processed: M029_light_uniform_neutral_camera_up.mp4
#     Faces Extracted: 194
#     Optical Flow Maps: 194
#     Edge Maps: 194
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W116\light_rightdown\neutral\camera_left\W116_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: W116_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M137\light_rightup\neutral\camera_up\M137_light_rightup_neutral_camera_up.mp4...
#
#  Video Processed: M137_light_rightup_neutral_camera_up.mp4
#     Faces Extracted: 393
#     Optical Flow Maps: 393
#     Edge Maps: 393
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W015\light_uniform\neutral\camera_left\W015_light_uniform_neutral_camera_left.mp4...
#
#  Video Processed: W015_light_uniform_neutral_camera_left.mp4
#     Faces Extracted: 209
#     Optical Flow Maps: 209
#     Edge Maps: 209
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M027\light_rightdown\neutral\camera_down\M027_light_rightdown_neutral_camera_down.mp4...
#
#  Video Processed: M027_light_rightdown_neutral_camera_down.mp4
#     Faces Extracted: 5
#     Optical Flow Maps: 5
#     Edge Maps: 5
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_leftup\neutral\camera_leftfront\M004_light_leftup_neutral_camera_leftfront.mp4...
#
#  Video Processed: M004_light_leftup_neutral_camera_leftfront.mp4
#     Faces Extracted: 301
#     Optical Flow Maps: 301
#     Edge Maps: 301
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M114\light_uniform\neutral\camera_right\M114_light_uniform_neutral_camera_right.mp4...
#
#  Video Processed: M114_light_uniform_neutral_camera_right.mp4
#     Faces Extracted: 202
#     Optical Flow Maps: 202
#     Edge Maps: 202
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M114\light_up\neutral\camera_right\M114_light_up_neutral_camera_right.mp4...
#
#  Video Processed: M114_light_up_neutral_camera_right.mp4
#     Faces Extracted: 220
#     Optical Flow Maps: 220
#     Edge Maps: 220
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M115\light_left\neutral\camera_leftfront\M115_light_left_neutral_camera_leftfront.mp4...
#
#  Video Processed: M115_light_left_neutral_camera_leftfront.mp4
#     Faces Extracted: 255
#     Optical Flow Maps: 255
#     Edge Maps: 255
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_right\neutral\camera_up\M004_light_right_neutral_camera_up.mp4...
#
#  Video Processed: M004_light_right_neutral_camera_up.mp4
#     Faces Extracted: 40
#     Optical Flow Maps: 40
#     Edge Maps: 40
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W110\light_up\neutral\camera_right\W110_light_up_neutral_camera_right.mp4...
#
#  Video Processed: W110_light_up_neutral_camera_right.mp4
#     Faces Extracted: 117
#     Optical Flow Maps: 117
#     Edge Maps: 117
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M028\light_rightdown\neutral\camera_left\M028_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: M028_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 103
#     Optical Flow Maps: 103
#     Edge Maps: 103
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_rightdown\neutral\camera_right\M021_light_rightdown_neutral_camera_right.mp4...
#
#  Video Processed: M021_light_rightdown_neutral_camera_right.mp4
#     Faces Extracted: 16
#     Optical Flow Maps: 16
#     Edge Maps: 16
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W133\light_leftdown\neutral\camera_right\W133_light_leftdown_neutral_camera_right.mp4...
#
#  Video Processed: W133_light_leftdown_neutral_camera_right.mp4
#     Faces Extracted: 5
#     Optical Flow Maps: 5
#     Edge Maps: 5
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M134\light_leftdown\neutral\camera_up\M134_light_leftdown_neutral_camera_up.mp4...
#
#  Video Processed: M134_light_leftdown_neutral_camera_up.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W016\light_leftdown\neutral\camera_left\W016_light_leftdown_neutral_camera_left.mp4...
#
#  Video Processed: W016_light_leftdown_neutral_camera_left.mp4
#     Faces Extracted: 140
#     Optical Flow Maps: 140
#     Edge Maps: 140
# ==================================================
# ...
#
#  Video Processed: M141_light_right_neutral_camera_front.mp4
#     Faces Extracted: 320
#     Optical Flow Maps: 320
#     Edge Maps: 320
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M034\light_up\neutral\camera_down\M034_light_up_neutral_camera_down.mp4...
#
#  Video Processed: M034_light_up_neutral_camera_down.mp4
#     Faces Extracted: 210
#     Optical Flow Maps: 210
#     Edge Maps: 210
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_rightdown\neutral\camera_leftfront\W023_light_rightdown_neutral_camera_leftfront.mp4...
#
#  Video Processed: W023_light_rightdown_neutral_camera_leftfront.mp4
#     Faces Extracted: 240
#     Optical Flow Maps: 240
#     Edge Maps: 240
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W110\light_left\neutral\camera_rightfront\W110_light_left_neutral_camera_rightfront.mp4...
#
#  Video Processed: W110_light_left_neutral_camera_rightfront.mp4
#     Faces Extracted: 220
#     Optical Flow Maps: 220
#     Edge Maps: 220
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W022\light_rightdown\neutral\camera_rightfront\W022_light_rightdown_neutral_camera_rightfront.mp4...
#
#  Video Processed: W022_light_rightdown_neutral_camera_rightfront.mp4
#     Faces Extracted: 223
#     Optical Flow Maps: 223
#     Edge Maps: 223
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M023\light_rightdown\neutral\camera_up\M023_light_rightdown_neutral_camera_up.mp4...
#
#  Video Processed: M023_light_rightdown_neutral_camera_up.mp4
#     Faces Extracted: 303
#     Optical Flow Maps: 303
#     Edge Maps: 303
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W025\light_rightdown\neutral\camera_down\W025_light_rightdown_neutral_camera_down.mp4...
#
#  Video Processed: W025_light_rightdown_neutral_camera_down.mp4
#     Faces Extracted: 79
#     Optical Flow Maps: 79
#     Edge Maps: 79
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W040\light_rightdown\neutral\camera_left\W040_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: W040_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 6
#     Optical Flow Maps: 6
#     Edge Maps: 6
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M010\light_down\neutral\camera_front\M010_light_down_neutral_camera_front.mp4...
#
#  Video Processed: M010_light_down_neutral_camera_front.mp4
#     Faces Extracted: 171
#     Optical Flow Maps: 171
#     Edge Maps: 171
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M136\light_down\neutral\camera_right\M136_light_down_neutral_camera_right.mp4...
#
#  Video Processed: M136_light_down_neutral_camera_right.mp4
#     Faces Extracted: 412
#     Optical Flow Maps: 412
#     Edge Maps: 412
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M018\light_right\neutral\camera_rightfront\M018_light_right_neutral_camera_rightfront.mp4...
#
#  Video Processed: M018_light_right_neutral_camera_rightfront.mp4
#     Faces Extracted: 114
#     Optical Flow Maps: 114
#     Edge Maps: 114
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M122\light_leftdown\neutral\camera_up\M122_light_leftdown_neutral_camera_up.mp4...
#
#  Video Processed: M122_light_leftdown_neutral_camera_up.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M132\light_leftup\neutral\camera_left\M132_light_leftup_neutral_camera_left.mp4...
#
#  Video Processed: M132_light_leftup_neutral_camera_left.mp4
#     Faces Extracted: 380
#     Optical Flow Maps: 380
#     Edge Maps: 380
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M133\light_rightup\neutral\camera_up\M133_light_rightup_neutral_camera_up.mp4...
#
#  Video Processed: M133_light_rightup_neutral_camera_up.mp4
#     Faces Extracted: 372
#     Optical Flow Maps: 372
#     Edge Maps: 372
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M039\light_leftup\neutral\camera_leftfront\M039_light_leftup_neutral_camera_leftfront.mp4...
#
#  Video Processed: M039_light_leftup_neutral_camera_leftfront.mp4
#     Faces Extracted: 178
#     Optical Flow Maps: 178
#     Edge Maps: 178
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W023\light_up\neutral\camera_down\W023_light_up_neutral_camera_down.mp4...
#
#  Video Processed: W023_light_up_neutral_camera_down.mp4
#     Faces Extracted: 252
#     Optical Flow Maps: 252
#     Edge Maps: 252
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W035\light_rightup\neutral\camera_left\W035_light_rightup_neutral_camera_left.mp4...
#
#  Video Processed: W035_light_rightup_neutral_camera_left.mp4
#     Faces Extracted: 14
#     Optical Flow Maps: 14
#     Edge Maps: 14
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W125\light_uniform\neutral\camera_up\W125_light_uniform_neutral_camera_up.mp4...
#
#  Video Processed: W125_light_uniform_neutral_camera_up.mp4
#     Faces Extracted: 194
#     Optical Flow Maps: 194
#     Edge Maps: 194
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M027\light_rightdown\neutral\camera_left\M027_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: M027_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W134\light_rightup\neutral\camera_front\W134_light_rightup_neutral_camera_front.mp4...
#
#  Video Processed: W134_light_rightup_neutral_camera_front.mp4
#     Faces Extracted: 379
#     Optical Flow Maps: 379
#     Edge Maps: 379
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W132\light_rightdown\neutral\camera_right\W132_light_rightdown_neutral_camera_right.mp4...
#
#  Video Processed: W132_light_rightdown_neutral_camera_right.mp4
#     Faces Extracted: 403
#     Optical Flow Maps: 403
#     Edge Maps: 403
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M114\light_right\neutral\camera_down\M114_light_right_neutral_camera_down.mp4...
#
#  Video Processed: M114_light_right_neutral_camera_down.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M004\light_uniform\neutral\camera_up\M004_light_uniform_neutral_camera_up.mp4...
#
#  Video Processed: M004_light_uniform_neutral_camera_up.mp4
#     Faces Extracted: 315
#     Optical Flow Maps: 315
#     Edge Maps: 315
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W006\light_down\neutral\camera_up\W006_light_down_neutral_camera_up.mp4...
#
#  Video Processed: W006_light_down_neutral_camera_up.mp4
#     Faces Extracted: 180
#     Optical Flow Maps: 180
#     Edge Maps: 180
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M139\light_left\neutral\camera_down\M139_light_left_neutral_camera_down.mp4...
#
#  Video Processed: M139_light_left_neutral_camera_down.mp4
#     Faces Extracted: 65
#     Optical Flow Maps: 65
#     Edge Maps: 65
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W135\light_right\neutral\camera_left\W135_light_right_neutral_camera_left.mp4...
#
#  Video Processed: W135_light_right_neutral_camera_left.mp4
#     Faces Extracted: 180
#     Optical Flow Maps: 180
#     Edge Maps: 180
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M137\light_up\neutral\camera_leftfront\M137_light_up_neutral_camera_leftfront.mp4...
#
#  Video Processed: M137_light_up_neutral_camera_leftfront.mp4
#     Faces Extracted: 399
#     Optical Flow Maps: 399
#     Edge Maps: 399
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M027\light_leftup\neutral\camera_front\M027_light_leftup_neutral_camera_front.mp4...
#
#  Video Processed: M027_light_leftup_neutral_camera_front.mp4
#     Faces Extracted: 301
#     Optical Flow Maps: 301
#     Edge Maps: 301
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M121\light_left\neutral\camera_leftfront\M121_light_left_neutral_camera_leftfront.mp4...
#
#  Video Processed: M121_light_left_neutral_camera_leftfront.mp4
#     Faces Extracted: 247
#     Optical Flow Maps: 247
#     Edge Maps: 247
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M117\light_right\neutral\camera_up\M117_light_right_neutral_camera_up.mp4...
#
#  Video Processed: M117_light_right_neutral_camera_up.mp4
#     Faces Extracted: 134
#     Optical Flow Maps: 134
#     Edge Maps: 134
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M021\light_down\neutral\camera_down\M021_light_down_neutral_camera_down.mp4...
#
#  Video Processed: M021_light_down_neutral_camera_down.mp4
#     Faces Extracted: 0
#     Optical Flow Maps: 0
#     Edge Maps: 0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W111\light_down\neutral\camera_front\W111_light_down_neutral_camera_front.mp4...
#
#  Video Processed: W111_light_down_neutral_camera_front.mp4
#     Faces Extracted: 196
#     Optical Flow Maps: 196
#     Edge Maps: 196
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M026\light_up\neutral\camera_left\M026_light_up_neutral_camera_left.mp4...
#
#  Video Processed: M026_light_up_neutral_camera_left.mp4
#     Faces Extracted: 161
#     Optical Flow Maps: 161
#     Edge Maps: 161
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M120\light_right\neutral\camera_leftfront\M120_light_right_neutral_camera_leftfront.mp4...
#
#  Video Processed: M120_light_right_neutral_camera_leftfront.mp4
#     Faces Extracted: 197
#     Optical Flow Maps: 197
#     Edge Maps: 197
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W125\light_leftup\neutral\camera_front\W125_light_leftup_neutral_camera_front.mp4...
#
#  Video Processed: W125_light_leftup_neutral_camera_front.mp4
#     Faces Extracted: 219
#     Optical Flow Maps: 219
#     Edge Maps: 219
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W024\light_left\neutral\camera_rightfront\W024_light_left_neutral_camera_rightfront.mp4...
#
#  Video Processed: W024_light_left_neutral_camera_rightfront.mp4
#     Faces Extracted: 242
#     Optical Flow Maps: 242
#     Edge Maps: 242
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W006\light_rightdown\neutral\camera_right\W006_light_rightdown_neutral_camera_right.mp4...
#
#  Video Processed: W006_light_rightdown_neutral_camera_right.mp4
#     Faces Extracted: 216
#     Optical Flow Maps: 216
#     Edge Maps: 216
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W032\light_rightdown\neutral\camera_leftfront\W032_light_rightdown_neutral_camera_leftfront.mp4...
#
#  Video Processed: W032_light_rightdown_neutral_camera_leftfront.mp4
#     Faces Extracted: 177
#     Optical Flow Maps: 177
#     Edge Maps: 177
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M016\light_uniform\neutral\camera_right\M016_light_uniform_neutral_camera_right.mp4...
#
#  Video Processed: M016_light_uniform_neutral_camera_right.mp4
#     Faces Extracted: 131
#     Optical Flow Maps: 131
#     Edge Maps: 131
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M022\light_rightdown\neutral\camera_left\M022_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: M022_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 207
#     Optical Flow Maps: 207
#     Edge Maps: 207
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M012\light_leftdown\neutral\camera_leftfront\M012_light_leftdown_neutral_camera_leftfront.mp4...
#
#  Video Processed: M012_light_leftdown_neutral_camera_leftfront.mp4
#     Faces Extracted: 171
#     Optical Flow Maps: 171
#     Edge Maps: 171
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M133\light_left\neutral\camera_down\M133_light_left_neutral_camera_down.mp4...
#
#  Video Processed: M133_light_left_neutral_camera_down.mp4
#     Faces Extracted: 306
#     Optical Flow Maps: 306
#     Edge Maps: 306
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M133\light_rightdown\neutral\camera_left\M133_light_rightdown_neutral_camera_left.mp4...
#
#  Video Processed: M133_light_rightdown_neutral_camera_left.mp4
#     Faces Extracted: 125
#     Optical Flow Maps: 125
#     Edge Maps: 125
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\W009\light_leftdown\neutral\camera_left\W009_light_leftdown_neutral_camera_left.mp4...
#
#  Video Processed: W009_light_leftdown_neutral_camera_left.mp4
#     Faces Extracted: 215
#     Optical Flow Maps: 215
#     Edge Maps: 215
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/source_videos\M140\light_right\neutral\camera_up\M140_light_right_neutral_camera_up.mp4...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 159
#     155         process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir)
#     158 # Process real videos (source_videos) but only if 'neutral' is in the path
# --> 159 traverse_and_process(real_videos_dir, output_real_faces, output_optical_flow, output_edges, check_neutral=True)
#     161 print("\nProcessing complete!")
#
# Cell In[9], line 155, in traverse_and_process(root_dir, save_faces_dir, save_flow_dir, save_edges_dir, check_neutral)
#     152     continue
#     154 print(f"Processing {video_path}...")
# --> 155 process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir)
#
# Cell In[9], line 87, in process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir)
#      85 # Compute optical flow and crop to face region
#      86 if prev_frame is not None:
# ---> 87     flow_map = compute_dense_optical_flow(prev_frame, frame)
#      88     flow_crop = flow_map[y1:y2, x1:x2]
#      89     if flow_crop.shape[0] > 0 and flow_crop.shape[1] > 0:
#
# Cell In[9], line 22, in compute_dense_optical_flow(prev_frame, next_frame)
#      19 prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
#      20 next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)
# ---> 22 flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
#      23 magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1])
#      25 hsv = np.zeros_like(prev_frame)
#
# KeyboardInterrupt:
