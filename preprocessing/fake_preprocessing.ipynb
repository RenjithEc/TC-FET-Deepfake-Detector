# %%
import os
import cv2
import dlib
import numpy as np

# %%
import os
import cv2
import dlib
import numpy as np

# Paths for input and output
fake_videos_dir = "F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end"

output_fake_faces = "E:/dataset_1/happy/fake"
output_optical_flow = "E:/dataset_1/happy/optical_flow"
output_edges = "E:/dataset_1/happy/edges"

# Create directories if not exist
for path in [output_fake_faces, output_optical_flow, output_edges]:
    os.makedirs(path, exist_ok=True)

# Load face detector
detector = dlib.get_frontal_face_detector()
predictor_path = "D:/school/Research/TC-FET-Deepfake-Detector/preprocessing/shape_predictor_68_face_landmarks.dat"  
predictor = dlib.shape_predictor(predictor_path)

def compute_dense_optical_flow(prev_frame, next_frame):
    """Computes dense optical flow and converts it into an RGB representation."""
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)

    flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
    magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    
    hsv = np.zeros_like(prev_frame)
    hsv[..., 1] = 255
    hsv[..., 0] = angle * 180 / np.pi / 2
    hsv[..., 2] = cv2.normalize(magnitude, None, 0, 255, cv2.NORM_MINMAX)

    return cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

def extract_edges(frame):
    """Extracts edges from a frame using the Canny edge detection method."""
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)
    return cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

def process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir):
    """Extracts faces and ensures optical flow and edge maps match the face frames."""
    folder_name = os.path.basename(os.path.dirname(video_path))  # Get folder name for naming
    cap = cv2.VideoCapture(video_path)
    ret, prev_frame = cap.read()
    frame_count = 0

    # Counters for statistics
    face_count = 0
    flow_count = 0
    edge_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = detector(gray)

        if faces:  # Only process optical flow and edges if a face is found
            for i, face in enumerate(faces):
                landmarks = predictor(gray, face)
                interocular_distance = landmarks.part(42).x - landmarks.part(39).x

                x, y, w, h = face.left(), face.top(), face.width(), face.height()
                size = 5 * interocular_distance  # Increase bounding box size

                x1 = max(0, x - size)
                y1 = max(0, y - size)
                x2 = min(frame.shape[1], x + size)
                y2 = min(frame.shape[0], y + size)

                face_crop = frame[y1:y2, x1:x2]

                if face_crop.shape[0] > 0 and face_crop.shape[1] > 0:  # Ensure valid cropping
                    face_resized = cv2.resize(face_crop, (299, 299))

                    filename_base = f"{folder_name}_{os.path.basename(video_path)}_frame{frame_count}_face{i}"
                    filename_face = f"{filename_base}.jpg"
                    filename_flow = f"{filename_base}_flow.jpg"
                    filename_edges = f"{filename_base}_edges.jpg"

                    # Save face
                    cv2.imwrite(os.path.join(save_faces_dir, filename_face), face_resized)
                    face_count += 1

                    # Compute optical flow and crop to face region
                    if prev_frame is not None:
                        flow_map = compute_dense_optical_flow(prev_frame, frame)
                        flow_crop = flow_map[y1:y2, x1:x2]
                        if flow_crop.shape[0] > 0 and flow_crop.shape[1] > 0:
                            flow_resized = cv2.resize(flow_crop, (299, 299))
                            cv2.imwrite(os.path.join(save_flow_dir, filename_flow), flow_resized)
                            flow_count += 1

                    # Compute edges and crop to face region
                    edge_map = extract_edges(frame)
                    edge_crop = edge_map[y1:y2, x1:x2]
                    if edge_crop.shape[0] > 0 and edge_crop.shape[1] > 0:
                        edge_resized = cv2.resize(edge_crop, (299, 299))
                        cv2.imwrite(os.path.join(save_edges_dir, filename_edges), edge_resized)
                        edge_count += 1

        prev_frame = frame
        frame_count += 1

    cap.release()

    # Print statistics for this video
    print(f"\n Video Processed: {os.path.basename(video_path)}")
    print(f"    Faces Extracted: {face_count}")
    print(f"    Optical Flow Maps: {flow_count}")
    print(f"    Edge Maps: {edge_count}")
    print("=" * 50)

def traverse_and_process(root_dir, save_faces_dir, save_flow_dir, save_edges_dir, check_happy=False):
    """Traverses folders recursively, filtering based on 'happy' if required, and skips already processed videos."""
    for root, _, files in os.walk(root_dir):
        if check_happy and "happy" not in root.lower():
            continue  # Skip this folder if 'happy' is not in its path
        # if check_happy and all(w not in root.lower() for w in ["w0", "w1"]):
        #     continue  # Skip this folder if 'w0' || 'w1' is not in its path
        
        for file in files:
            if file.endswith(".mp4") or file.endswith(".avi"):
                video_path = os.path.join(root, file)
                folder_name = os.path.basename(root)
                
                # Generate expected output filenames
                base_filename = f"{folder_name}_{file}_frame"
                
                # Check if at least one output exists
                processed = any(
                    filename.startswith(base_filename) 
                    for directory in [save_faces_dir, save_flow_dir, save_edges_dir] 
                    for filename in os.listdir(directory)
                )

                if processed:
                    print(f"Skipping {video_path} (already processed)")
                    continue

                print(f"Processing {video_path}...")
                process_video(video_path, save_faces_dir, save_flow_dir, save_edges_dir)

# Process fake videos (manipulated_videos) but only if 'happy' is in the path
traverse_and_process(fake_videos_dir, output_fake_faces, output_optical_flow, output_edges, check_happy=False)

print("\nProcessing complete!")
# Out:
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\711_M007.mp4...
#
#  Video Processed: 711_M007.mp4
#     Faces Extracted: 291
#     Optical Flow Maps: 291
#     Edge Maps: 291
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\023_M113.mp4...
#
#  Video Processed: 023_M113.mp4
#     Faces Extracted: 552
#     Optical Flow Maps: 552
#     Edge Maps: 552
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\759_W025.mp4...
#
#  Video Processed: 759_W025.mp4
#     Faces Extracted: 855
#     Optical Flow Maps: 855
#     Edge Maps: 855
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\952_W101.mp4...
#
#  Video Processed: 952_W101.mp4
#     Faces Extracted: 699
#     Optical Flow Maps: 699
#     Edge Maps: 699
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\351_M023.mp4...
#
#  Video Processed: 351_M023.mp4
#     Faces Extracted: 683
#     Optical Flow Maps: 683
#     Edge Maps: 683
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\837_W037.mp4...
#
#  Video Processed: 837_W037.mp4
#     Faces Extracted: 442
#     Optical Flow Maps: 442
#     Edge Maps: 442
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\974_M038.mp4...
#
#  Video Processed: 974_M038.mp4
#     Faces Extracted: 321
#     Optical Flow Maps: 321
#     Edge Maps: 321
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\092_M120.mp4...
#
#  Video Processed: 092_M120.mp4
#     Faces Extracted: 459
#     Optical Flow Maps: 459
#     Edge Maps: 459
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\503_W134.mp4...
#
#  Video Processed: 503_W134.mp4
#     Faces Extracted: 673
#     Optical Flow Maps: 673
#     Edge Maps: 673
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\436_W022.mp4...
#
#  Video Processed: 436_W022.mp4
#     Faces Extracted: 517
#     Optical Flow Maps: 517
#     Edge Maps: 517
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\816_W135.mp4...
#
#  Video Processed: 816_W135.mp4
#     Faces Extracted: 410
#     Optical Flow Maps: 410
#     Edge Maps: 410
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\591_M118.mp4...
#
#  Video Processed: 591_M118.mp4
#     Faces Extracted: 540
#     Optical Flow Maps: 540
#     Edge Maps: 540
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\967_W008.mp4...
#
#  Video Processed: 967_W008.mp4
#     Faces Extracted: 411
#     Optical Flow Maps: 411
#     Edge Maps: 411
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\050_M115.mp4...
#
#  Video Processed: 050_M115.mp4
#     Faces Extracted: 529
#     Optical Flow Maps: 529
#     Edge Maps: 529
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\536_W037.mp4...
#
#  Video Processed: 536_W037.mp4
#     Faces Extracted: 602
#     Optical Flow Maps: 602
#     Edge Maps: 602
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\270_M015.mp4...
#
#  Video Processed: 270_M015.mp4
#     Faces Extracted: 310
#     Optical Flow Maps: 310
#     Edge Maps: 310
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\059_M118.mp4...
#
#  Video Processed: 059_M118.mp4
#     Faces Extracted: 720
#     Optical Flow Maps: 720
#     Edge Maps: 720
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\451_M138.mp4...
#
#  Video Processed: 451_M138.mp4
#     Faces Extracted: 382
#     Optical Flow Maps: 382
#     Edge Maps: 382
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\467_W027.mp4...
#
#  Video Processed: 467_W027.mp4
#     Faces Extracted: 408
#     Optical Flow Maps: 408
#     Edge Maps: 408
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\851_M022.mp4...
#
#  Video Processed: 851_M022.mp4
#     Faces Extracted: 832
#     Optical Flow Maps: 832
#     Edge Maps: 832
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\543_M141.mp4...
#
#  Video Processed: 543_M141.mp4
#     Faces Extracted: 717
#     Optical Flow Maps: 717
#     Edge Maps: 717
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\814_W134.mp4...
#
#  Video Processed: 814_W134.mp4
#     Faces Extracted: 549
#     Optical Flow Maps: 549
#     Edge Maps: 549
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\231_W136.mp4...
#
#  Video Processed: 231_W136.mp4
#     Faces Extracted: 572
#     Optical Flow Maps: 572
#     Edge Maps: 572
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\038_W009.mp4...
#
#  Video Processed: 038_W009.mp4
#     Faces Extracted: 298
#     Optical Flow Maps: 298
#     Edge Maps: 298
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\904_W111.mp4...
#
#  Video Processed: 904_W111.mp4
#     Faces Extracted: 378
#     Optical Flow Maps: 378
#     Edge Maps: 378
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\326_M021.mp4...
#
#  Video Processed: 326_M021.mp4
#     Faces Extracted: 913
#     Optical Flow Maps: 913
#     Edge Maps: 913
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\161_W027.mp4...
#
#  Video Processed: 161_W027.mp4
#     Faces Extracted: 368
#     Optical Flow Maps: 368
#     Edge Maps: 368
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\377_M026.mp4...
#
#  Video Processed: 377_M026.mp4
#     Faces Extracted: 397
#     Optical Flow Maps: 397
#     Edge Maps: 397
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\955_M138.mp4...
#
#  Video Processed: 955_M138.mp4
#     Faces Extracted: 530
#     Optical Flow Maps: 530
#     Edge Maps: 530
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\758_W025.mp4...
#
#  Video Processed: 758_W025.mp4
#     Faces Extracted: 390
#     Optical Flow Maps: 390
#     Edge Maps: 390
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\673_W013.mp4...
#
#  Video Processed: 673_W013.mp4
#     Faces Extracted: 1182
#     Optical Flow Maps: 1182
#     Edge Maps: 1182
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\667_W005.mp4...
#
#  Video Processed: 667_W005.mp4
#     Faces Extracted: 468
#     Optical Flow Maps: 468
#     Edge Maps: 468
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\357_M024.mp4...
#
#  Video Processed: 357_M024.mp4
#     Faces Extracted: 690
#     Optical Flow Maps: 690
#     Edge Maps: 690
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\205_W135.mp4...
#
#  Video Processed: 205_W135.mp4
#     Faces Extracted: 306
#     Optical Flow Maps: 306
#     Edge Maps: 306
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\912_M031.mp4...
#
#  Video Processed: 912_M031.mp4
#     Faces Extracted: 646
#     Optical Flow Maps: 646
#     Edge Maps: 646
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\111_M123.mp4...
#
#  Video Processed: 111_M123.mp4
#     Faces Extracted: 432
#     Optical Flow Maps: 432
#     Edge Maps: 432
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\304_M019.mp4...
#
#  Video Processed: 304_M019.mp4
#     Faces Extracted: 609
#     Optical Flow Maps: 609
#     Edge Maps: 609
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\317_W006.mp4...
#
#  Video Processed: 317_W006.mp4
#     Faces Extracted: 681
#     Optical Flow Maps: 681
#     Edge Maps: 681
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\350_W131.mp4...
#
#  Video Processed: 350_W131.mp4
#     Faces Extracted: 404
#     Optical Flow Maps: 404
#     Edge Maps: 404
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\683_W014.mp4...
#
#  Video Processed: 683_W014.mp4
#     Faces Extracted: 301
#     Optical Flow Maps: 301
#     Edge Maps: 301
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\025_W007.mp4...
#
#  Video Processed: 025_W007.mp4
#     Faces Extracted: 746
#     Optical Flow Maps: 746
#     Edge Maps: 746
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\330_W008.mp4...
#
#  Video Processed: 330_W008.mp4
#     Faces Extracted: 406
#     Optical Flow Maps: 406
#     Edge Maps: 406
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\979_M038.mp4...
#
#  Video Processed: 979_M038.mp4
#     Faces Extracted: 334
#     Optical Flow Maps: 334
#     Edge Maps: 334
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\844_M134.mp4...
#
#  Video Processed: 844_M134.mp4
#     Faces Extracted: 851
#     Optical Flow Maps: 851
#     Edge Maps: 851
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\259_M014.mp4...
#
#  Video Processed: 259_M014.mp4
#     Faces Extracted: 443
#     Optical Flow Maps: 443
#     Edge Maps: 443
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\854_M022.mp4...
#
#  Video Processed: 854_M022.mp4
#     Faces Extracted: 293
#     Optical Flow Maps: 293
#     Edge Maps: 293
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\568_M114.mp4...
#
#  Video Processed: 568_M114.mp4
#     Faces Extracted: 569
#     Optical Flow Maps: 569
#     Edge Maps: 569
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\470_M139.mp4...
#
#  Video Processed: 470_M139.mp4
#     Faces Extracted: 904
#     Optical Flow Maps: 904
#     Edge Maps: 904
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\356_M024.mp4...
#
#  Video Processed: 356_M024.mp4
#     Faces Extracted: 837
#     Optical Flow Maps: 837
#     Edge Maps: 837
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\869_W040.mp4...
#
#  Video Processed: 869_W040.mp4
#     Faces Extracted: 1453
#     Optical Flow Maps: 1453
#     Edge Maps: 1453
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\648_W009.mp4...
#
#  Video Processed: 648_W009.mp4
#     Faces Extracted: 470
#     Optical Flow Maps: 470
#     Edge Maps: 470
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\448_M034.mp4...
#
#  Video Processed: 448_M034.mp4
#     Faces Extracted: 527
#     Optical Flow Maps: 527
#     Edge Maps: 527
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\122_W021.mp4...
#
#  Video Processed: 122_W021.mp4
#     Faces Extracted: 308
#     Optical Flow Maps: 308
#     Edge Maps: 308
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\453_W024.mp4...
#
#  Video Processed: 453_W024.mp4
#     Faces Extracted: 644
#     Optical Flow Maps: 644
#     Edge Maps: 644
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\992_W012.mp4...
#
#  Video Processed: 992_W012.mp4
#     Faces Extracted: 717
#     Optical Flow Maps: 717
#     Edge Maps: 717
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\116_W132.mp4...
#
#  Video Processed: 116_W132.mp4
#     Faces Extracted: 327
#     Optical Flow Maps: 327
#     Edge Maps: 327
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\630_W006.mp4...
#
#  Video Processed: 630_W006.mp4
#     Faces Extracted: 424
#     Optical Flow Maps: 424
#     Edge Maps: 424
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\634_W007.mp4...
#
#  Video Processed: 634_W007.mp4
#     Faces Extracted: 337
#     Optical Flow Maps: 337
#     Edge Maps: 337
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\625_W006.mp4...
#
#  Video Processed: 625_W006.mp4
#     Faces Extracted: 331
#     Optical Flow Maps: 331
#     Edge Maps: 331
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\294_W100.mp4...
#
#  Video Processed: 294_W100.mp4
#     Faces Extracted: 603
#     Optical Flow Maps: 603
#     Edge Maps: 603
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\214_W035.mp4...
#
#  Video Processed: 214_W035.mp4
#     Faces Extracted: 461
#     Optical Flow Maps: 461
#     Edge Maps: 461
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\586_W111.mp4...
#
#  Video Processed: 586_W111.mp4
#     Faces Extracted: 384
#     Optical Flow Maps: 384
#     Edge Maps: 384
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\942_M137.mp4...
#
#  Video Processed: 942_M137.mp4
#     Faces Extracted: 494
#     Optical Flow Maps: 494
#     Edge Maps: 494
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\368_W005.mp4...
#
#  Video Processed: 368_W005.mp4
#     Faces Extracted: 760
#     Optical Flow Maps: 760
#     Edge Maps: 760
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\781_W029.mp4...
#
#  Video Processed: 781_W029.mp4
#     Faces Extracted: 474
#     Optical Flow Maps: 474
#     Edge Maps: 474
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\310_M019.mp4...
#
#  Video Processed: 310_M019.mp4
#     Faces Extracted: 374
#     Optical Flow Maps: 374
#     Edge Maps: 374
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\892_W110.mp4...
#
#  Video Processed: 892_W110.mp4
#     Faces Extracted: 310
#     Optical Flow Maps: 310
#     Edge Maps: 310
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\088_W016.mp4...
#
#  Video Processed: 088_W016.mp4
#     Faces Extracted: 664
#     Optical Flow Maps: 664
#     Edge Maps: 664
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\145_W025.mp4...
#
#  Video Processed: 145_W025.mp4
#     Faces Extracted: 521
#     Optical Flow Maps: 521
#     Edge Maps: 521
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\288_W125.mp4...
#
#  Video Processed: 288_W125.mp4
#     Faces Extracted: 542
#     Optical Flow Maps: 542
#     Edge Maps: 542
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\888_M027.mp4...
#
#  Video Processed: 888_M027.mp4
#     Faces Extracted: 306
#     Optical Flow Maps: 306
#     Edge Maps: 306
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\406_W018.mp4...
#
#  Video Processed: 406_W018.mp4
#     Faces Extracted: 511
#     Optical Flow Maps: 511
#     Edge Maps: 511
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\831_W036.mp4...
#
#  Video Processed: 831_W036.mp4
#     Faces Extracted: 326
#     Optical Flow Maps: 326
#     Edge Maps: 326
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\725_W021.mp4...
#
#  Video Processed: 725_W021.mp4
#     Faces Extracted: 698
#     Optical Flow Maps: 698
#     Edge Maps: 698
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\983_W131.mp4...
#
#  Video Processed: 983_W131.mp4
#     Faces Extracted: 405
#     Optical Flow Maps: 405
#     Edge Maps: 405
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\784_W029.mp4...
#
#  Video Processed: 784_W029.mp4
#     Faces Extracted: 556
#     Optical Flow Maps: 556
#     Edge Maps: 556
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\114_M123.mp4...
#
#  Video Processed: 114_M123.mp4
#     Faces Extracted: 1268
#     Optical Flow Maps: 1268
#     Edge Maps: 1268
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\996_M039.mp4...
#
#  Video Processed: 996_M039.mp4
#     Faces Extracted: 311
#     Optical Flow Maps: 311
#     Edge Maps: 311
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\099_W018.mp4...
#
#  Video Processed: 099_W018.mp4
#     Faces Extracted: 612
#     Optical Flow Maps: 612
#     Edge Maps: 612
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\371_W013.mp4...
#
#  Video Processed: 371_W013.mp4
#     Faces Extracted: 717
#     Optical Flow Maps: 717
#     Edge Maps: 717
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\674_M131.mp4...
#
#  Video Processed: 674_M131.mp4
#     Faces Extracted: 366
#     Optical Flow Maps: 366
#     Edge Maps: 366
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\766_W027.mp4...
#
#  Video Processed: 766_W027.mp4
#     Faces Extracted: 859
#     Optical Flow Maps: 859
#     Edge Maps: 859
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\848_M021.mp4...
#
#  Video Processed: 848_M021.mp4
#     Faces Extracted: 360
#     Optical Flow Maps: 360
#     Edge Maps: 360
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\281_W116.mp4...
#
#  Video Processed: 281_W116.mp4
#     Faces Extracted: 308
#     Optical Flow Maps: 308
#     Edge Maps: 308
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\424_M031.mp4...
#
#  Video Processed: 424_M031.mp4
#     Faces Extracted: 310
#     Optical Flow Maps: 310
#     Edge Maps: 310
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\128_M124.mp4...
#
#  Video Processed: 128_M124.mp4
#     Faces Extracted: 726
#     Optical Flow Maps: 726
#     Edge Maps: 726
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\971_M138.mp4...
#
#  Video Processed: 971_M138.mp4
#     Faces Extracted: 353
#     Optical Flow Maps: 353
#     Edge Maps: 353
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\954_W101.mp4...
#
#  Video Processed: 954_W101.mp4
#     Faces Extracted: 375
#     Optical Flow Maps: 375
#     Edge Maps: 375
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\508_W135.mp4...
#
#  Video Processed: 508_W135.mp4
#     Faces Extracted: 602
#     Optical Flow Maps: 602
#     Edge Maps: 602
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\206_W135.mp4...
#
#  Video Processed: 206_W135.mp4
#     Faces Extracted: 713
#     Optical Flow Maps: 713
#     Edge Maps: 713
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\613_M120.mp4...
#
#  Video Processed: 613_M120.mp4
#     Faces Extracted: 414
#     Optical Flow Maps: 414
#     Edge Maps: 414
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\104_W018.mp4...
#
#  Video Processed: 104_W018.mp4
#     Faces Extracted: 461
#     Optical Flow Maps: 461
#     Edge Maps: 461
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\986_W131.mp4...
#
#  Video Processed: 986_W131.mp4
#     Faces Extracted: 827
#     Optical Flow Maps: 827
#     Edge Maps: 827
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\218_M011.mp4...
#
#  Video Processed: 218_M011.mp4
#     Faces Extracted: 352
#     Optical Flow Maps: 352
#     Edge Maps: 352
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\668_W005.mp4...
#
#  Video Processed: 668_W005.mp4
#     Faces Extracted: 397
#     Optical Flow Maps: 397
#     Edge Maps: 397
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\929_W116.mp4...
#
#  Video Processed: 929_W116.mp4
#     Faces Extracted: 461
#     Optical Flow Maps: 461
#     Edge Maps: 461
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\629_W006.mp4...
#
#  Video Processed: 629_W006.mp4
#     Faces Extracted: 973
#     Optical Flow Maps: 973
#     Edge Maps: 973
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\578_W110.mp4...
#
#  Video Processed: 578_W110.mp4
#     Faces Extracted: 563
#     Optical Flow Maps: 563
#     Edge Maps: 563
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\143_M132.mp4...
#
#  Video Processed: 143_M132.mp4
#     Faces Extracted: 413
#     Optical Flow Maps: 413
#     Edge Maps: 413
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\836_W037.mp4...
#
#  Video Processed: 836_W037.mp4
#     Faces Extracted: 342
#     Optical Flow Maps: 342
#     Edge Maps: 342
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\637_W008.mp4...
#
#  Video Processed: 637_W008.mp4
#     Faces Extracted: 509
#     Optical Flow Maps: 509
#     Edge Maps: 509
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\658_M124.mp4...
#
#  Video Processed: 658_M124.mp4
#     Faces Extracted: 403
#     Optical Flow Maps: 403
#     Edge Maps: 403
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\209_M010.mp4...
#
#  Video Processed: 209_M010.mp4
#     Faces Extracted: 336
#     Optical Flow Maps: 336
#     Edge Maps: 336
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\847_M021.mp4...
#
#  Video Processed: 847_M021.mp4
#     Faces Extracted: 300
#     Optical Flow Maps: 300
#     Edge Maps: 300
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\645_W009.mp4...
#
#  Video Processed: 645_W009.mp4
#     Faces Extracted: 555
#     Optical Flow Maps: 555
#     Edge Maps: 555
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\477_W029.mp4...
#
#  Video Processed: 477_W029.mp4
#     Faces Extracted: 364
#     Optical Flow Maps: 364
#     Edge Maps: 364
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\181_M007.mp4...
#
#  Video Processed: 181_M007.mp4
#     Faces Extracted: 477
#     Optical Flow Maps: 477
#     Edge Maps: 477
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\677_W013.mp4...
#
#  Video Processed: 677_W013.mp4
#     Faces Extracted: 313
#     Optical Flow Maps: 313
#     Edge Maps: 313
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\600_M118.mp4...
#
#  Video Processed: 600_M118.mp4
#     Faces Extracted: 387
#     Optical Flow Maps: 387
#     Edge Maps: 387
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\021_W007.mp4...
#
#  Video Processed: 021_W007.mp4
#     Faces Extracted: 430
#     Optical Flow Maps: 430
#     Edge Maps: 430
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\201_W134.mp4...
#
#  Video Processed: 201_W134.mp4
#     Faces Extracted: 862
#     Optical Flow Maps: 862
#     Edge Maps: 862
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\669_M124.mp4...
#
#  Video Processed: 669_M124.mp4
#     Faces Extracted: 488
#     Optical Flow Maps: 488
#     Edge Maps: 488
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\631_M121.mp4...
#
#  Video Processed: 631_M121.mp4
#     Faces Extracted: 423
#     Optical Flow Maps: 423
#     Edge Maps: 423
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\443_M137.mp4...
#
#  Video Processed: 443_M137.mp4
#     Faces Extracted: 1145
#     Optical Flow Maps: 1145
#     Edge Maps: 1145
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\086_W016.mp4...
#
#  Video Processed: 086_W016.mp4
#     Faces Extracted: 934
#     Optical Flow Maps: 934
#     Edge Maps: 934
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\686_W015.mp4...
#
#  Video Processed: 686_W015.mp4
#     Faces Extracted: 341
#     Optical Flow Maps: 341
#     Edge Maps: 341
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\922_M135.mp4...
#
#  Video Processed: 922_M135.mp4
#     Faces Extracted: 615
#     Optical Flow Maps: 615
#     Edge Maps: 615
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\774_M013.mp4...
#
#  Video Processed: 774_M013.mp4
#     Faces Extracted: 312
#     Optical Flow Maps: 312
#     Edge Maps: 312
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\510_M104.mp4...
#
#  Video Processed: 510_M104.mp4
#     Faces Extracted: 339
#     Optical Flow Maps: 339
#     Edge Maps: 339
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\134_W023.mp4...
#
#  Video Processed: 134_W023.mp4
#     Faces Extracted: 345
#     Optical Flow Maps: 345
#     Edge Maps: 345
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\715_M007.mp4...
#
#  Video Processed: 715_M007.mp4
#     Faces Extracted: 855
#     Optical Flow Maps: 855
#     Edge Maps: 855
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\352_M024.mp4...
#
#  Video Processed: 352_M024.mp4
#     Faces Extracted: 420
#     Optical Flow Maps: 420
#     Edge Maps: 420
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\426_W021.mp4...
#
#  Video Processed: 426_W021.mp4
#     Faces Extracted: 334
#     Optical Flow Maps: 334
#     Edge Maps: 334
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\978_W010.mp4...
#
#  Video Processed: 978_W010.mp4
#     Faces Extracted: 756
#     Optical Flow Maps: 756
#     Edge Maps: 756
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\627_M121.mp4...
#
#  Video Processed: 627_M121.mp4
#     Faces Extracted: 373
#     Optical Flow Maps: 373
#     Edge Maps: 373
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\282_W116.mp4...
#
#  Video Processed: 282_W116.mp4
#     Faces Extracted: 593
#     Optical Flow Maps: 593
#     Edge Maps: 593
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\765_W027.mp4...
#
#  Video Processed: 765_W027.mp4
#     Faces Extracted: 1093
#     Optical Flow Maps: 1093
#     Edge Maps: 1093
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\057_W012.mp4...
#
#  Video Processed: 057_W012.mp4
#     Faces Extracted: 430
#     Optical Flow Maps: 430
#     Edge Maps: 430
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\793_M015.mp4...
#
#  Video Processed: 793_M015.mp4
#     Faces Extracted: 589
#     Optical Flow Maps: 589
#     Edge Maps: 589
# ==================================================
# ...
#
#  Video Processed: 258_W110.mp4
#     Faces Extracted: 497
#     Optical Flow Maps: 497
#     Edge Maps: 497
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\262_W110.mp4...
#
#  Video Processed: 262_W110.mp4
#     Faces Extracted: 396
#     Optical Flow Maps: 396
#     Edge Maps: 396
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\404_M029.mp4...
#
#  Video Processed: 404_M029.mp4
#     Faces Extracted: 806
#     Optical Flow Maps: 806
#     Edge Maps: 806
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\737_M010.mp4...
#
#  Video Processed: 737_M010.mp4
#     Faces Extracted: 368
#     Optical Flow Maps: 368
#     Edge Maps: 368
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\980_W010.mp4...
#
#  Video Processed: 980_W010.mp4
#     Faces Extracted: 382
#     Optical Flow Maps: 382
#     Edge Maps: 382
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\264_W111.mp4...
#
#  Video Processed: 264_W111.mp4
#     Faces Extracted: 454
#     Optical Flow Maps: 454
#     Edge Maps: 454
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\353_M024.mp4...
#
#  Video Processed: 353_M024.mp4
#     Faces Extracted: 357
#     Optical Flow Maps: 357
#     Edge Maps: 357
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\319_M135.mp4...
#
#  Video Processed: 319_M135.mp4
#     Faces Extracted: 716
#     Optical Flow Maps: 716
#     Edge Maps: 716
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\517_W135.mp4...
#
#  Video Processed: 517_W135.mp4
#     Faces Extracted: 372
#     Optical Flow Maps: 372
#     Edge Maps: 372
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\753_W024.mp4...
#
#  Video Processed: 753_W024.mp4
#     Faces Extracted: 685
#     Optical Flow Maps: 685
#     Edge Maps: 685
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\163_M005.mp4...
#
#  Video Processed: 163_M005.mp4
#     Faces Extracted: 303
#     Optical Flow Maps: 303
#     Edge Maps: 303
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\449_M138.mp4...
#
#  Video Processed: 449_M138.mp4
#     Faces Extracted: 305
#     Optical Flow Maps: 305
#     Edge Maps: 305
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\391_W016.mp4...
#
#  Video Processed: 391_W016.mp4
#     Faces Extracted: 546
#     Optical Flow Maps: 546
#     Edge Maps: 546
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\690_M004.mp4...
#
#  Video Processed: 690_M004.mp4
#     Faces Extracted: 330
#     Optical Flow Maps: 330
#     Edge Maps: 330
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\647_M123.mp4...
#
#  Video Processed: 647_M123.mp4
#     Faces Extracted: 698
#     Optical Flow Maps: 698
#     Edge Maps: 698
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\704_W017.mp4...
#
#  Video Processed: 704_W017.mp4
#     Faces Extracted: 449
#     Optical Flow Maps: 449
#     Edge Maps: 449
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\096_W017.mp4...
#
#  Video Processed: 096_W017.mp4
#     Faces Extracted: 503
#     Optical Flow Maps: 503
#     Edge Maps: 503
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\830_W036.mp4...
#
#  Video Processed: 830_W036.mp4
#     Faces Extracted: 510
#     Optical Flow Maps: 510
#     Edge Maps: 510
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\676_W013.mp4...
#
#  Video Processed: 676_W013.mp4
#     Faces Extracted: 514
#     Optical Flow Maps: 514
#     Edge Maps: 514
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\389_W016.mp4...
#
#  Video Processed: 389_W016.mp4
#     Faces Extracted: 313
#     Optical Flow Maps: 313
#     Edge Maps: 313
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\236_M012.mp4...
#
#  Video Processed: 236_M012.mp4
#     Faces Extracted: 650
#     Optical Flow Maps: 650
#     Edge Maps: 650
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\485_W031.mp4...
#
#  Video Processed: 485_W031.mp4
#     Faces Extracted: 802
#     Optical Flow Maps: 802
#     Edge Maps: 802
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\407_M029.mp4...
#
#  Video Processed: 407_M029.mp4
#     Faces Extracted: 509
#     Optical Flow Maps: 509
#     Edge Maps: 509
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\399_W017.mp4...
#
#  Video Processed: 399_W017.mp4
#     Faces Extracted: 861
#     Optical Flow Maps: 861
#     Edge Maps: 861
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\867_W040.mp4...
#
#  Video Processed: 867_W040.mp4
#     Faces Extracted: 1488
#     Optical Flow Maps: 1488
#     Edge Maps: 1488
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\422_M031.mp4...
#
#  Video Processed: 422_M031.mp4
#     Faces Extracted: 315
#     Optical Flow Maps: 315
#     Edge Maps: 315
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\089_W016.mp4...
#
#  Video Processed: 089_W016.mp4
#     Faces Extracted: 751
#     Optical Flow Maps: 751
#     Edge Maps: 751
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\240_W039.mp4...
#
#  Video Processed: 240_W039.mp4
#     Faces Extracted: 2127
#     Optical Flow Maps: 2127
#     Edge Maps: 2127
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\397_W017.mp4...
#
#  Video Processed: 397_W017.mp4
#     Faces Extracted: 354
#     Optical Flow Maps: 354
#     Edge Maps: 354
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\689_M004.mp4...
#
#  Video Processed: 689_M004.mp4
#     Faces Extracted: 454
#     Optical Flow Maps: 454
#     Edge Maps: 454
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\361_M025.mp4...
#
#  Video Processed: 361_M025.mp4
#     Faces Extracted: 454
#     Optical Flow Maps: 454
#     Edge Maps: 454
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\772_W028.mp4...
#
#  Video Processed: 772_W028.mp4
#     Faces Extracted: 340
#     Optical Flow Maps: 340
#     Edge Maps: 340
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\141_W024.mp4...
#
#  Video Processed: 141_W024.mp4
#     Faces Extracted: 507
#     Optical Flow Maps: 507
#     Edge Maps: 507
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\873_M025.mp4...
#
#  Video Processed: 873_M025.mp4
#     Faces Extracted: 2650
#     Optical Flow Maps: 2650
#     Edge Maps: 2650
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\811_M133.mp4...
#
#  Video Processed: 811_M133.mp4
#     Faces Extracted: 541
#     Optical Flow Maps: 541
#     Edge Maps: 541
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\271_W111.mp4...
#
#  Video Processed: 271_W111.mp4
#     Faces Extracted: 489
#     Optical Flow Maps: 489
#     Edge Maps: 489
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\944_W100.mp4...
#
#  Video Processed: 944_W100.mp4
#     Faces Extracted: 341
#     Optical Flow Maps: 341
#     Edge Maps: 341
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\870_W040.mp4...
#
#  Video Processed: 870_W040.mp4
#     Faces Extracted: 603
#     Optical Flow Maps: 603
#     Edge Maps: 603
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\034_W009.mp4...
#
#  Video Processed: 034_W009.mp4
#     Faces Extracted: 406
#     Optical Flow Maps: 406
#     Edge Maps: 406
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\877_M026.mp4...
#
#  Video Processed: 877_M026.mp4
#     Faces Extracted: 569
#     Optical Flow Maps: 569
#     Edge Maps: 569
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\491_M038.mp4...
#
#  Video Processed: 491_M038.mp4
#     Faces Extracted: 427
#     Optical Flow Maps: 427
#     Edge Maps: 427
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\812_M133.mp4...
#
#  Video Processed: 812_M133.mp4
#     Faces Extracted: 432
#     Optical Flow Maps: 432
#     Edge Maps: 432
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\697_M005.mp4...
#
#  Video Processed: 697_M005.mp4
#     Faces Extracted: 464
#     Optical Flow Maps: 464
#     Edge Maps: 464
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\087_M120.mp4...
#
#  Video Processed: 087_M120.mp4
#     Faces Extracted: 308
#     Optical Flow Maps: 308
#     Edge Maps: 308
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\618_W101.mp4...
#
#  Video Processed: 618_W101.mp4
#     Faces Extracted: 381
#     Optical Flow Maps: 381
#     Edge Maps: 381
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\741_M010.mp4...
#
#  Video Processed: 741_M010.mp4
#     Faces Extracted: 369
#     Optical Flow Maps: 369
#     Edge Maps: 369
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\968_W008.mp4...
#
#  Video Processed: 968_W008.mp4
#     Faces Extracted: 299
#     Optical Flow Maps: 299
#     Edge Maps: 299
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\154_W026.mp4...
#
#  Video Processed: 154_W026.mp4
#     Faces Extracted: 593
#     Optical Flow Maps: 593
#     Edge Maps: 593
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\298_M018.mp4...
#
#  Video Processed: 298_M018.mp4
#     Faces Extracted: 568
#     Optical Flow Maps: 568
#     Edge Maps: 568
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\166_W028.mp4...
#
#  Video Processed: 166_W028.mp4
#     Faces Extracted: 755
#     Optical Flow Maps: 755
#     Edge Maps: 755
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\438_W023.mp4...
#
#  Video Processed: 438_W023.mp4
#     Faces Extracted: 541
#     Optical Flow Maps: 541
#     Edge Maps: 541
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\857_M023.mp4...
#
#  Video Processed: 857_M023.mp4
#     Faces Extracted: 640
#     Optical Flow Maps: 640
#     Edge Maps: 640
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\230_W136.mp4...
#
#  Video Processed: 230_W136.mp4
#     Faces Extracted: 371
#     Optical Flow Maps: 371
#     Edge Maps: 371
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\855_M023.mp4...
#
#  Video Processed: 855_M023.mp4
#     Faces Extracted: 632
#     Optical Flow Maps: 632
#     Edge Maps: 632
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\431_M136.mp4...
#
#  Video Processed: 431_M136.mp4
#     Faces Extracted: 615
#     Optical Flow Maps: 615
#     Edge Maps: 615
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\927_M136.mp4...
#
#  Video Processed: 927_M136.mp4
#     Faces Extracted: 696
#     Optical Flow Maps: 696
#     Edge Maps: 696
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\588_W111.mp4...
#
#  Video Processed: 588_W111.mp4
#     Faces Extracted: 543
#     Optical Flow Maps: 543
#     Edge Maps: 543
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\125_W101.mp4...
#
#  Video Processed: 125_W101.mp4
#     Faces Extracted: 499
#     Optical Flow Maps: 499
#     Edge Maps: 499
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\380_M027.mp4...
#
#  Video Processed: 380_M027.mp4
#     Faces Extracted: 454
#     Optical Flow Maps: 454
#     Edge Maps: 454
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\189_W031.mp4...
#
#  Video Processed: 189_W031.mp4
#     Faces Extracted: 513
#     Optical Flow Maps: 513
#     Edge Maps: 513
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\011_M131.mp4...
#
#  Video Processed: 011_M131.mp4
#     Faces Extracted: 1262
#     Optical Flow Maps: 1262
#     Edge Maps: 1262
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\429_M136.mp4...
#
#  Video Processed: 429_M136.mp4
#     Faces Extracted: 456
#     Optical Flow Maps: 456
#     Edge Maps: 456
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\915_M031.mp4...
#
#  Video Processed: 915_M031.mp4
#     Faces Extracted: 351
#     Optical Flow Maps: 351
#     Edge Maps: 351
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\363_M025.mp4...
#
#  Video Processed: 363_M025.mp4
#     Faces Extracted: 478
#     Optical Flow Maps: 478
#     Edge Maps: 478
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\779_M013.mp4...
#
#  Video Processed: 779_M013.mp4
#     Faces Extracted: 305
#     Optical Flow Maps: 305
#     Edge Maps: 305
# ==================================================
# Processing F:/dataset/DeeperForensics-1.0/manipulated_videos/end_to_end\603_W125.mp4...
#
#  Video Processed: 603_W125.mp4
#     Faces Extracted: 295
#     Optical Flow Maps: 295
#     Edge Maps: 295
# ==================================================
#
# Processing complete!
